# %%
def update_parameters(parameters,y,y_hat,A1,X):
    parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*A1[0][0])
    parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*A1[1][0])
    parameters['W2'][2][0] = parameters['W2'][2][0] + (0.0001 * (y - y_hat)*A1[2][0])
    parameters['W2'][3][0] = parameters['W2'][3][0] + (0.0001 * (y - y_hat)*A1[3][0])
    parameters['b2'][0][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat))
    
    parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[0][0])
    parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[0][0])
    parameters['W1'][0][2] = parameters['W1'][0][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[0][0])
    parameters['W1'][0][3] = parameters['W1'][0][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[0][0])

    parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[1][0])
    parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[1][0])
    parameters['W1'][1][2] = parameters['W1'][1][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[1][0])
    parameters['W1'][1][3] = parameters['W1'][1][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[1][0])

    parameters['W1'][2][0] = parameters['W1'][2][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[2][0])
    parameters['W1'][2][1] = parameters['W1'][2][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[2][0])
    parameters['W1'][2][2] = parameters['W1'][2][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[2][0])
    parameters['W1'][2][3] = parameters['W1'][2][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[2][0])

    parameters['W1'][3][0] = parameters['W1'][3][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[3][0])
    parameters['W1'][3][1] = parameters['W1'][3][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[3][0])
    parameters['W1'][3][2] = parameters['W1'][3][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[3][0])
    parameters['W1'][3][3] = parameters['W1'][3][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[3][0])

    parameters['W1'][4][0] = parameters['W1'][4][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[4][0])
    parameters['W1'][4][1] = parameters['W1'][4][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[4][0])
    parameters['W1'][4][2] = parameters['W1'][4][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[4][0])
    parameters['W1'][4][3] = parameters['W1'][4][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[4][0])

    parameters['W1'][5][0] = parameters['W1'][5][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[5][0])
    parameters['W1'][5][1] = parameters['W1'][5][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[5][0])
    parameters['W1'][5][2] = parameters['W1'][5][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[5][0])
    parameters['W1'][5][3] = parameters['W1'][5][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[5][0])

    parameters['W1'][6][0] = parameters['W1'][6][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[6][0])
    parameters['W1'][6][1] = parameters['W1'][6][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[6][0])
    parameters['W1'][6][2] = parameters['W1'][6][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[6][0])
    parameters['W1'][6][3] = parameters['W1'][6][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[6][0])

    parameters['W1'][7][0] = parameters['W1'][7][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[7][0])
    parameters['W1'][7][1] = parameters['W1'][7][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[7][0])
    parameters['W1'][7][2] = parameters['W1'][7][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[7][0])
    parameters['W1'][7][3] = parameters['W1'][7][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[7][0])

    parameters['W1'][8][0] = parameters['W1'][8][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[8][0])
    parameters['W1'][8][1] = parameters['W1'][8][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[8][0])
    parameters['W1'][8][2] = parameters['W1'][8][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[8][0])
    parameters['W1'][8][3] = parameters['W1'][8][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[8][0])

    parameters['W1'][9][0] = parameters['W1'][9][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[9][0])
    parameters['W1'][9][1] = parameters['W1'][9][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[9][0])
    parameters['W1'][9][2] = parameters['W1'][9][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[9][0])
    parameters['W1'][9][3] = parameters['W1'][9][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[9][0])

    parameters['W1'][10][0] = parameters['W1'][10][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[10][0])
    parameters['W1'][10][1] = parameters['W1'][10][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[10][0])
    parameters['W1'][10][2] = parameters['W1'][10][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[10][0])
    parameters['W1'][10][3] = parameters['W1'][10][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[10][0])

    parameters['W1'][11][0] = parameters['W1'][11][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[11][0])
    parameters['W1'][11][1] = parameters['W1'][11][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[11][0])
    parameters['W1'][11][2] = parameters['W1'][11][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[11][0])
    parameters['W1'][11][3] = parameters['W1'][11][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[11][0])

    parameters['W1'][12][0] = parameters['W1'][12][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[12][0])
    parameters['W1'][12][1] = parameters['W1'][12][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[12][0])
    parameters['W1'][12][2] = parameters['W1'][12][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[12][0])
    parameters['W1'][12][3] = parameters['W1'][12][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[12][0])

    parameters['W1'][13][0] = parameters['W1'][13][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[13][0])
    parameters['W1'][13][1] = parameters['W1'][13][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[13][0])
    parameters['W1'][13][2] = parameters['W1'][13][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[13][0])
    parameters['W1'][13][3] = parameters['W1'][13][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[13][0])

    parameters['W1'][14][0] = parameters['W1'][14][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[14][0])
    parameters['W1'][14][1] = parameters['W1'][14][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[14][0])
    parameters['W1'][14][2] = parameters['W1'][14][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[14][0])
    parameters['W1'][14][3] = parameters['W1'][14][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[14][0])

    parameters['W1'][15][0] = parameters['W1'][15][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[15][0])
    parameters['W1'][15][1] = parameters['W1'][15][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[15][0])
    parameters['W1'][15][2] = parameters['W1'][15][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[15][0])
    parameters['W1'][15][3] = parameters['W1'][15][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[15][0])

    parameters['W1'][16][0] = parameters['W1'][16][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[16][0])
    parameters['W1'][16][1] = parameters['W1'][16][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[16][0])
    parameters['W1'][16][2] = parameters['W1'][16][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[16][0])
    parameters['W1'][16][3] = parameters['W1'][16][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[16][0])

    parameters['W1'][17][0] = parameters['W1'][17][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[17][0])
    parameters['W1'][17][1] = parameters['W1'][17][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[17][0])
    parameters['W1'][17][2] = parameters['W1'][17][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[17][0])
    parameters['W1'][17][3] = parameters['W1'][17][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[17][0])

    parameters['W1'][18][0] = parameters['W1'][18][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[18][0])
    parameters['W1'][18][1] = parameters['W1'][18][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[18][0])
    parameters['W1'][18][2] = parameters['W1'][18][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[18][0])
    parameters['W1'][18][3] = parameters['W1'][18][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[18][0])

    parameters['W1'][19][0] = parameters['W1'][19][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[19][0])
    parameters['W1'][19][1] = parameters['W1'][19][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[19][0])
    parameters['W1'][19][2] = parameters['W1'][19][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[19][0])
    parameters['W1'][19][3] = parameters['W1'][19][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[19][0])

    parameters['W1'][20][0] = parameters['W1'][20][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[20][0])
    parameters['W1'][20][1] = parameters['W1'][20][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[20][0])
    parameters['W1'][20][2] = parameters['W1'][20][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[20][0])
    parameters['W1'][20][3] = parameters['W1'][20][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[20][0])

    parameters['W1'][21][0] = parameters['W1'][21][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[21][0])
    parameters['W1'][21][1] = parameters['W1'][21][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[21][0])
    parameters['W1'][21][2] = parameters['W1'][21][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[21][0])
    parameters['W1'][21][3] = parameters['W1'][21][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[21][0])

    parameters['W1'][22][0] = parameters['W1'][22][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[22][0])
    parameters['W1'][22][1] = parameters['W1'][22][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[22][0])
    parameters['W1'][22][2] = parameters['W1'][22][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[22][0])
    parameters['W1'][22][3] = parameters['W1'][22][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[22][0])

    parameters['W1'][23][0] = parameters['W1'][23][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[23][0])
    parameters['W1'][23][1] = parameters['W1'][23][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[23][0])
    parameters['W1'][23][2] = parameters['W1'][23][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[23][0])
    parameters['W1'][23][3] = parameters['W1'][23][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[23][0])

    parameters['W1'][24][0] = parameters['W1'][24][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[24][0])
    parameters['W1'][24][1] = parameters['W1'][24][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[24][0])
    parameters['W1'][24][2] = parameters['W1'][24][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[24][0])
    parameters['W1'][24][3] = parameters['W1'][24][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[24][0])

    parameters['W1'][25][0] = parameters['W1'][25][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[25][0])
    parameters['W1'][25][1] = parameters['W1'][25][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[25][0])
    parameters['W1'][25][2] = parameters['W1'][25][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[25][0])
    parameters['W1'][25][3] = parameters['W1'][25][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[25][0])

    parameters['W1'][26][0] = parameters['W1'][26][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[26][0])
    parameters['W1'][26][1] = parameters['W1'][26][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[26][0])
    parameters['W1'][26][2] = parameters['W1'][26][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[26][0])
    parameters['W1'][26][3] = parameters['W1'][26][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[26][0])

    parameters['W1'][27][0] = parameters['W1'][27][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[27][0])
    parameters['W1'][27][1] = parameters['W1'][27][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[27][0])
    parameters['W1'][27][2] = parameters['W1'][27][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[27][0])
    parameters['W1'][27][3] = parameters['W1'][27][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[27][0])

    parameters['W1'][28][0] = parameters['W1'][28][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[28][0])
    parameters['W1'][28][1] = parameters['W1'][28][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[28][0])
    parameters['W1'][28][2] = parameters['W1'][28][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[28][0])
    parameters['W1'][28][3] = parameters['W1'][28][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[28][0])

    parameters['W1'][29][0] = parameters['W1'][29][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[29][0])
    parameters['W1'][29][1] = parameters['W1'][29][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[29][0])
    parameters['W1'][29][2] = parameters['W1'][29][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[29][0])
    parameters['W1'][29][3] = parameters['W1'][29][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[29][0])

    parameters['W1'][30][0] = parameters['W1'][30][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[30][0])
    parameters['W1'][30][1] = parameters['W1'][30][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[30][0])
    parameters['W1'][30][2] = parameters['W1'][30][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[30][0])
    parameters['W1'][30][3] = parameters['W1'][30][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[30][0])

    parameters['W1'][31][0] = parameters['W1'][31][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[31][0])
    parameters['W1'][31][1] = parameters['W1'][31][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[31][0])
    parameters['W1'][31][2] = parameters['W1'][31][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[31][0])
    parameters['W1'][31][3] = parameters['W1'][31][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[31][0])

    parameters['W1'][32][0] = parameters['W1'][32][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[32][0])
    parameters['W1'][32][1] = parameters['W1'][32][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[32][0])
    parameters['W1'][32][2] = parameters['W1'][32][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[32][0])
    parameters['W1'][32][3] = parameters['W1'][32][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[32][0])

    parameters['W1'][33][0] = parameters['W1'][33][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[33][0])
    parameters['W1'][33][1] = parameters['W1'][33][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[33][0])
    parameters['W1'][33][2] = parameters['W1'][33][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[33][0])
    parameters['W1'][33][3] = parameters['W1'][33][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[33][0])

    parameters['W1'][34][0] = parameters['W1'][34][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[34][0])
    parameters['W1'][34][1] = parameters['W1'][34][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[34][0])
    parameters['W1'][34][2] = parameters['W1'][34][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[34][0])
    parameters['W1'][34][3] = parameters['W1'][34][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[34][0])

    parameters['W1'][35][0] = parameters['W1'][35][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[35][0])
    parameters['W1'][35][1] = parameters['W1'][35][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[35][0])
    parameters['W1'][35][2] = parameters['W1'][35][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[35][0])
    parameters['W1'][35][3] = parameters['W1'][35][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[35][0])

    parameters['W1'][36][0] = parameters['W1'][36][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[36][0])
    parameters['W1'][36][1] = parameters['W1'][36][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[36][0])
    parameters['W1'][36][2] = parameters['W1'][36][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[36][0])
    parameters['W1'][36][3] = parameters['W1'][36][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[36][0])

    parameters['W1'][37][0] = parameters['W1'][37][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[37][0])
    parameters['W1'][37][1] = parameters['W1'][37][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[37][0])
    parameters['W1'][37][2] = parameters['W1'][37][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[37][0])
    parameters['W1'][37][3] = parameters['W1'][37][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[37][0])

    parameters['W1'][38][0] = parameters['W1'][38][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[38][0])
    parameters['W1'][38][1] = parameters['W1'][38][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[38][0])
    parameters['W1'][38][2] = parameters['W1'][38][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[38][0])
    parameters['W1'][38][3] = parameters['W1'][38][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[38][0])

    parameters['W1'][39][0] = parameters['W1'][39][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[39][0])
    parameters['W1'][39][1] = parameters['W1'][39][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[39][0])
    parameters['W1'][39][2] = parameters['W1'][39][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[39][0])
    parameters['W1'][39][3] = parameters['W1'][39][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[39][0])

    parameters['W1'][40][0] = parameters['W1'][40][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[40][0])
    parameters['W1'][40][1] = parameters['W1'][40][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[40][0])
    parameters['W1'][40][2] = parameters['W1'][40][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[40][0])
    parameters['W1'][40][3] = parameters['W1'][40][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[40][0])

    parameters['W1'][41][0] = parameters['W1'][41][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[41][0])
    parameters['W1'][41][1] = parameters['W1'][41][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[41][0])
    parameters['W1'][41][2] = parameters['W1'][41][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[41][0])
    parameters['W1'][41][3] = parameters['W1'][41][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[41][0])

    parameters['W1'][42][0] = parameters['W1'][42][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[42][0])
    parameters['W1'][42][1] = parameters['W1'][42][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[42][0])
    parameters['W1'][42][2] = parameters['W1'][42][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[42][0])
    parameters['W1'][42][3] = parameters['W1'][42][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[42][0])

    parameters['W1'][43][0] = parameters['W1'][43][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[43][0])
    parameters['W1'][43][1] = parameters['W1'][43][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[43][0])
    parameters['W1'][43][2] = parameters['W1'][43][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[43][0])
    parameters['W1'][43][3] = parameters['W1'][43][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[43][0])

    parameters['W1'][44][0] = parameters['W1'][44][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[44][0])
    parameters['W1'][44][1] = parameters['W1'][44][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[44][0])
    parameters['W1'][44][2] = parameters['W1'][44][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[44][0])
    parameters['W1'][44][3] = parameters['W1'][44][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[44][0])

    parameters['W1'][45][0] = parameters['W1'][45][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[45][0])
    parameters['W1'][45][1] = parameters['W1'][45][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[45][0])
    parameters['W1'][45][2] = parameters['W1'][45][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[45][0])
    parameters['W1'][45][3] = parameters['W1'][45][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[45][0])

    parameters['W1'][46][0] = parameters['W1'][46][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[46][0])
    parameters['W1'][46][1] = parameters['W1'][46][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[46][0])
    parameters['W1'][46][2] = parameters['W1'][46][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[46][0])
    parameters['W1'][46][3] = parameters['W1'][46][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[46][0])

    parameters['W1'][47][0] = parameters['W1'][47][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[47][0])
    parameters['W1'][47][1] = parameters['W1'][47][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[47][0])
    parameters['W1'][47][2] = parameters['W1'][47][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[47][0])
    parameters['W1'][47][3] = parameters['W1'][47][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[47][0])

    parameters['W1'][48][0] = parameters['W1'][48][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[48][0])
    parameters['W1'][48][1] = parameters['W1'][48][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[48][0])
    parameters['W1'][48][2] = parameters['W1'][48][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[48][0])
    parameters['W1'][48][3] = parameters['W1'][48][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[48][0])

    parameters['W1'][49][0] = parameters['W1'][49][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[49][0])
    parameters['W1'][49][1] = parameters['W1'][49][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[49][0])
    parameters['W1'][49][2] = parameters['W1'][49][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[49][0])
    parameters['W1'][49][3] = parameters['W1'][49][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[49][0])

    parameters['W1'][50][0] = parameters['W1'][50][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[50][0])
    parameters['W1'][50][1] = parameters['W1'][50][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[50][0])
    parameters['W1'][50][2] = parameters['W1'][50][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[50][0])
    parameters['W1'][50][3] = parameters['W1'][50][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[50][0])

    parameters['W1'][51][0] = parameters['W1'][51][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[51][0])
    parameters['W1'][51][1] = parameters['W1'][51][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[51][0])
    parameters['W1'][51][2] = parameters['W1'][51][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[51][0])
    parameters['W1'][51][3] = parameters['W1'][51][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[51][0])

    parameters['W1'][52][0] = parameters['W1'][52][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[52][0])
    parameters['W1'][52][1] = parameters['W1'][52][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[52][0])
    parameters['W1'][52][2] = parameters['W1'][52][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[52][0])
    parameters['W1'][52][3] = parameters['W1'][52][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[52][0])

    parameters['W1'][53][0] = parameters['W1'][53][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[53][0])
    parameters['W1'][53][1] = parameters['W1'][53][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[53][0])
    parameters['W1'][53][2] = parameters['W1'][53][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[53][0])
    parameters['W1'][53][3] = parameters['W1'][53][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[53][0])

    parameters['W1'][54][0] = parameters['W1'][54][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[54][0])
    parameters['W1'][54][1] = parameters['W1'][54][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[54][0])
    parameters['W1'][54][2] = parameters['W1'][54][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[54][0])
    parameters['W1'][54][3] = parameters['W1'][54][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[54][0])

    parameters['W1'][55][0] = parameters['W1'][55][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[55][0])
    parameters['W1'][55][1] = parameters['W1'][55][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[55][0])
    parameters['W1'][55][2] = parameters['W1'][55][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[55][0])
    parameters['W1'][55][3] = parameters['W1'][55][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[55][0])

    parameters['W1'][56][0] = parameters['W1'][56][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[56][0])
    parameters['W1'][56][1] = parameters['W1'][56][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[56][0])
    parameters['W1'][56][2] = parameters['W1'][56][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[56][0])
    parameters['W1'][56][3] = parameters['W1'][56][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[56][0])

    parameters['W1'][57][0] = parameters['W1'][57][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[57][0])
    parameters['W1'][57][1] = parameters['W1'][57][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[57][0])
    parameters['W1'][57][2] = parameters['W1'][57][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[57][0])
    parameters['W1'][57][3] = parameters['W1'][57][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[57][0])

    parameters['W1'][58][0] = parameters['W1'][58][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[58][0])
    parameters['W1'][58][1] = parameters['W1'][58][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[58][0])
    parameters['W1'][58][2] = parameters['W1'][58][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[58][0])
    parameters['W1'][58][3] = parameters['W1'][58][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[58][0])

    parameters['W1'][59][0] = parameters['W1'][59][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[59][0])
    parameters['W1'][59][1] = parameters['W1'][59][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[59][0])
    parameters['W1'][59][2] = parameters['W1'][59][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[59][0])
    parameters['W1'][59][3] = parameters['W1'][59][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[59][0])

    parameters['W1'][60][0] = parameters['W1'][60][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[60][0])
    parameters['W1'][60][1] = parameters['W1'][60][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[60][0])
    parameters['W1'][60][2] = parameters['W1'][60][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[60][0])
    parameters['W1'][60][3] = parameters['W1'][60][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[60][0])

    parameters['W1'][61][0] = parameters['W1'][61][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[61][0])
    parameters['W1'][61][1] = parameters['W1'][61][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[61][0])
    parameters['W1'][61][2] = parameters['W1'][61][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[61][0])
    parameters['W1'][61][3] = parameters['W1'][61][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[61][0])

    parameters['W1'][62][0] = parameters['W1'][62][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[62][0])
    parameters['W1'][62][1] = parameters['W1'][62][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[62][0])
    parameters['W1'][62][2] = parameters['W1'][62][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[62][0])
    parameters['W1'][62][3] = parameters['W1'][62][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[62][0])

    parameters['W1'][63][0] = parameters['W1'][63][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[63][0])
    parameters['W1'][63][1] = parameters['W1'][63][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[63][0])
    parameters['W1'][63][2] = parameters['W1'][63][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[63][0])
    parameters['W1'][63][3] = parameters['W1'][63][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[63][0])

    parameters['W1'][64][0] = parameters['W1'][64][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[64][0])
    parameters['W1'][64][1] = parameters['W1'][64][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[64][0])
    parameters['W1'][64][2] = parameters['W1'][64][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[64][0])
    parameters['W1'][64][3] = parameters['W1'][64][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[64][0])

    parameters['W1'][65][0] = parameters['W1'][65][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[65][0])
    parameters['W1'][65][1] = parameters['W1'][65][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[65][0])
    parameters['W1'][65][2] = parameters['W1'][65][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[65][0])
    parameters['W1'][65][3] = parameters['W1'][65][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[65][0])

    parameters['W1'][66][0] = parameters['W1'][66][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[66][0])
    parameters['W1'][66][1] = parameters['W1'][66][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[66][0])
    parameters['W1'][66][2] = parameters['W1'][66][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[66][0])
    parameters['W1'][66][3] = parameters['W1'][66][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[66][0])

    parameters['W1'][67][0] = parameters['W1'][67][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[67][0])
    parameters['W1'][67][1] = parameters['W1'][67][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[67][0])
    parameters['W1'][67][2] = parameters['W1'][67][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[67][0])
    parameters['W1'][67][3] = parameters['W1'][67][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[67][0])

    parameters['W1'][68][0] = parameters['W1'][68][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[68][0])
    parameters['W1'][68][1] = parameters['W1'][68][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[68][0])
    parameters['W1'][68][2] = parameters['W1'][68][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[68][0])
    parameters['W1'][68][3] = parameters['W1'][68][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[68][0])

    parameters['W1'][69][0] = parameters['W1'][69][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[69][0])
    parameters['W1'][69][1] = parameters['W1'][69][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[69][0])
    parameters['W1'][69][2] = parameters['W1'][69][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[69][0])
    parameters['W1'][69][3] = parameters['W1'][69][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[69][0])

    parameters['W1'][70][0] = parameters['W1'][70][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[70][0])
    parameters['W1'][70][1] = parameters['W1'][70][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[70][0])
    parameters['W1'][70][2] = parameters['W1'][70][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[70][0])
    parameters['W1'][70][3] = parameters['W1'][70][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[70][0])

    parameters['W1'][71][0] = parameters['W1'][71][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[71][0])
    parameters['W1'][71][1] = parameters['W1'][71][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[71][0])
    parameters['W1'][71][2] = parameters['W1'][71][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[71][0])
    parameters['W1'][71][3] = parameters['W1'][71][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[71][0])

    parameters['W1'][72][0] = parameters['W1'][72][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[72][0])
    parameters['W1'][72][1] = parameters['W1'][72][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[72][0])
    parameters['W1'][72][2] = parameters['W1'][72][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[72][0])
    parameters['W1'][72][3] = parameters['W1'][72][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[72][0])

    parameters['W1'][73][0] = parameters['W1'][73][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[73][0])
    parameters['W1'][73][1] = parameters['W1'][73][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[73][0])
    parameters['W1'][73][2] = parameters['W1'][73][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[73][0])
    parameters['W1'][73][3] = parameters['W1'][73][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[73][0])

    parameters['W1'][74][0] = parameters['W1'][74][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[74][0])
    parameters['W1'][74][1] = parameters['W1'][74][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[74][0])
    parameters['W1'][74][2] = parameters['W1'][74][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[74][0])
    parameters['W1'][74][3] = parameters['W1'][74][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[74][0])

    parameters['W1'][75][0] = parameters['W1'][75][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[75][0])
    parameters['W1'][75][1] = parameters['W1'][75][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[75][0])
    parameters['W1'][75][2] = parameters['W1'][75][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[75][0])
    parameters['W1'][75][3] = parameters['W1'][75][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[75][0])

    parameters['W1'][76][0] = parameters['W1'][76][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[76][0])
    parameters['W1'][76][1] = parameters['W1'][76][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[76][0])
    parameters['W1'][76][2] = parameters['W1'][76][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[76][0])
    parameters['W1'][76][3] = parameters['W1'][76][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[76][0])

    parameters['W1'][77][0] = parameters['W1'][77][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[77][0])
    parameters['W1'][77][1] = parameters['W1'][77][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[77][0])
    parameters['W1'][77][2] = parameters['W1'][77][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[77][0])
    parameters['W1'][77][3] = parameters['W1'][77][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[77][0])

    parameters['W1'][78][0] = parameters['W1'][78][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[78][0])
    parameters['W1'][78][1] = parameters['W1'][78][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[78][0])
    parameters['W1'][78][2] = parameters['W1'][78][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[78][0])
    parameters['W1'][78][3] = parameters['W1'][78][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[78][0])

    parameters['W1'][79][0] = parameters['W1'][79][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[79][0])
    parameters['W1'][79][1] = parameters['W1'][79][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[79][0])
    parameters['W1'][79][2] = parameters['W1'][79][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[79][0])
    parameters['W1'][79][3] = parameters['W1'][79][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[79][0])

    parameters['W1'][80][0] = parameters['W1'][80][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[80][0])
    parameters['W1'][80][1] = parameters['W1'][80][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[80][0])
    parameters['W1'][80][2] = parameters['W1'][80][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[80][0])
    parameters['W1'][80][3] = parameters['W1'][80][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[80][0])

    parameters['W1'][81][0] = parameters['W1'][81][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[81][0])
    parameters['W1'][81][1] = parameters['W1'][81][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[81][0])
    parameters['W1'][81][2] = parameters['W1'][81][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[81][0])
    parameters['W1'][81][3] = parameters['W1'][81][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[81][0])

    parameters['W1'][82][0] = parameters['W1'][82][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[82][0])
    parameters['W1'][82][1] = parameters['W1'][82][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[82][0])
    parameters['W1'][82][2] = parameters['W1'][82][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[82][0])
    parameters['W1'][82][3] = parameters['W1'][82][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[82][0])

    parameters['W1'][83][0] = parameters['W1'][83][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[83][0])
    parameters['W1'][83][1] = parameters['W1'][83][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[83][0])
    parameters['W1'][83][2] = parameters['W1'][83][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[83][0])
    parameters['W1'][83][3] = parameters['W1'][83][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[83][0])

    parameters['W1'][84][0] = parameters['W1'][84][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[84][0])
    parameters['W1'][84][1] = parameters['W1'][84][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[84][0])
    parameters['W1'][84][2] = parameters['W1'][84][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[84][0])
    parameters['W1'][84][3] = parameters['W1'][84][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[84][0])

    parameters['W1'][85][0] = parameters['W1'][85][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[85][0])
    parameters['W1'][85][1] = parameters['W1'][85][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[85][0])
    parameters['W1'][85][2] = parameters['W1'][85][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[85][0])
    parameters['W1'][85][3] = parameters['W1'][85][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[85][0])

    parameters['W1'][86][0] = parameters['W1'][86][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[86][0])
    parameters['W1'][86][1] = parameters['W1'][86][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[86][0])
    parameters['W1'][86][2] = parameters['W1'][86][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[86][0])
    parameters['W1'][86][3] = parameters['W1'][86][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[86][0])

    parameters['W1'][87][0] = parameters['W1'][87][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[87][0])
    parameters['W1'][87][1] = parameters['W1'][87][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[87][0])
    parameters['W1'][87][2] = parameters['W1'][87][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[87][0])
    parameters['W1'][87][3] = parameters['W1'][87][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[87][0])

    parameters['W1'][88][0] = parameters['W1'][88][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[88][0])
    parameters['W1'][88][1] = parameters['W1'][88][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[88][0])
    parameters['W1'][88][2] = parameters['W1'][88][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[88][0])
    parameters['W1'][88][3] = parameters['W1'][88][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[88][0])

    parameters['W1'][89][0] = parameters['W1'][89][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[89][0])
    parameters['W1'][89][1] = parameters['W1'][89][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[89][0])
    parameters['W1'][89][2] = parameters['W1'][89][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[89][0])
    parameters['W1'][89][3] = parameters['W1'][89][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[89][0])

    parameters['W1'][90][0] = parameters['W1'][90][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[90][0])
    parameters['W1'][90][1] = parameters['W1'][90][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[90][0])
    parameters['W1'][90][2] = parameters['W1'][90][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[90][0])
    parameters['W1'][90][3] = parameters['W1'][90][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[90][0])

    parameters['W1'][91][0] = parameters['W1'][91][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[91][0])
    parameters['W1'][91][1] = parameters['W1'][91][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[91][0])
    parameters['W1'][91][2] = parameters['W1'][91][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[91][0])
    parameters['W1'][91][3] = parameters['W1'][91][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[91][0])

    parameters['W1'][92][0] = parameters['W1'][92][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[92][0])
    parameters['W1'][92][1] = parameters['W1'][92][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[92][0])
    parameters['W1'][92][2] = parameters['W1'][92][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[92][0])
    parameters['W1'][92][3] = parameters['W1'][92][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[92][0])

    parameters['W1'][93][0] = parameters['W1'][93][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[93][0])
    parameters['W1'][93][1] = parameters['W1'][93][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[93][0])
    parameters['W1'][93][2] = parameters['W1'][93][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[93][0])
    parameters['W1'][93][3] = parameters['W1'][93][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[93][0])

    parameters['W1'][94][0] = parameters['W1'][94][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[94][0])
    parameters['W1'][94][1] = parameters['W1'][94][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[94][0])
    parameters['W1'][94][2] = parameters['W1'][94][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[94][0])
    parameters['W1'][94][3] = parameters['W1'][94][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[94][0])

    parameters['W1'][95][0] = parameters['W1'][95][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[95][0])
    parameters['W1'][95][1] = parameters['W1'][95][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[95][0])
    parameters['W1'][95][2] = parameters['W1'][95][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[95][0])
    parameters['W1'][95][3] = parameters['W1'][95][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[95][0])

    parameters['W1'][96][0] = parameters['W1'][96][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[96][0])
    parameters['W1'][96][1] = parameters['W1'][96][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[96][0])
    parameters['W1'][96][2] = parameters['W1'][96][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[96][0])
    parameters['W1'][96][3] = parameters['W1'][96][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[96][0])

    parameters['W1'][97][0] = parameters['W1'][97][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[97][0])
    parameters['W1'][97][1] = parameters['W1'][97][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[97][0])
    parameters['W1'][97][2] = parameters['W1'][97][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[97][0])
    parameters['W1'][97][3] = parameters['W1'][97][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[97][0])

    parameters['W1'][98][0] = parameters['W1'][98][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[98][0])
    parameters['W1'][98][1] = parameters['W1'][98][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[98][0])
    parameters['W1'][98][2] = parameters['W1'][98][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[98][0])
    parameters['W1'][98][3] = parameters['W1'][98][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[98][0])

    parameters['W1'][99][0] = parameters['W1'][99][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[99][0])
    parameters['W1'][99][1] = parameters['W1'][99][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[99][0])
    parameters['W1'][99][2] = parameters['W1'][99][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[99][0])
    parameters['W1'][99][3] = parameters['W1'][99][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[99][0])

    parameters['W1'][100][0] = parameters['W1'][100][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[100][0])
    parameters['W1'][100][1] = parameters['W1'][100][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[100][0])
    parameters['W1'][100][2] = parameters['W1'][100][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[100][0])
    parameters['W1'][100][3] = parameters['W1'][100][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[100][0])

    parameters['W1'][101][0] = parameters['W1'][101][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[101][0])
    parameters['W1'][101][1] = parameters['W1'][101][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[101][0])
    parameters['W1'][101][2] = parameters['W1'][101][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[101][0])
    parameters['W1'][101][3] = parameters['W1'][101][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[101][0])

    parameters['W1'][102][0] = parameters['W1'][102][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[102][0])
    parameters['W1'][102][1] = parameters['W1'][102][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[102][0])
    parameters['W1'][102][2] = parameters['W1'][102][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[102][0])
    parameters['W1'][102][3] = parameters['W1'][102][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[102][0])

    parameters['W1'][103][0] = parameters['W1'][103][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[103][0])
    parameters['W1'][103][1] = parameters['W1'][103][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[103][0])
    parameters['W1'][103][2] = parameters['W1'][103][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[103][0])
    parameters['W1'][103][3] = parameters['W1'][103][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[103][0])

    parameters['W1'][104][0] = parameters['W1'][104][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[104][0])
    parameters['W1'][104][1] = parameters['W1'][104][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[104][0])
    parameters['W1'][104][2] = parameters['W1'][104][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[104][0])
    parameters['W1'][104][3] = parameters['W1'][104][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[104][0])

    parameters['W1'][105][0] = parameters['W1'][105][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[105][0])
    parameters['W1'][105][1] = parameters['W1'][105][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[105][0])
    parameters['W1'][105][2] = parameters['W1'][105][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[105][0])
    parameters['W1'][105][3] = parameters['W1'][105][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[105][0])

    parameters['W1'][106][0] = parameters['W1'][106][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[106][0])
    parameters['W1'][106][1] = parameters['W1'][106][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[106][0])
    parameters['W1'][106][2] = parameters['W1'][106][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[106][0])
    parameters['W1'][106][3] = parameters['W1'][106][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[106][0])

    parameters['W1'][107][0] = parameters['W1'][107][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[107][0])
    parameters['W1'][107][1] = parameters['W1'][107][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[107][0])
    parameters['W1'][107][2] = parameters['W1'][107][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[107][0])
    parameters['W1'][107][3] = parameters['W1'][107][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[107][0])

    parameters['W1'][108][0] = parameters['W1'][108][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[108][0])
    parameters['W1'][108][1] = parameters['W1'][108][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[108][0])
    parameters['W1'][108][2] = parameters['W1'][108][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[108][0])
    parameters['W1'][108][3] = parameters['W1'][108][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[108][0])

    parameters['W1'][109][0] = parameters['W1'][109][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[109][0])
    parameters['W1'][109][1] = parameters['W1'][109][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[109][0])
    parameters['W1'][109][2] = parameters['W1'][109][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[109][0])
    parameters['W1'][109][3] = parameters['W1'][109][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[109][0])

    parameters['W1'][110][0] = parameters['W1'][110][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[110][0])
    parameters['W1'][110][1] = parameters['W1'][110][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[110][0])
    parameters['W1'][110][2] = parameters['W1'][110][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[110][0])
    parameters['W1'][110][3] = parameters['W1'][110][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[110][0])

    parameters['W1'][111][0] = parameters['W1'][111][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[111][0])
    parameters['W1'][111][1] = parameters['W1'][111][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[111][0])
    parameters['W1'][111][2] = parameters['W1'][111][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[111][0])
    parameters['W1'][111][3] = parameters['W1'][111][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[111][0])

    parameters['W1'][112][0] = parameters['W1'][112][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[112][0])
    parameters['W1'][112][1] = parameters['W1'][112][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[112][0])
    parameters['W1'][112][2] = parameters['W1'][112][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[112][0])
    parameters['W1'][112][3] = parameters['W1'][112][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[112][0])

    parameters['W1'][113][0] = parameters['W1'][113][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[113][0])
    parameters['W1'][113][1] = parameters['W1'][113][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[113][0])
    parameters['W1'][113][2] = parameters['W1'][113][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[113][0])
    parameters['W1'][113][3] = parameters['W1'][113][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[113][0])

    parameters['W1'][114][0] = parameters['W1'][114][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[114][0])
    parameters['W1'][114][1] = parameters['W1'][114][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[114][0])
    parameters['W1'][114][2] = parameters['W1'][114][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[114][0])
    parameters['W1'][114][3] = parameters['W1'][114][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[114][0])

    parameters['W1'][115][0] = parameters['W1'][115][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[115][0])
    parameters['W1'][115][1] = parameters['W1'][115][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[115][0])
    parameters['W1'][115][2] = parameters['W1'][115][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[115][0])
    parameters['W1'][115][3] = parameters['W1'][115][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[115][0])

    parameters['W1'][116][0] = parameters['W1'][116][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[116][0])
    parameters['W1'][116][1] = parameters['W1'][116][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[116][0])
    parameters['W1'][116][2] = parameters['W1'][116][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[116][0])
    parameters['W1'][116][3] = parameters['W1'][116][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[116][0])

    parameters['W1'][117][0] = parameters['W1'][117][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[117][0])
    parameters['W1'][117][1] = parameters['W1'][117][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[117][0])
    parameters['W1'][117][2] = parameters['W1'][117][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[117][0])
    parameters['W1'][117][3] = parameters['W1'][117][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[117][0])

    parameters['W1'][118][0] = parameters['W1'][118][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[118][0])
    parameters['W1'][118][1] = parameters['W1'][118][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[118][0])
    parameters['W1'][118][2] = parameters['W1'][118][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[118][0])
    parameters['W1'][118][3] = parameters['W1'][118][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[118][0])

    parameters['W1'][119][0] = parameters['W1'][119][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[119][0])
    parameters['W1'][119][1] = parameters['W1'][119][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[119][0])
    parameters['W1'][119][2] = parameters['W1'][119][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[119][0])
    parameters['W1'][119][3] = parameters['W1'][119][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[119][0])

    parameters['W1'][120][0] = parameters['W1'][120][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[120][0])
    parameters['W1'][120][1] = parameters['W1'][120][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[120][0])
    parameters['W1'][120][2] = parameters['W1'][120][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[120][0])
    parameters['W1'][120][3] = parameters['W1'][120][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[120][0])

    parameters['W1'][121][0] = parameters['W1'][121][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[121][0])
    parameters['W1'][121][1] = parameters['W1'][121][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[121][0])
    parameters['W1'][121][2] = parameters['W1'][121][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[121][0])
    parameters['W1'][121][3] = parameters['W1'][121][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[121][0])

    parameters['W1'][122][0] = parameters['W1'][122][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[122][0])
    parameters['W1'][122][1] = parameters['W1'][122][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[122][0])
    parameters['W1'][122][2] = parameters['W1'][122][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[122][0])
    parameters['W1'][122][3] = parameters['W1'][122][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[122][0])

    parameters['W1'][123][0] = parameters['W1'][123][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[123][0])
    parameters['W1'][123][1] = parameters['W1'][123][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[123][0])
    parameters['W1'][123][2] = parameters['W1'][123][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[123][0])
    parameters['W1'][123][3] = parameters['W1'][123][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[123][0])

    parameters['W1'][124][0] = parameters['W1'][124][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[124][0])
    parameters['W1'][124][1] = parameters['W1'][124][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[124][0])
    parameters['W1'][124][2] = parameters['W1'][124][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[124][0])
    parameters['W1'][124][3] = parameters['W1'][124][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[124][0])

    parameters['W1'][125][0] = parameters['W1'][125][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[125][0])
    parameters['W1'][125][1] = parameters['W1'][125][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[125][0])
    parameters['W1'][125][2] = parameters['W1'][125][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[125][0])
    parameters['W1'][125][3] = parameters['W1'][125][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[125][0])

    parameters['W1'][126][0] = parameters['W1'][126][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[126][0])
    parameters['W1'][126][1] = parameters['W1'][126][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[126][0])
    parameters['W1'][126][2] = parameters['W1'][126][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[126][0])
    parameters['W1'][126][3] = parameters['W1'][126][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[126][0])

    parameters['W1'][127][0] = parameters['W1'][127][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[127][0])
    parameters['W1'][127][1] = parameters['W1'][127][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[127][0])
    parameters['W1'][127][2] = parameters['W1'][127][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[127][0])
    parameters['W1'][127][3] = parameters['W1'][127][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[127][0])

    parameters['W1'][128][0] = parameters['W1'][128][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[128][0])
    parameters['W1'][128][1] = parameters['W1'][128][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[128][0])
    parameters['W1'][128][2] = parameters['W1'][128][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[128][0])
    parameters['W1'][128][3] = parameters['W1'][128][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[128][0])

    parameters['W1'][129][0] = parameters['W1'][129][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[129][0])
    parameters['W1'][129][1] = parameters['W1'][129][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[129][0])
    parameters['W1'][129][2] = parameters['W1'][129][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[129][0])
    parameters['W1'][129][3] = parameters['W1'][129][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[129][0])

    parameters['W1'][130][0] = parameters['W1'][130][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[130][0])
    parameters['W1'][130][1] = parameters['W1'][130][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[130][0])
    parameters['W1'][130][2] = parameters['W1'][130][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[130][0])
    parameters['W1'][130][3] = parameters['W1'][130][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[130][0])

    parameters['W1'][131][0] = parameters['W1'][131][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[131][0])
    parameters['W1'][131][1] = parameters['W1'][131][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[131][0])
    parameters['W1'][131][2] = parameters['W1'][131][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[131][0])
    parameters['W1'][131][3] = parameters['W1'][131][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[131][0])

    parameters['W1'][132][0] = parameters['W1'][132][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[132][0])
    parameters['W1'][132][1] = parameters['W1'][132][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[132][0])
    parameters['W1'][132][2] = parameters['W1'][132][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[132][0])
    parameters['W1'][132][3] = parameters['W1'][132][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[132][0])

    parameters['W1'][133][0] = parameters['W1'][133][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[133][0])
    parameters['W1'][133][1] = parameters['W1'][133][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[133][0])
    parameters['W1'][133][2] = parameters['W1'][133][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[133][0])
    parameters['W1'][133][3] = parameters['W1'][133][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[133][0])

    parameters['W1'][134][0] = parameters['W1'][134][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[134][0])
    parameters['W1'][134][1] = parameters['W1'][134][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[134][0])
    parameters['W1'][134][2] = parameters['W1'][134][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[134][0])
    parameters['W1'][134][3] = parameters['W1'][134][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[134][0])

    parameters['W1'][135][0] = parameters['W1'][135][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[135][0])
    parameters['W1'][135][1] = parameters['W1'][135][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[135][0])
    parameters['W1'][135][2] = parameters['W1'][135][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[135][0])
    parameters['W1'][135][3] = parameters['W1'][135][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[135][0])

    parameters['W1'][136][0] = parameters['W1'][136][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[136][0])
    parameters['W1'][136][1] = parameters['W1'][136][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[136][0])
    parameters['W1'][136][2] = parameters['W1'][136][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[136][0])
    parameters['W1'][136][3] = parameters['W1'][136][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[136][0])

    parameters['W1'][137][0] = parameters['W1'][137][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[137][0])
    parameters['W1'][137][1] = parameters['W1'][137][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[137][0])
    parameters['W1'][137][2] = parameters['W1'][137][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[137][0])
    parameters['W1'][137][3] = parameters['W1'][137][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[137][0])

    parameters['W1'][138][0] = parameters['W1'][138][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[138][0])
    parameters['W1'][138][1] = parameters['W1'][138][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[138][0])
    parameters['W1'][138][2] = parameters['W1'][138][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[138][0])
    parameters['W1'][138][3] = parameters['W1'][138][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[138][0])

    parameters['W1'][139][0] = parameters['W1'][139][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[139][0])
    parameters['W1'][139][1] = parameters['W1'][139][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[139][0])
    parameters['W1'][139][2] = parameters['W1'][139][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[139][0])
    parameters['W1'][139][3] = parameters['W1'][139][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[139][0])

    parameters['W1'][140][0] = parameters['W1'][140][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[140][0])
    parameters['W1'][140][1] = parameters['W1'][140][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[140][0])
    parameters['W1'][140][2] = parameters['W1'][140][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[140][0])
    parameters['W1'][140][3] = parameters['W1'][140][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[140][0])

    parameters['W1'][141][0] = parameters['W1'][141][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[141][0])
    parameters['W1'][141][1] = parameters['W1'][141][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[141][0])
    parameters['W1'][141][2] = parameters['W1'][141][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[141][0])
    parameters['W1'][141][3] = parameters['W1'][141][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[141][0])

    parameters['W1'][142][0] = parameters['W1'][142][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[142][0])
    parameters['W1'][142][1] = parameters['W1'][142][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[142][0])
    parameters['W1'][142][2] = parameters['W1'][142][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[142][0])
    parameters['W1'][142][3] = parameters['W1'][142][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[142][0])

    parameters['W1'][143][0] = parameters['W1'][143][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[143][0])
    parameters['W1'][143][1] = parameters['W1'][143][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[143][0])
    parameters['W1'][143][2] = parameters['W1'][143][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[143][0])
    parameters['W1'][143][3] = parameters['W1'][143][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[143][0])

    parameters['W1'][144][0] = parameters['W1'][144][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[144][0])
    parameters['W1'][144][1] = parameters['W1'][144][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[144][0])
    parameters['W1'][144][2] = parameters['W1'][144][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[144][0])
    parameters['W1'][144][3] = parameters['W1'][144][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[144][0])

    parameters['W1'][145][0] = parameters['W1'][145][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[145][0])
    parameters['W1'][145][1] = parameters['W1'][145][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[145][0])
    parameters['W1'][145][2] = parameters['W1'][145][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[145][0])
    parameters['W1'][145][3] = parameters['W1'][145][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[145][0])

    parameters['W1'][146][0] = parameters['W1'][146][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[146][0])
    parameters['W1'][146][1] = parameters['W1'][146][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[146][0])
    parameters['W1'][146][2] = parameters['W1'][146][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[146][0])
    parameters['W1'][146][3] = parameters['W1'][146][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[146][0])

    parameters['W1'][147][0] = parameters['W1'][147][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[147][0])
    parameters['W1'][147][1] = parameters['W1'][147][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[147][0])
    parameters['W1'][147][2] = parameters['W1'][147][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[147][0])
    parameters['W1'][147][3] = parameters['W1'][147][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[147][0])

    parameters['W1'][148][0] = parameters['W1'][148][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[148][0])
    parameters['W1'][148][1] = parameters['W1'][148][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[148][0])
    parameters['W1'][148][2] = parameters['W1'][148][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[148][0])
    parameters['W1'][148][3] = parameters['W1'][148][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[148][0])

    parameters['W1'][149][0] = parameters['W1'][149][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[149][0])
    parameters['W1'][149][1] = parameters['W1'][149][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[149][0])
    parameters['W1'][149][2] = parameters['W1'][149][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[149][0])
    parameters['W1'][149][3] = parameters['W1'][149][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[149][0])

    parameters['W1'][150][0] = parameters['W1'][150][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[150][0])
    parameters['W1'][150][1] = parameters['W1'][150][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[150][0])
    parameters['W1'][150][2] = parameters['W1'][150][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[150][0])
    parameters['W1'][150][3] = parameters['W1'][150][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[150][0])

    parameters['W1'][151][0] = parameters['W1'][151][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[151][0])
    parameters['W1'][151][1] = parameters['W1'][151][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[151][0])
    parameters['W1'][151][2] = parameters['W1'][151][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[151][0])
    parameters['W1'][151][3] = parameters['W1'][151][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[151][0])

    parameters['W1'][152][0] = parameters['W1'][152][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[152][0])
    parameters['W1'][152][1] = parameters['W1'][152][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[152][0])
    parameters['W1'][152][2] = parameters['W1'][152][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[152][0])
    parameters['W1'][152][3] = parameters['W1'][152][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[152][0])

    parameters['W1'][153][0] = parameters['W1'][153][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[153][0])
    parameters['W1'][153][1] = parameters['W1'][153][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[153][0])
    parameters['W1'][153][2] = parameters['W1'][153][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[153][0])
    parameters['W1'][153][3] = parameters['W1'][153][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[153][0])

    parameters['W1'][154][0] = parameters['W1'][154][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[154][0])
    parameters['W1'][154][1] = parameters['W1'][154][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[154][0])
    parameters['W1'][154][2] = parameters['W1'][154][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[154][0])
    parameters['W1'][154][3] = parameters['W1'][154][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[154][0])

    parameters['W1'][155][0] = parameters['W1'][155][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[155][0])
    parameters['W1'][155][1] = parameters['W1'][155][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[155][0])
    parameters['W1'][155][2] = parameters['W1'][155][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[155][0])
    parameters['W1'][155][3] = parameters['W1'][155][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[155][0])

    parameters['W1'][156][0] = parameters['W1'][156][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[156][0])
    parameters['W1'][156][1] = parameters['W1'][156][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[156][0])
    parameters['W1'][156][2] = parameters['W1'][156][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[156][0])
    parameters['W1'][156][3] = parameters['W1'][156][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[156][0])

    parameters['W1'][157][0] = parameters['W1'][157][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[157][0])
    parameters['W1'][157][1] = parameters['W1'][157][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[157][0])
    parameters['W1'][157][2] = parameters['W1'][157][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[157][0])
    parameters['W1'][157][3] = parameters['W1'][157][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[157][0])

    parameters['W1'][158][0] = parameters['W1'][158][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[158][0])
    parameters['W1'][158][1] = parameters['W1'][158][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[158][0])
    parameters['W1'][158][2] = parameters['W1'][158][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[158][0])
    parameters['W1'][158][3] = parameters['W1'][158][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[158][0])

    parameters['W1'][159][0] = parameters['W1'][159][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[159][0])
    parameters['W1'][159][1] = parameters['W1'][159][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[159][0])
    parameters['W1'][159][2] = parameters['W1'][159][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[159][0])
    parameters['W1'][159][3] = parameters['W1'][159][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[159][0])

    parameters['W1'][160][0] = parameters['W1'][160][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[160][0])
    parameters['W1'][160][1] = parameters['W1'][160][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[160][0])
    parameters['W1'][160][2] = parameters['W1'][160][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[160][0])
    parameters['W1'][160][3] = parameters['W1'][160][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[160][0])

    parameters['W1'][161][0] = parameters['W1'][161][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[161][0])
    parameters['W1'][161][1] = parameters['W1'][161][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[161][0])
    parameters['W1'][161][2] = parameters['W1'][161][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[161][0])
    parameters['W1'][161][3] = parameters['W1'][161][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[161][0])

    parameters['W1'][162][0] = parameters['W1'][162][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[162][0])
    parameters['W1'][162][1] = parameters['W1'][162][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[162][0])
    parameters['W1'][162][2] = parameters['W1'][162][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[162][0])
    parameters['W1'][162][3] = parameters['W1'][162][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[162][0])

    parameters['W1'][163][0] = parameters['W1'][163][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[163][0])
    parameters['W1'][163][1] = parameters['W1'][163][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[163][0])
    parameters['W1'][163][2] = parameters['W1'][163][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[163][0])
    parameters['W1'][163][3] = parameters['W1'][163][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[163][0])

    parameters['W1'][164][0] = parameters['W1'][164][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[164][0])
    parameters['W1'][164][1] = parameters['W1'][164][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[164][0])
    parameters['W1'][164][2] = parameters['W1'][164][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[164][0])
    parameters['W1'][164][3] = parameters['W1'][164][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[164][0])

    parameters['W1'][165][0] = parameters['W1'][165][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[165][0])
    parameters['W1'][165][1] = parameters['W1'][165][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[165][0])
    parameters['W1'][165][2] = parameters['W1'][165][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[165][0])
    parameters['W1'][165][3] = parameters['W1'][165][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[165][0])

    parameters['W1'][166][0] = parameters['W1'][166][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[166][0])
    parameters['W1'][166][1] = parameters['W1'][166][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[166][0])
    parameters['W1'][166][2] = parameters['W1'][166][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[166][0])
    parameters['W1'][166][3] = parameters['W1'][166][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[166][0])

    parameters['W1'][167][0] = parameters['W1'][167][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[167][0])
    parameters['W1'][167][1] = parameters['W1'][167][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[167][0])
    parameters['W1'][167][2] = parameters['W1'][167][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[167][0])
    parameters['W1'][167][3] = parameters['W1'][167][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[167][0])

    parameters['W1'][168][0] = parameters['W1'][168][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[168][0])
    parameters['W1'][168][1] = parameters['W1'][168][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[168][0])
    parameters['W1'][168][2] = parameters['W1'][168][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[168][0])
    parameters['W1'][168][3] = parameters['W1'][168][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[168][0])

    parameters['W1'][169][0] = parameters['W1'][169][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[169][0])
    parameters['W1'][169][1] = parameters['W1'][169][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[169][0])
    parameters['W1'][169][2] = parameters['W1'][169][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[169][0])
    parameters['W1'][169][3] = parameters['W1'][169][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[169][0])

    parameters['W1'][170][0] = parameters['W1'][170][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[170][0])
    parameters['W1'][170][1] = parameters['W1'][170][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[170][0])
    parameters['W1'][170][2] = parameters['W1'][170][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[170][0])
    parameters['W1'][170][3] = parameters['W1'][170][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[170][0])

    parameters['W1'][171][0] = parameters['W1'][171][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[171][0])
    parameters['W1'][171][1] = parameters['W1'][171][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[171][0])
    parameters['W1'][171][2] = parameters['W1'][171][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[171][0])
    parameters['W1'][171][3] = parameters['W1'][171][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[171][0])

    parameters['W1'][172][0] = parameters['W1'][172][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[172][0])
    parameters['W1'][172][1] = parameters['W1'][172][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[172][0])
    parameters['W1'][172][2] = parameters['W1'][172][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[172][0])
    parameters['W1'][172][3] = parameters['W1'][172][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[172][0])

    parameters['W1'][173][0] = parameters['W1'][173][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[173][0])
    parameters['W1'][173][1] = parameters['W1'][173][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[173][0])
    parameters['W1'][173][2] = parameters['W1'][173][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[173][0])
    parameters['W1'][173][3] = parameters['W1'][173][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[173][0])

    parameters['W1'][174][0] = parameters['W1'][174][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[174][0])
    parameters['W1'][174][1] = parameters['W1'][174][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[174][0])
    parameters['W1'][174][2] = parameters['W1'][174][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[174][0])
    parameters['W1'][174][3] = parameters['W1'][174][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[174][0])

    parameters['W1'][175][0] = parameters['W1'][175][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[175][0])
    parameters['W1'][175][1] = parameters['W1'][175][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[175][0])
    parameters['W1'][175][2] = parameters['W1'][175][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[175][0])
    parameters['W1'][175][3] = parameters['W1'][175][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[175][0])

    parameters['W1'][176][0] = parameters['W1'][176][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[176][0])
    parameters['W1'][176][1] = parameters['W1'][176][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[176][0])
    parameters['W1'][176][2] = parameters['W1'][176][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[176][0])
    parameters['W1'][176][3] = parameters['W1'][176][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[176][0])

    parameters['W1'][177][0] = parameters['W1'][177][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[177][0])
    parameters['W1'][177][1] = parameters['W1'][177][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[177][0])
    parameters['W1'][177][2] = parameters['W1'][177][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[177][0])
    parameters['W1'][177][3] = parameters['W1'][177][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[177][0])

    parameters['W1'][178][0] = parameters['W1'][178][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[178][0])
    parameters['W1'][178][1] = parameters['W1'][178][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[178][0])
    parameters['W1'][178][2] = parameters['W1'][178][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[178][0])
    parameters['W1'][178][3] = parameters['W1'][178][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[178][0])

    parameters['W1'][179][0] = parameters['W1'][179][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[179][0])
    parameters['W1'][179][1] = parameters['W1'][179][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[179][0])
    parameters['W1'][179][2] = parameters['W1'][179][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[179][0])
    parameters['W1'][179][3] = parameters['W1'][179][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[179][0])

    parameters['W1'][180][0] = parameters['W1'][180][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[180][0])
    parameters['W1'][180][1] = parameters['W1'][180][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[180][0])
    parameters['W1'][180][2] = parameters['W1'][180][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[180][0])
    parameters['W1'][180][3] = parameters['W1'][180][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[180][0])

    parameters['W1'][181][0] = parameters['W1'][181][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[181][0])
    parameters['W1'][181][1] = parameters['W1'][181][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[181][0])
    parameters['W1'][181][2] = parameters['W1'][181][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[181][0])
    parameters['W1'][181][3] = parameters['W1'][181][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[181][0])

    parameters['W1'][182][0] = parameters['W1'][182][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[182][0])
    parameters['W1'][182][1] = parameters['W1'][182][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[182][0])
    parameters['W1'][182][2] = parameters['W1'][182][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[182][0])
    parameters['W1'][182][3] = parameters['W1'][182][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[182][0])

    parameters['W1'][183][0] = parameters['W1'][183][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[183][0])
    parameters['W1'][183][1] = parameters['W1'][183][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[183][0])
    parameters['W1'][183][2] = parameters['W1'][183][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[183][0])
    parameters['W1'][183][3] = parameters['W1'][183][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[183][0])

    parameters['W1'][184][0] = parameters['W1'][184][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[184][0])
    parameters['W1'][184][1] = parameters['W1'][184][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[184][0])
    parameters['W1'][184][2] = parameters['W1'][184][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[184][0])
    parameters['W1'][184][3] = parameters['W1'][184][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[184][0])

    parameters['W1'][185][0] = parameters['W1'][185][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[185][0])
    parameters['W1'][185][1] = parameters['W1'][185][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[185][0])
    parameters['W1'][185][2] = parameters['W1'][185][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[185][0])
    parameters['W1'][185][3] = parameters['W1'][185][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[185][0])

    parameters['W1'][186][0] = parameters['W1'][186][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[186][0])
    parameters['W1'][186][1] = parameters['W1'][186][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[186][0])
    parameters['W1'][186][2] = parameters['W1'][186][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[186][0])
    parameters['W1'][186][3] = parameters['W1'][186][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[186][0])

    parameters['W1'][187][0] = parameters['W1'][187][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[187][0])
    parameters['W1'][187][1] = parameters['W1'][187][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[187][0])
    parameters['W1'][187][2] = parameters['W1'][187][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[187][0])
    parameters['W1'][187][3] = parameters['W1'][187][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[187][0])

    parameters['W1'][188][0] = parameters['W1'][188][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[188][0])
    parameters['W1'][188][1] = parameters['W1'][188][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[188][0])
    parameters['W1'][188][2] = parameters['W1'][188][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[188][0])
    parameters['W1'][188][3] = parameters['W1'][188][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[188][0])

    parameters['W1'][189][0] = parameters['W1'][189][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[189][0])
    parameters['W1'][189][1] = parameters['W1'][189][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[189][0])
    parameters['W1'][189][2] = parameters['W1'][189][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[189][0])
    parameters['W1'][189][3] = parameters['W1'][189][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[189][0])

    parameters['W1'][190][0] = parameters['W1'][190][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[190][0])
    parameters['W1'][190][1] = parameters['W1'][190][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[190][0])
    parameters['W1'][190][2] = parameters['W1'][190][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[190][0])
    parameters['W1'][190][3] = parameters['W1'][190][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[190][0])

    parameters['W1'][191][0] = parameters['W1'][191][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[191][0])
    parameters['W1'][191][1] = parameters['W1'][191][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[191][0])
    parameters['W1'][191][2] = parameters['W1'][191][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[191][0])
    parameters['W1'][191][3] = parameters['W1'][191][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[191][0])

    parameters['W1'][192][0] = parameters['W1'][192][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[192][0])
    parameters['W1'][192][1] = parameters['W1'][192][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[192][0])
    parameters['W1'][192][2] = parameters['W1'][192][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[192][0])
    parameters['W1'][192][3] = parameters['W1'][192][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[192][0])

    parameters['W1'][193][0] = parameters['W1'][193][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[193][0])
    parameters['W1'][193][1] = parameters['W1'][193][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[193][0])
    parameters['W1'][193][2] = parameters['W1'][193][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[193][0])
    parameters['W1'][193][3] = parameters['W1'][193][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[193][0])

    parameters['W1'][194][0] = parameters['W1'][194][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[194][0])
    parameters['W1'][194][1] = parameters['W1'][194][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[194][0])
    parameters['W1'][194][2] = parameters['W1'][194][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[194][0])
    parameters['W1'][194][3] = parameters['W1'][194][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[194][0])

    parameters['W1'][195][0] = parameters['W1'][195][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[195][0])
    parameters['W1'][195][1] = parameters['W1'][195][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[195][0])
    parameters['W1'][195][2] = parameters['W1'][195][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[195][0])
    parameters['W1'][195][3] = parameters['W1'][195][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[195][0])

    parameters['W1'][196][0] = parameters['W1'][196][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[196][0])
    parameters['W1'][196][1] = parameters['W1'][196][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[196][0])
    parameters['W1'][196][2] = parameters['W1'][196][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[196][0])
    parameters['W1'][196][3] = parameters['W1'][196][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[196][0])

    parameters['W1'][197][0] = parameters['W1'][197][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[197][0])
    parameters['W1'][197][1] = parameters['W1'][197][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[197][0])
    parameters['W1'][197][2] = parameters['W1'][197][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[197][0])
    parameters['W1'][197][3] = parameters['W1'][197][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[197][0])

    parameters['W1'][198][0] = parameters['W1'][198][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[198][0])
    parameters['W1'][198][1] = parameters['W1'][198][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[198][0])
    parameters['W1'][198][2] = parameters['W1'][198][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[198][0])
    parameters['W1'][198][3] = parameters['W1'][198][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[198][0])

    parameters['W1'][199][0] = parameters['W1'][199][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[199][0])
    parameters['W1'][199][1] = parameters['W1'][199][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[199][0])
    parameters['W1'][199][2] = parameters['W1'][199][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[199][0])
    parameters['W1'][199][3] = parameters['W1'][199][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[199][0])

    parameters['W1'][200][0] = parameters['W1'][200][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[200][0])
    parameters['W1'][200][1] = parameters['W1'][200][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[200][0])
    parameters['W1'][200][2] = parameters['W1'][200][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[200][0])
    parameters['W1'][200][3] = parameters['W1'][200][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[200][0])

    parameters['W1'][201][0] = parameters['W1'][201][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[201][0])
    parameters['W1'][201][1] = parameters['W1'][201][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[201][0])
    parameters['W1'][201][2] = parameters['W1'][201][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[201][0])
    parameters['W1'][201][3] = parameters['W1'][201][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[201][0])

    parameters['W1'][202][0] = parameters['W1'][202][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[202][0])
    parameters['W1'][202][1] = parameters['W1'][202][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[202][0])
    parameters['W1'][202][2] = parameters['W1'][202][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[202][0])
    parameters['W1'][202][3] = parameters['W1'][202][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[202][0])

    parameters['W1'][203][0] = parameters['W1'][203][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[203][0])
    parameters['W1'][203][1] = parameters['W1'][203][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[203][0])
    parameters['W1'][203][2] = parameters['W1'][203][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[203][0])
    parameters['W1'][203][3] = parameters['W1'][203][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[203][0])

    parameters['W1'][204][0] = parameters['W1'][204][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[204][0])
    parameters['W1'][204][1] = parameters['W1'][204][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[204][0])
    parameters['W1'][204][2] = parameters['W1'][204][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[204][0])
    parameters['W1'][204][3] = parameters['W1'][204][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[204][0])

    parameters['W1'][205][0] = parameters['W1'][205][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[205][0])
    parameters['W1'][205][1] = parameters['W1'][205][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[205][0])
    parameters['W1'][205][2] = parameters['W1'][205][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[205][0])
    parameters['W1'][205][3] = parameters['W1'][205][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[205][0])

    parameters['W1'][206][0] = parameters['W1'][206][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[206][0])
    parameters['W1'][206][1] = parameters['W1'][206][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[206][0])
    parameters['W1'][206][2] = parameters['W1'][206][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[206][0])
    parameters['W1'][206][3] = parameters['W1'][206][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[206][0])

    parameters['W1'][207][0] = parameters['W1'][207][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[207][0])
    parameters['W1'][207][1] = parameters['W1'][207][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[207][0])
    parameters['W1'][207][2] = parameters['W1'][207][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[207][0])
    parameters['W1'][207][3] = parameters['W1'][207][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[207][0])

    parameters['W1'][208][0] = parameters['W1'][208][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[208][0])
    parameters['W1'][208][1] = parameters['W1'][208][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[208][0])
    parameters['W1'][208][2] = parameters['W1'][208][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[208][0])
    parameters['W1'][208][3] = parameters['W1'][208][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[208][0])

    parameters['W1'][209][0] = parameters['W1'][209][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[209][0])
    parameters['W1'][209][1] = parameters['W1'][209][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[209][0])
    parameters['W1'][209][2] = parameters['W1'][209][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[209][0])
    parameters['W1'][209][3] = parameters['W1'][209][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[209][0])

    parameters['W1'][210][0] = parameters['W1'][210][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[210][0])
    parameters['W1'][210][1] = parameters['W1'][210][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[210][0])
    parameters['W1'][210][2] = parameters['W1'][210][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[210][0])
    parameters['W1'][210][3] = parameters['W1'][210][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[210][0])

    parameters['W1'][211][0] = parameters['W1'][211][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[211][0])
    parameters['W1'][211][1] = parameters['W1'][211][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[211][0])
    parameters['W1'][211][2] = parameters['W1'][211][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[211][0])
    parameters['W1'][211][3] = parameters['W1'][211][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[211][0])

    parameters['W1'][212][0] = parameters['W1'][212][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[212][0])
    parameters['W1'][212][1] = parameters['W1'][212][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[212][0])
    parameters['W1'][212][2] = parameters['W1'][212][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[212][0])
    parameters['W1'][212][3] = parameters['W1'][212][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[212][0])

    parameters['W1'][213][0] = parameters['W1'][213][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[213][0])
    parameters['W1'][213][1] = parameters['W1'][213][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[213][0])
    parameters['W1'][213][2] = parameters['W1'][213][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[213][0])
    parameters['W1'][213][3] = parameters['W1'][213][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[213][0])

    parameters['W1'][214][0] = parameters['W1'][214][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[214][0])
    parameters['W1'][214][1] = parameters['W1'][214][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[214][0])
    parameters['W1'][214][2] = parameters['W1'][214][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[214][0])
    parameters['W1'][214][3] = parameters['W1'][214][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[214][0])

    parameters['W1'][215][0] = parameters['W1'][215][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[215][0])
    parameters['W1'][215][1] = parameters['W1'][215][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[215][0])
    parameters['W1'][215][2] = parameters['W1'][215][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[215][0])
    parameters['W1'][215][3] = parameters['W1'][215][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[215][0])

    parameters['W1'][216][0] = parameters['W1'][216][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[216][0])
    parameters['W1'][216][1] = parameters['W1'][216][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[216][0])
    parameters['W1'][216][2] = parameters['W1'][216][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[216][0])
    parameters['W1'][216][3] = parameters['W1'][216][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[216][0])

    parameters['W1'][217][0] = parameters['W1'][217][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[217][0])
    parameters['W1'][217][1] = parameters['W1'][217][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[217][0])
    parameters['W1'][217][2] = parameters['W1'][217][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[217][0])
    parameters['W1'][217][3] = parameters['W1'][217][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[217][0])

    parameters['W1'][218][0] = parameters['W1'][218][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[218][0])
    parameters['W1'][218][1] = parameters['W1'][218][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[218][0])
    parameters['W1'][218][2] = parameters['W1'][218][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[218][0])
    parameters['W1'][218][3] = parameters['W1'][218][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[218][0])

    parameters['W1'][219][0] = parameters['W1'][219][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[219][0])
    parameters['W1'][219][1] = parameters['W1'][219][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[219][0])
    parameters['W1'][219][2] = parameters['W1'][219][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[219][0])
    parameters['W1'][219][3] = parameters['W1'][219][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[219][0])

    parameters['W1'][220][0] = parameters['W1'][220][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[220][0])
    parameters['W1'][220][1] = parameters['W1'][220][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[220][0])
    parameters['W1'][220][2] = parameters['W1'][220][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[220][0])
    parameters['W1'][220][3] = parameters['W1'][220][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[220][0])

    parameters['W1'][221][0] = parameters['W1'][221][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[221][0])
    parameters['W1'][221][1] = parameters['W1'][221][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[221][0])
    parameters['W1'][221][2] = parameters['W1'][221][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[221][0])
    parameters['W1'][221][3] = parameters['W1'][221][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[221][0])

    parameters['W1'][222][0] = parameters['W1'][222][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[222][0])
    parameters['W1'][222][1] = parameters['W1'][222][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[222][0])
    parameters['W1'][222][2] = parameters['W1'][222][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[222][0])
    parameters['W1'][222][3] = parameters['W1'][222][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[222][0])

    parameters['W1'][223][0] = parameters['W1'][223][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[223][0])
    parameters['W1'][223][1] = parameters['W1'][223][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[223][0])
    parameters['W1'][223][2] = parameters['W1'][223][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[223][0])
    parameters['W1'][223][3] = parameters['W1'][223][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[223][0])

    parameters['W1'][224][0] = parameters['W1'][224][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[224][0])
    parameters['W1'][224][1] = parameters['W1'][224][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[224][0])
    parameters['W1'][224][2] = parameters['W1'][224][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[224][0])
    parameters['W1'][224][3] = parameters['W1'][224][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[224][0])

    parameters['W1'][225][0] = parameters['W1'][225][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[225][0])
    parameters['W1'][225][1] = parameters['W1'][225][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[225][0])
    parameters['W1'][225][2] = parameters['W1'][225][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[225][0])
    parameters['W1'][225][3] = parameters['W1'][225][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[225][0])

    parameters['W1'][226][0] = parameters['W1'][226][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[226][0])
    parameters['W1'][226][1] = parameters['W1'][226][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[226][0])
    parameters['W1'][226][2] = parameters['W1'][226][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[226][0])
    parameters['W1'][226][3] = parameters['W1'][226][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[226][0])

    parameters['W1'][227][0] = parameters['W1'][227][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[227][0])
    parameters['W1'][227][1] = parameters['W1'][227][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[227][0])
    parameters['W1'][227][2] = parameters['W1'][227][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[227][0])
    parameters['W1'][227][3] = parameters['W1'][227][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[227][0])

    parameters['W1'][228][0] = parameters['W1'][228][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[228][0])
    parameters['W1'][228][1] = parameters['W1'][228][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[228][0])
    parameters['W1'][228][2] = parameters['W1'][228][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[228][0])
    parameters['W1'][228][3] = parameters['W1'][228][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[228][0])

    parameters['W1'][229][0] = parameters['W1'][229][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[229][0])
    parameters['W1'][229][1] = parameters['W1'][229][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[229][0])
    parameters['W1'][229][2] = parameters['W1'][229][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[229][0])
    parameters['W1'][229][3] = parameters['W1'][229][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[229][0])

    parameters['W1'][230][0] = parameters['W1'][230][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[230][0])
    parameters['W1'][230][1] = parameters['W1'][230][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[230][0])
    parameters['W1'][230][2] = parameters['W1'][230][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[230][0])
    parameters['W1'][230][3] = parameters['W1'][230][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[230][0])

    parameters['W1'][231][0] = parameters['W1'][231][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[231][0])
    parameters['W1'][231][1] = parameters['W1'][231][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[231][0])
    parameters['W1'][231][2] = parameters['W1'][231][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[231][0])
    parameters['W1'][231][3] = parameters['W1'][231][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[231][0])

    parameters['W1'][232][0] = parameters['W1'][232][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[232][0])
    parameters['W1'][232][1] = parameters['W1'][232][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[232][0])
    parameters['W1'][232][2] = parameters['W1'][232][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[232][0])
    parameters['W1'][232][3] = parameters['W1'][232][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[232][0])

    parameters['W1'][233][0] = parameters['W1'][233][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[233][0])
    parameters['W1'][233][1] = parameters['W1'][233][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[233][0])
    parameters['W1'][233][2] = parameters['W1'][233][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[233][0])
    parameters['W1'][233][3] = parameters['W1'][233][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[233][0])

    parameters['W1'][234][0] = parameters['W1'][234][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[234][0])
    parameters['W1'][234][1] = parameters['W1'][234][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[234][0])
    parameters['W1'][234][2] = parameters['W1'][234][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[234][0])
    parameters['W1'][234][3] = parameters['W1'][234][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[234][0])

    parameters['W1'][235][0] = parameters['W1'][235][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[235][0])
    parameters['W1'][235][1] = parameters['W1'][235][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[235][0])
    parameters['W1'][235][2] = parameters['W1'][235][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[235][0])
    parameters['W1'][235][3] = parameters['W1'][235][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[235][0])

    parameters['W1'][236][0] = parameters['W1'][236][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[236][0])
    parameters['W1'][236][1] = parameters['W1'][236][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[236][0])
    parameters['W1'][236][2] = parameters['W1'][236][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[236][0])
    parameters['W1'][236][3] = parameters['W1'][236][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[236][0])

    parameters['W1'][237][0] = parameters['W1'][237][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[237][0])
    parameters['W1'][237][1] = parameters['W1'][237][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[237][0])
    parameters['W1'][237][2] = parameters['W1'][237][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[237][0])
    parameters['W1'][237][3] = parameters['W1'][237][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[237][0])

    parameters['W1'][238][0] = parameters['W1'][238][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[238][0])
    parameters['W1'][238][1] = parameters['W1'][238][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[238][0])
    parameters['W1'][238][2] = parameters['W1'][238][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[238][0])
    parameters['W1'][238][3] = parameters['W1'][238][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[238][0])

    parameters['W1'][239][0] = parameters['W1'][239][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[239][0])
    parameters['W1'][239][1] = parameters['W1'][239][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[239][0])
    parameters['W1'][239][2] = parameters['W1'][239][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[239][0])
    parameters['W1'][239][3] = parameters['W1'][239][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[239][0])

    parameters['W1'][240][0] = parameters['W1'][240][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[240][0])
    parameters['W1'][240][1] = parameters['W1'][240][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[240][0])
    parameters['W1'][240][2] = parameters['W1'][240][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[240][0])
    parameters['W1'][240][3] = parameters['W1'][240][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[240][0])

    parameters['W1'][241][0] = parameters['W1'][241][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[241][0])
    parameters['W1'][241][1] = parameters['W1'][241][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[241][0])
    parameters['W1'][241][2] = parameters['W1'][241][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[241][0])
    parameters['W1'][241][3] = parameters['W1'][241][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[241][0])

    parameters['W1'][242][0] = parameters['W1'][242][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[242][0])
    parameters['W1'][242][1] = parameters['W1'][242][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[242][0])
    parameters['W1'][242][2] = parameters['W1'][242][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[242][0])
    parameters['W1'][242][3] = parameters['W1'][242][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[242][0])

    parameters['W1'][243][0] = parameters['W1'][243][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[243][0])
    parameters['W1'][243][1] = parameters['W1'][243][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[243][0])
    parameters['W1'][243][2] = parameters['W1'][243][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[243][0])
    parameters['W1'][243][3] = parameters['W1'][243][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[243][0])

    parameters['W1'][244][0] = parameters['W1'][244][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[244][0])
    parameters['W1'][244][1] = parameters['W1'][244][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[244][0])
    parameters['W1'][244][2] = parameters['W1'][244][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[244][0])
    parameters['W1'][244][3] = parameters['W1'][244][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[244][0])

    parameters['W1'][245][0] = parameters['W1'][245][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[245][0])
    parameters['W1'][245][1] = parameters['W1'][245][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[245][0])
    parameters['W1'][245][2] = parameters['W1'][245][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[245][0])
    parameters['W1'][245][3] = parameters['W1'][245][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[245][0])

    parameters['W1'][246][0] = parameters['W1'][246][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[246][0])
    parameters['W1'][246][1] = parameters['W1'][246][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[246][0])
    parameters['W1'][246][2] = parameters['W1'][246][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[246][0])
    parameters['W1'][246][3] = parameters['W1'][246][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[246][0])

    parameters['W1'][247][0] = parameters['W1'][247][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[247][0])
    parameters['W1'][247][1] = parameters['W1'][247][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[247][0])
    parameters['W1'][247][2] = parameters['W1'][247][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[247][0])
    parameters['W1'][247][3] = parameters['W1'][247][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[247][0])

    parameters['W1'][248][0] = parameters['W1'][248][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[248][0])
    parameters['W1'][248][1] = parameters['W1'][248][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[248][0])
    parameters['W1'][248][2] = parameters['W1'][248][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[248][0])
    parameters['W1'][248][3] = parameters['W1'][248][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[248][0])

    parameters['W1'][249][0] = parameters['W1'][249][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[249][0])
    parameters['W1'][249][1] = parameters['W1'][249][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[249][0])
    parameters['W1'][249][2] = parameters['W1'][249][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[249][0])
    parameters['W1'][249][3] = parameters['W1'][249][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[249][0])

    parameters['W1'][250][0] = parameters['W1'][250][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[250][0])
    parameters['W1'][250][1] = parameters['W1'][250][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[250][0])
    parameters['W1'][250][2] = parameters['W1'][250][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[250][0])
    parameters['W1'][250][3] = parameters['W1'][250][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[250][0])

    parameters['W1'][251][0] = parameters['W1'][251][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[251][0])
    parameters['W1'][251][1] = parameters['W1'][251][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[251][0])
    parameters['W1'][251][2] = parameters['W1'][251][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[251][0])
    parameters['W1'][251][3] = parameters['W1'][251][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[251][0])

    parameters['W1'][252][0] = parameters['W1'][252][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[252][0])
    parameters['W1'][252][1] = parameters['W1'][252][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[252][0])
    parameters['W1'][252][2] = parameters['W1'][252][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[252][0])
    parameters['W1'][252][3] = parameters['W1'][252][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[252][0])

    parameters['W1'][253][0] = parameters['W1'][253][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[253][0])
    parameters['W1'][253][1] = parameters['W1'][253][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[253][0])
    parameters['W1'][253][2] = parameters['W1'][253][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[253][0])
    parameters['W1'][253][3] = parameters['W1'][253][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[253][0])

    parameters['W1'][254][0] = parameters['W1'][254][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[254][0])
    parameters['W1'][254][1] = parameters['W1'][254][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[254][0])
    parameters['W1'][254][2] = parameters['W1'][254][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[254][0])
    parameters['W1'][254][3] = parameters['W1'][254][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[254][0])

    parameters['W1'][255][0] = parameters['W1'][255][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[255][0])
    parameters['W1'][255][1] = parameters['W1'][255][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[255][0])
    parameters['W1'][255][2] = parameters['W1'][255][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[255][0])
    parameters['W1'][255][3] = parameters['W1'][255][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[255][0])

    parameters['W1'][256][0] = parameters['W1'][256][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[256][0])
    parameters['W1'][256][1] = parameters['W1'][256][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[256][0])
    parameters['W1'][256][2] = parameters['W1'][256][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[256][0])
    parameters['W1'][256][3] = parameters['W1'][256][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[256][0])

    parameters['W1'][257][0] = parameters['W1'][257][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[257][0])
    parameters['W1'][257][1] = parameters['W1'][257][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[257][0])
    parameters['W1'][257][2] = parameters['W1'][257][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[257][0])
    parameters['W1'][257][3] = parameters['W1'][257][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[257][0])

    parameters['W1'][258][0] = parameters['W1'][258][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[258][0])
    parameters['W1'][258][1] = parameters['W1'][258][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[258][0])
    parameters['W1'][258][2] = parameters['W1'][258][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[258][0])
    parameters['W1'][258][3] = parameters['W1'][258][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[258][0])

    parameters['W1'][259][0] = parameters['W1'][259][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[259][0])
    parameters['W1'][259][1] = parameters['W1'][259][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[259][0])
    parameters['W1'][259][2] = parameters['W1'][259][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[259][0])
    parameters['W1'][259][3] = parameters['W1'][259][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[259][0])

    parameters['W1'][260][0] = parameters['W1'][260][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[260][0])
    parameters['W1'][260][1] = parameters['W1'][260][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[260][0])
    parameters['W1'][260][2] = parameters['W1'][260][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[260][0])
    parameters['W1'][260][3] = parameters['W1'][260][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[260][0])

    parameters['W1'][261][0] = parameters['W1'][261][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[261][0])
    parameters['W1'][261][1] = parameters['W1'][261][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[261][0])
    parameters['W1'][261][2] = parameters['W1'][261][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[261][0])
    parameters['W1'][261][3] = parameters['W1'][261][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[261][0])

    parameters['W1'][262][0] = parameters['W1'][262][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[262][0])
    parameters['W1'][262][1] = parameters['W1'][262][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[262][0])
    parameters['W1'][262][2] = parameters['W1'][262][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[262][0])
    parameters['W1'][262][3] = parameters['W1'][262][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[262][0])

    parameters['W1'][263][0] = parameters['W1'][263][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[263][0])
    parameters['W1'][263][1] = parameters['W1'][263][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[263][0])
    parameters['W1'][263][2] = parameters['W1'][263][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[263][0])
    parameters['W1'][263][3] = parameters['W1'][263][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[263][0])

    parameters['W1'][264][0] = parameters['W1'][264][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[264][0])
    parameters['W1'][264][1] = parameters['W1'][264][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[264][0])
    parameters['W1'][264][2] = parameters['W1'][264][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[264][0])
    parameters['W1'][264][3] = parameters['W1'][264][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[264][0])

    parameters['W1'][265][0] = parameters['W1'][265][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[265][0])
    parameters['W1'][265][1] = parameters['W1'][265][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[265][0])
    parameters['W1'][265][2] = parameters['W1'][265][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[265][0])
    parameters['W1'][265][3] = parameters['W1'][265][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[265][0])

    parameters['W1'][266][0] = parameters['W1'][266][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[266][0])
    parameters['W1'][266][1] = parameters['W1'][266][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[266][0])
    parameters['W1'][266][2] = parameters['W1'][266][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[266][0])
    parameters['W1'][266][3] = parameters['W1'][266][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[266][0])

    parameters['W1'][267][0] = parameters['W1'][267][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[267][0])
    parameters['W1'][267][1] = parameters['W1'][267][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[267][0])
    parameters['W1'][267][2] = parameters['W1'][267][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[267][0])
    parameters['W1'][267][3] = parameters['W1'][267][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[267][0])

    parameters['W1'][268][0] = parameters['W1'][268][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[268][0])
    parameters['W1'][268][1] = parameters['W1'][268][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[268][0])
    parameters['W1'][268][2] = parameters['W1'][268][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[268][0])
    parameters['W1'][268][3] = parameters['W1'][268][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[268][0])

    parameters['W1'][269][0] = parameters['W1'][269][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[269][0])
    parameters['W1'][269][1] = parameters['W1'][269][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[269][0])
    parameters['W1'][269][2] = parameters['W1'][269][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[269][0])
    parameters['W1'][269][3] = parameters['W1'][269][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[269][0])

    parameters['W1'][270][0] = parameters['W1'][270][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[270][0])
    parameters['W1'][270][1] = parameters['W1'][270][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[270][0])
    parameters['W1'][270][2] = parameters['W1'][270][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[270][0])
    parameters['W1'][270][3] = parameters['W1'][270][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[270][0])

    parameters['W1'][271][0] = parameters['W1'][271][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[271][0])
    parameters['W1'][271][1] = parameters['W1'][271][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[271][0])
    parameters['W1'][271][2] = parameters['W1'][271][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[271][0])
    parameters['W1'][271][3] = parameters['W1'][271][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[271][0])

    parameters['W1'][272][0] = parameters['W1'][272][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[272][0])
    parameters['W1'][272][1] = parameters['W1'][272][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[272][0])
    parameters['W1'][272][2] = parameters['W1'][272][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[272][0])
    parameters['W1'][272][3] = parameters['W1'][272][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[272][0])

    parameters['W1'][273][0] = parameters['W1'][273][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[273][0])
    parameters['W1'][273][1] = parameters['W1'][273][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[273][0])
    parameters['W1'][273][2] = parameters['W1'][273][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[273][0])
    parameters['W1'][273][3] = parameters['W1'][273][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[273][0])

    parameters['W1'][274][0] = parameters['W1'][274][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[274][0])
    parameters['W1'][274][1] = parameters['W1'][274][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[274][0])
    parameters['W1'][274][2] = parameters['W1'][274][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[274][0])
    parameters['W1'][274][3] = parameters['W1'][274][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[274][0])

    parameters['W1'][275][0] = parameters['W1'][275][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[275][0])
    parameters['W1'][275][1] = parameters['W1'][275][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[275][0])
    parameters['W1'][275][2] = parameters['W1'][275][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[275][0])
    parameters['W1'][275][3] = parameters['W1'][275][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[275][0])

    parameters['W1'][276][0] = parameters['W1'][276][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[276][0])
    parameters['W1'][276][1] = parameters['W1'][276][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[276][0])
    parameters['W1'][276][2] = parameters['W1'][276][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[276][0])
    parameters['W1'][276][3] = parameters['W1'][276][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[276][0])

    parameters['W1'][277][0] = parameters['W1'][277][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[277][0])
    parameters['W1'][277][1] = parameters['W1'][277][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[277][0])
    parameters['W1'][277][2] = parameters['W1'][277][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[277][0])
    parameters['W1'][277][3] = parameters['W1'][277][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[277][0])

    parameters['W1'][278][0] = parameters['W1'][278][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[278][0])
    parameters['W1'][278][1] = parameters['W1'][278][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[278][0])
    parameters['W1'][278][2] = parameters['W1'][278][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[278][0])
    parameters['W1'][278][3] = parameters['W1'][278][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[278][0])

    parameters['W1'][279][0] = parameters['W1'][279][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[279][0])
    parameters['W1'][279][1] = parameters['W1'][279][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[279][0])
    parameters['W1'][279][2] = parameters['W1'][279][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[279][0])
    parameters['W1'][279][3] = parameters['W1'][279][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[279][0])

    parameters['W1'][280][0] = parameters['W1'][280][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[280][0])
    parameters['W1'][280][1] = parameters['W1'][280][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[280][0])
    parameters['W1'][280][2] = parameters['W1'][280][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[280][0])
    parameters['W1'][280][3] = parameters['W1'][280][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[280][0])

    parameters['W1'][281][0] = parameters['W1'][281][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[281][0])
    parameters['W1'][281][1] = parameters['W1'][281][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[281][0])
    parameters['W1'][281][2] = parameters['W1'][281][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[281][0])
    parameters['W1'][281][3] = parameters['W1'][281][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[281][0])

    parameters['W1'][282][0] = parameters['W1'][282][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[282][0])
    parameters['W1'][282][1] = parameters['W1'][282][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[282][0])
    parameters['W1'][282][2] = parameters['W1'][282][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[282][0])
    parameters['W1'][282][3] = parameters['W1'][282][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[282][0])

    parameters['W1'][283][0] = parameters['W1'][283][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[283][0])
    parameters['W1'][283][1] = parameters['W1'][283][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[283][0])
    parameters['W1'][283][2] = parameters['W1'][283][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[283][0])
    parameters['W1'][283][3] = parameters['W1'][283][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[283][0])

    parameters['W1'][284][0] = parameters['W1'][284][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[284][0])
    parameters['W1'][284][1] = parameters['W1'][284][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[284][0])
    parameters['W1'][284][2] = parameters['W1'][284][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[284][0])
    parameters['W1'][284][3] = parameters['W1'][284][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[284][0])

    parameters['W1'][285][0] = parameters['W1'][285][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[285][0])
    parameters['W1'][285][1] = parameters['W1'][285][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[285][0])
    parameters['W1'][285][2] = parameters['W1'][285][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[285][0])
    parameters['W1'][285][3] = parameters['W1'][285][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[285][0])

    parameters['W1'][286][0] = parameters['W1'][286][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[286][0])
    parameters['W1'][286][1] = parameters['W1'][286][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[286][0])
    parameters['W1'][286][2] = parameters['W1'][286][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[286][0])
    parameters['W1'][286][3] = parameters['W1'][286][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[286][0])

    parameters['W1'][287][0] = parameters['W1'][287][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[287][0])
    parameters['W1'][287][1] = parameters['W1'][287][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[287][0])
    parameters['W1'][287][2] = parameters['W1'][287][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[287][0])
    parameters['W1'][287][3] = parameters['W1'][287][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[287][0])

    parameters['W1'][288][0] = parameters['W1'][288][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[288][0])
    parameters['W1'][288][1] = parameters['W1'][288][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[288][0])
    parameters['W1'][288][2] = parameters['W1'][288][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[288][0])
    parameters['W1'][288][3] = parameters['W1'][288][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[288][0])

    parameters['W1'][289][0] = parameters['W1'][289][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[289][0])
    parameters['W1'][289][1] = parameters['W1'][289][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[289][0])
    parameters['W1'][289][2] = parameters['W1'][289][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[289][0])
    parameters['W1'][289][3] = parameters['W1'][289][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[289][0])

    parameters['W1'][290][0] = parameters['W1'][290][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[290][0])
    parameters['W1'][290][1] = parameters['W1'][290][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[290][0])
    parameters['W1'][290][2] = parameters['W1'][290][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[290][0])
    parameters['W1'][290][3] = parameters['W1'][290][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[290][0])

    parameters['W1'][291][0] = parameters['W1'][291][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[291][0])
    parameters['W1'][291][1] = parameters['W1'][291][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[291][0])
    parameters['W1'][291][2] = parameters['W1'][291][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[291][0])
    parameters['W1'][291][3] = parameters['W1'][291][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[291][0])

    parameters['W1'][292][0] = parameters['W1'][292][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[292][0])
    parameters['W1'][292][1] = parameters['W1'][292][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[292][0])
    parameters['W1'][292][2] = parameters['W1'][292][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[292][0])
    parameters['W1'][292][3] = parameters['W1'][292][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[292][0])

    parameters['W1'][293][0] = parameters['W1'][293][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[293][0])
    parameters['W1'][293][1] = parameters['W1'][293][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[293][0])
    parameters['W1'][293][2] = parameters['W1'][293][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[293][0])
    parameters['W1'][293][3] = parameters['W1'][293][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[293][0])

    parameters['W1'][294][0] = parameters['W1'][294][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[294][0])
    parameters['W1'][294][1] = parameters['W1'][294][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[294][0])
    parameters['W1'][294][2] = parameters['W1'][294][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[294][0])
    parameters['W1'][294][3] = parameters['W1'][294][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[294][0])

    parameters['W1'][295][0] = parameters['W1'][295][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[295][0])
    parameters['W1'][295][1] = parameters['W1'][295][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[295][0])
    parameters['W1'][295][2] = parameters['W1'][295][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[295][0])
    parameters['W1'][295][3] = parameters['W1'][295][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[295][0])

    parameters['W1'][296][0] = parameters['W1'][296][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[296][0])
    parameters['W1'][296][1] = parameters['W1'][296][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[296][0])
    parameters['W1'][296][2] = parameters['W1'][296][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[296][0])
    parameters['W1'][296][3] = parameters['W1'][296][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[296][0])

    parameters['W1'][297][0] = parameters['W1'][297][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[297][0])
    parameters['W1'][297][1] = parameters['W1'][297][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[297][0])
    parameters['W1'][297][2] = parameters['W1'][297][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[297][0])
    parameters['W1'][297][3] = parameters['W1'][297][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[297][0])

    parameters['W1'][298][0] = parameters['W1'][298][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[298][0])
    parameters['W1'][298][1] = parameters['W1'][298][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[298][0])
    parameters['W1'][298][2] = parameters['W1'][298][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[298][0])
    parameters['W1'][298][3] = parameters['W1'][298][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[298][0])

    parameters['W1'][299][0] = parameters['W1'][299][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[299][0])
    parameters['W1'][299][1] = parameters['W1'][299][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[299][0])
    parameters['W1'][299][2] = parameters['W1'][299][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[299][0])
    parameters['W1'][299][3] = parameters['W1'][299][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[299][0])

    parameters['W1'][300][0] = parameters['W1'][300][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[300][0])
    parameters['W1'][300][1] = parameters['W1'][300][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[300][0])
    parameters['W1'][300][2] = parameters['W1'][300][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[300][0])
    parameters['W1'][300][3] = parameters['W1'][300][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[300][0])

    parameters['W1'][301][0] = parameters['W1'][301][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[301][0])
    parameters['W1'][301][1] = parameters['W1'][301][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[301][0])
    parameters['W1'][301][2] = parameters['W1'][301][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[301][0])
    parameters['W1'][301][3] = parameters['W1'][301][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[301][0])

    parameters['W1'][302][0] = parameters['W1'][302][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[302][0])
    parameters['W1'][302][1] = parameters['W1'][302][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[302][0])
    parameters['W1'][302][2] = parameters['W1'][302][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[302][0])
    parameters['W1'][302][3] = parameters['W1'][302][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[302][0])

    parameters['W1'][303][0] = parameters['W1'][303][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[303][0])
    parameters['W1'][303][1] = parameters['W1'][303][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[303][0])
    parameters['W1'][303][2] = parameters['W1'][303][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[303][0])
    parameters['W1'][303][3] = parameters['W1'][303][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[303][0])

    parameters['W1'][304][0] = parameters['W1'][304][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[304][0])
    parameters['W1'][304][1] = parameters['W1'][304][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[304][0])
    parameters['W1'][304][2] = parameters['W1'][304][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[304][0])
    parameters['W1'][304][3] = parameters['W1'][304][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[304][0])

    parameters['W1'][305][0] = parameters['W1'][305][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[305][0])
    parameters['W1'][305][1] = parameters['W1'][305][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[305][0])
    parameters['W1'][305][2] = parameters['W1'][305][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[305][0])
    parameters['W1'][305][3] = parameters['W1'][305][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[305][0])

    parameters['W1'][306][0] = parameters['W1'][306][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[306][0])
    parameters['W1'][306][1] = parameters['W1'][306][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[306][0])
    parameters['W1'][306][2] = parameters['W1'][306][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[306][0])
    parameters['W1'][306][3] = parameters['W1'][306][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[306][0])

    parameters['W1'][307][0] = parameters['W1'][307][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[307][0])
    parameters['W1'][307][1] = parameters['W1'][307][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[307][0])
    parameters['W1'][307][2] = parameters['W1'][307][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[307][0])
    parameters['W1'][307][3] = parameters['W1'][307][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[307][0])

    parameters['W1'][308][0] = parameters['W1'][308][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[308][0])
    parameters['W1'][308][1] = parameters['W1'][308][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[308][0])
    parameters['W1'][308][2] = parameters['W1'][308][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[308][0])
    parameters['W1'][308][3] = parameters['W1'][308][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[308][0])

    parameters['W1'][309][0] = parameters['W1'][309][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[309][0])
    parameters['W1'][309][1] = parameters['W1'][309][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[309][0])
    parameters['W1'][309][2] = parameters['W1'][309][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[309][0])
    parameters['W1'][309][3] = parameters['W1'][309][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[309][0])

    parameters['W1'][310][0] = parameters['W1'][310][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[310][0])
    parameters['W1'][310][1] = parameters['W1'][310][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[310][0])
    parameters['W1'][310][2] = parameters['W1'][310][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[310][0])
    parameters['W1'][310][3] = parameters['W1'][310][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[310][0])

    parameters['W1'][311][0] = parameters['W1'][311][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[311][0])
    parameters['W1'][311][1] = parameters['W1'][311][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[311][0])
    parameters['W1'][311][2] = parameters['W1'][311][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[311][0])
    parameters['W1'][311][3] = parameters['W1'][311][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[311][0])

    parameters['W1'][312][0] = parameters['W1'][312][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[312][0])
    parameters['W1'][312][1] = parameters['W1'][312][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[312][0])
    parameters['W1'][312][2] = parameters['W1'][312][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[312][0])
    parameters['W1'][312][3] = parameters['W1'][312][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[312][0])

    parameters['W1'][313][0] = parameters['W1'][313][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[313][0])
    parameters['W1'][313][1] = parameters['W1'][313][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[313][0])
    parameters['W1'][313][2] = parameters['W1'][313][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[313][0])
    parameters['W1'][313][3] = parameters['W1'][313][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[313][0])

    parameters['W1'][314][0] = parameters['W1'][314][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[314][0])
    parameters['W1'][314][1] = parameters['W1'][314][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[314][0])
    parameters['W1'][314][2] = parameters['W1'][314][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[314][0])
    parameters['W1'][314][3] = parameters['W1'][314][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[314][0])

    parameters['W1'][315][0] = parameters['W1'][315][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[315][0])
    parameters['W1'][315][1] = parameters['W1'][315][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[315][0])
    parameters['W1'][315][2] = parameters['W1'][315][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[315][0])
    parameters['W1'][315][3] = parameters['W1'][315][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[315][0])

    parameters['W1'][316][0] = parameters['W1'][316][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[316][0])
    parameters['W1'][316][1] = parameters['W1'][316][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[316][0])
    parameters['W1'][316][2] = parameters['W1'][316][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[316][0])
    parameters['W1'][316][3] = parameters['W1'][316][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[316][0])

    parameters['W1'][317][0] = parameters['W1'][317][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[317][0])
    parameters['W1'][317][1] = parameters['W1'][317][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[317][0])
    parameters['W1'][317][2] = parameters['W1'][317][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[317][0])
    parameters['W1'][317][3] = parameters['W1'][317][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[317][0])

    parameters['W1'][318][0] = parameters['W1'][318][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[318][0])
    parameters['W1'][318][1] = parameters['W1'][318][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[318][0])
    parameters['W1'][318][2] = parameters['W1'][318][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[318][0])
    parameters['W1'][318][3] = parameters['W1'][318][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[318][0])

    parameters['W1'][319][0] = parameters['W1'][319][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[319][0])
    parameters['W1'][319][1] = parameters['W1'][319][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[319][0])
    parameters['W1'][319][2] = parameters['W1'][319][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[319][0])
    parameters['W1'][319][3] = parameters['W1'][319][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[319][0])

    parameters['W1'][320][0] = parameters['W1'][320][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[320][0])
    parameters['W1'][320][1] = parameters['W1'][320][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[320][0])
    parameters['W1'][320][2] = parameters['W1'][320][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[320][0])
    parameters['W1'][320][3] = parameters['W1'][320][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[320][0])

    parameters['W1'][321][0] = parameters['W1'][321][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[321][0])
    parameters['W1'][321][1] = parameters['W1'][321][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[321][0])
    parameters['W1'][321][2] = parameters['W1'][321][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[321][0])
    parameters['W1'][321][3] = parameters['W1'][321][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[321][0])

    parameters['W1'][322][0] = parameters['W1'][322][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[322][0])
    parameters['W1'][322][1] = parameters['W1'][322][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[322][0])
    parameters['W1'][322][2] = parameters['W1'][322][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[322][0])
    parameters['W1'][322][3] = parameters['W1'][322][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[322][0])

    parameters['W1'][323][0] = parameters['W1'][323][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[323][0])
    parameters['W1'][323][1] = parameters['W1'][323][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[323][0])
    parameters['W1'][323][2] = parameters['W1'][323][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[323][0])
    parameters['W1'][323][3] = parameters['W1'][323][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[323][0])

    parameters['W1'][324][0] = parameters['W1'][324][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[324][0])
    parameters['W1'][324][1] = parameters['W1'][324][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[324][0])
    parameters['W1'][324][2] = parameters['W1'][324][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[324][0])
    parameters['W1'][324][3] = parameters['W1'][324][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[324][0])

    parameters['W1'][325][0] = parameters['W1'][325][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[325][0])
    parameters['W1'][325][1] = parameters['W1'][325][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[325][0])
    parameters['W1'][325][2] = parameters['W1'][325][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[325][0])
    parameters['W1'][325][3] = parameters['W1'][325][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[325][0])

    parameters['W1'][326][0] = parameters['W1'][326][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[326][0])
    parameters['W1'][326][1] = parameters['W1'][326][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[326][0])
    parameters['W1'][326][2] = parameters['W1'][326][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[326][0])
    parameters['W1'][326][3] = parameters['W1'][326][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[326][0])

    parameters['W1'][327][0] = parameters['W1'][327][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[327][0])
    parameters['W1'][327][1] = parameters['W1'][327][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[327][0])
    parameters['W1'][327][2] = parameters['W1'][327][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[327][0])
    parameters['W1'][327][3] = parameters['W1'][327][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[327][0])

    parameters['W1'][328][0] = parameters['W1'][328][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[328][0])
    parameters['W1'][328][1] = parameters['W1'][328][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[328][0])
    parameters['W1'][328][2] = parameters['W1'][328][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[328][0])
    parameters['W1'][328][3] = parameters['W1'][328][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[328][0])

    parameters['W1'][329][0] = parameters['W1'][329][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[329][0])
    parameters['W1'][329][1] = parameters['W1'][329][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[329][0])
    parameters['W1'][329][2] = parameters['W1'][329][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[329][0])
    parameters['W1'][329][3] = parameters['W1'][329][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[329][0])

    parameters['W1'][330][0] = parameters['W1'][330][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[330][0])
    parameters['W1'][330][1] = parameters['W1'][330][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[330][0])
    parameters['W1'][330][2] = parameters['W1'][330][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[330][0])
    parameters['W1'][330][3] = parameters['W1'][330][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[330][0])

    parameters['W1'][331][0] = parameters['W1'][331][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[331][0])
    parameters['W1'][331][1] = parameters['W1'][331][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[331][0])
    parameters['W1'][331][2] = parameters['W1'][331][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[331][0])
    parameters['W1'][331][3] = parameters['W1'][331][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[331][0])

    parameters['W1'][332][0] = parameters['W1'][332][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[332][0])
    parameters['W1'][332][1] = parameters['W1'][332][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[332][0])
    parameters['W1'][332][2] = parameters['W1'][332][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[332][0])
    parameters['W1'][332][3] = parameters['W1'][332][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[332][0])

    parameters['W1'][333][0] = parameters['W1'][333][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[333][0])
    parameters['W1'][333][1] = parameters['W1'][333][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[333][0])
    parameters['W1'][333][2] = parameters['W1'][333][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[333][0])
    parameters['W1'][333][3] = parameters['W1'][333][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[333][0])

    parameters['W1'][334][0] = parameters['W1'][334][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[334][0])
    parameters['W1'][334][1] = parameters['W1'][334][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[334][0])
    parameters['W1'][334][2] = parameters['W1'][334][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[334][0])
    parameters['W1'][334][3] = parameters['W1'][334][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[334][0])

    parameters['W1'][335][0] = parameters['W1'][335][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[335][0])
    parameters['W1'][335][1] = parameters['W1'][335][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[335][0])
    parameters['W1'][335][2] = parameters['W1'][335][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[335][0])
    parameters['W1'][335][3] = parameters['W1'][335][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[335][0])

    parameters['W1'][336][0] = parameters['W1'][336][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[336][0])
    parameters['W1'][336][1] = parameters['W1'][336][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[336][0])
    parameters['W1'][336][2] = parameters['W1'][336][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[336][0])
    parameters['W1'][336][3] = parameters['W1'][336][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[336][0])

    parameters['W1'][337][0] = parameters['W1'][337][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[337][0])
    parameters['W1'][337][1] = parameters['W1'][337][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[337][0])
    parameters['W1'][337][2] = parameters['W1'][337][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[337][0])
    parameters['W1'][337][3] = parameters['W1'][337][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[337][0])

    parameters['W1'][338][0] = parameters['W1'][338][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[338][0])
    parameters['W1'][338][1] = parameters['W1'][338][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[338][0])
    parameters['W1'][338][2] = parameters['W1'][338][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[338][0])
    parameters['W1'][338][3] = parameters['W1'][338][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[338][0])

    parameters['W1'][339][0] = parameters['W1'][339][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[339][0])
    parameters['W1'][339][1] = parameters['W1'][339][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[339][0])
    parameters['W1'][339][2] = parameters['W1'][339][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[339][0])
    parameters['W1'][339][3] = parameters['W1'][339][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[339][0])

    parameters['W1'][340][0] = parameters['W1'][340][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[340][0])
    parameters['W1'][340][1] = parameters['W1'][340][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[340][0])
    parameters['W1'][340][2] = parameters['W1'][340][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[340][0])
    parameters['W1'][340][3] = parameters['W1'][340][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[340][0])

    parameters['W1'][341][0] = parameters['W1'][341][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[341][0])
    parameters['W1'][341][1] = parameters['W1'][341][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[341][0])
    parameters['W1'][341][2] = parameters['W1'][341][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[341][0])
    parameters['W1'][341][3] = parameters['W1'][341][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[341][0])

    parameters['W1'][342][0] = parameters['W1'][342][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[342][0])
    parameters['W1'][342][1] = parameters['W1'][342][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[342][0])
    parameters['W1'][342][2] = parameters['W1'][342][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[342][0])
    parameters['W1'][342][3] = parameters['W1'][342][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[342][0])

    parameters['W1'][343][0] = parameters['W1'][343][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[343][0])
    parameters['W1'][343][1] = parameters['W1'][343][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[343][0])
    parameters['W1'][343][2] = parameters['W1'][343][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[343][0])
    parameters['W1'][343][3] = parameters['W1'][343][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[343][0])

    parameters['W1'][344][0] = parameters['W1'][344][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[344][0])
    parameters['W1'][344][1] = parameters['W1'][344][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[344][0])
    parameters['W1'][344][2] = parameters['W1'][344][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[344][0])
    parameters['W1'][344][3] = parameters['W1'][344][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[344][0])

    parameters['W1'][345][0] = parameters['W1'][345][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[345][0])
    parameters['W1'][345][1] = parameters['W1'][345][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[345][0])
    parameters['W1'][345][2] = parameters['W1'][345][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[345][0])
    parameters['W1'][345][3] = parameters['W1'][345][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[345][0])

    parameters['W1'][346][0] = parameters['W1'][346][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[346][0])
    parameters['W1'][346][1] = parameters['W1'][346][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[346][0])
    parameters['W1'][346][2] = parameters['W1'][346][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[346][0])
    parameters['W1'][346][3] = parameters['W1'][346][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[346][0])

    parameters['W1'][347][0] = parameters['W1'][347][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[347][0])
    parameters['W1'][347][1] = parameters['W1'][347][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[347][0])
    parameters['W1'][347][2] = parameters['W1'][347][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[347][0])
    parameters['W1'][347][3] = parameters['W1'][347][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[347][0])

    parameters['W1'][348][0] = parameters['W1'][348][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[348][0])
    parameters['W1'][348][1] = parameters['W1'][348][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[348][0])
    parameters['W1'][348][2] = parameters['W1'][348][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[348][0])
    parameters['W1'][348][3] = parameters['W1'][348][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[348][0])

    parameters['W1'][349][0] = parameters['W1'][349][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[349][0])
    parameters['W1'][349][1] = parameters['W1'][349][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[349][0])
    parameters['W1'][349][2] = parameters['W1'][349][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[349][0])
    parameters['W1'][349][3] = parameters['W1'][349][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[349][0])

    parameters['W1'][350][0] = parameters['W1'][350][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[350][0])
    parameters['W1'][350][1] = parameters['W1'][350][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[350][0])
    parameters['W1'][350][2] = parameters['W1'][350][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[350][0])
    parameters['W1'][350][3] = parameters['W1'][350][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[350][0])

    parameters['W1'][351][0] = parameters['W1'][351][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[351][0])
    parameters['W1'][351][1] = parameters['W1'][351][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[351][0])
    parameters['W1'][351][2] = parameters['W1'][351][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[351][0])
    parameters['W1'][351][3] = parameters['W1'][351][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[351][0])

    parameters['W1'][352][0] = parameters['W1'][352][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[352][0])
    parameters['W1'][352][1] = parameters['W1'][352][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[352][0])
    parameters['W1'][352][2] = parameters['W1'][352][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[352][0])
    parameters['W1'][352][3] = parameters['W1'][352][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[352][0])

    parameters['W1'][353][0] = parameters['W1'][353][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[353][0])
    parameters['W1'][353][1] = parameters['W1'][353][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[353][0])
    parameters['W1'][353][2] = parameters['W1'][353][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[353][0])
    parameters['W1'][353][3] = parameters['W1'][353][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[353][0])

    parameters['W1'][354][0] = parameters['W1'][354][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[354][0])
    parameters['W1'][354][1] = parameters['W1'][354][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[354][0])
    parameters['W1'][354][2] = parameters['W1'][354][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[354][0])
    parameters['W1'][354][3] = parameters['W1'][354][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[354][0])

    parameters['W1'][355][0] = parameters['W1'][355][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[355][0])
    parameters['W1'][355][1] = parameters['W1'][355][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[355][0])
    parameters['W1'][355][2] = parameters['W1'][355][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[355][0])
    parameters['W1'][355][3] = parameters['W1'][355][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[355][0])

    parameters['W1'][356][0] = parameters['W1'][356][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[356][0])
    parameters['W1'][356][1] = parameters['W1'][356][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[356][0])
    parameters['W1'][356][2] = parameters['W1'][356][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[356][0])
    parameters['W1'][356][3] = parameters['W1'][356][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[356][0])

    parameters['W1'][357][0] = parameters['W1'][357][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[357][0])
    parameters['W1'][357][1] = parameters['W1'][357][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[357][0])
    parameters['W1'][357][2] = parameters['W1'][357][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[357][0])
    parameters['W1'][357][3] = parameters['W1'][357][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[357][0])

    parameters['W1'][358][0] = parameters['W1'][358][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[358][0])
    parameters['W1'][358][1] = parameters['W1'][358][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[358][0])
    parameters['W1'][358][2] = parameters['W1'][358][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[358][0])
    parameters['W1'][358][3] = parameters['W1'][358][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[358][0])

    parameters['W1'][359][0] = parameters['W1'][359][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[359][0])
    parameters['W1'][359][1] = parameters['W1'][359][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[359][0])
    parameters['W1'][359][2] = parameters['W1'][359][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[359][0])
    parameters['W1'][359][3] = parameters['W1'][359][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[359][0])

    parameters['W1'][360][0] = parameters['W1'][360][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[360][0])
    parameters['W1'][360][1] = parameters['W1'][360][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[360][0])
    parameters['W1'][360][2] = parameters['W1'][360][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[360][0])
    parameters['W1'][360][3] = parameters['W1'][360][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[360][0])

    parameters['W1'][361][0] = parameters['W1'][361][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[361][0])
    parameters['W1'][361][1] = parameters['W1'][361][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[361][0])
    parameters['W1'][361][2] = parameters['W1'][361][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[361][0])
    parameters['W1'][361][3] = parameters['W1'][361][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[361][0])

    parameters['W1'][362][0] = parameters['W1'][362][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[362][0])
    parameters['W1'][362][1] = parameters['W1'][362][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[362][0])
    parameters['W1'][362][2] = parameters['W1'][362][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[362][0])
    parameters['W1'][362][3] = parameters['W1'][362][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[362][0])

    parameters['W1'][363][0] = parameters['W1'][363][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[363][0])
    parameters['W1'][363][1] = parameters['W1'][363][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[363][0])
    parameters['W1'][363][2] = parameters['W1'][363][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[363][0])
    parameters['W1'][363][3] = parameters['W1'][363][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[363][0])

    parameters['W1'][364][0] = parameters['W1'][364][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[364][0])
    parameters['W1'][364][1] = parameters['W1'][364][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[364][0])
    parameters['W1'][364][2] = parameters['W1'][364][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[364][0])
    parameters['W1'][364][3] = parameters['W1'][364][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[364][0])

    parameters['W1'][365][0] = parameters['W1'][365][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[365][0])
    parameters['W1'][365][1] = parameters['W1'][365][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[365][0])
    parameters['W1'][365][2] = parameters['W1'][365][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[365][0])
    parameters['W1'][365][3] = parameters['W1'][365][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[365][0])

    parameters['W1'][366][0] = parameters['W1'][366][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[366][0])
    parameters['W1'][366][1] = parameters['W1'][366][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[366][0])
    parameters['W1'][366][2] = parameters['W1'][366][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[366][0])
    parameters['W1'][366][3] = parameters['W1'][366][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[366][0])

    parameters['W1'][367][0] = parameters['W1'][367][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[367][0])
    parameters['W1'][367][1] = parameters['W1'][367][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[367][0])
    parameters['W1'][367][2] = parameters['W1'][367][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[367][0])
    parameters['W1'][367][3] = parameters['W1'][367][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[367][0])

    parameters['W1'][368][0] = parameters['W1'][368][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[368][0])
    parameters['W1'][368][1] = parameters['W1'][368][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[368][0])
    parameters['W1'][368][2] = parameters['W1'][368][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[368][0])
    parameters['W1'][368][3] = parameters['W1'][368][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[368][0])

    parameters['W1'][369][0] = parameters['W1'][369][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[369][0])
    parameters['W1'][369][1] = parameters['W1'][369][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[369][0])
    parameters['W1'][369][2] = parameters['W1'][369][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[369][0])
    parameters['W1'][369][3] = parameters['W1'][369][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[369][0])

    parameters['W1'][370][0] = parameters['W1'][370][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[370][0])
    parameters['W1'][370][1] = parameters['W1'][370][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[370][0])
    parameters['W1'][370][2] = parameters['W1'][370][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[370][0])
    parameters['W1'][370][3] = parameters['W1'][370][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[370][0])

    parameters['W1'][371][0] = parameters['W1'][371][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[371][0])
    parameters['W1'][371][1] = parameters['W1'][371][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[371][0])
    parameters['W1'][371][2] = parameters['W1'][371][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[371][0])
    parameters['W1'][371][3] = parameters['W1'][371][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[371][0])

    parameters['W1'][372][0] = parameters['W1'][372][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[372][0])
    parameters['W1'][372][1] = parameters['W1'][372][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[372][0])
    parameters['W1'][372][2] = parameters['W1'][372][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[372][0])
    parameters['W1'][372][3] = parameters['W1'][372][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[372][0])

    parameters['W1'][373][0] = parameters['W1'][373][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[373][0])
    parameters['W1'][373][1] = parameters['W1'][373][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[373][0])
    parameters['W1'][373][2] = parameters['W1'][373][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[373][0])
    parameters['W1'][373][3] = parameters['W1'][373][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[373][0])

    parameters['W1'][374][0] = parameters['W1'][374][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[374][0])
    parameters['W1'][374][1] = parameters['W1'][374][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[374][0])
    parameters['W1'][374][2] = parameters['W1'][374][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[374][0])
    parameters['W1'][374][3] = parameters['W1'][374][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[374][0])

    parameters['W1'][375][0] = parameters['W1'][375][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[375][0])
    parameters['W1'][375][1] = parameters['W1'][375][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[375][0])
    parameters['W1'][375][2] = parameters['W1'][375][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[375][0])
    parameters['W1'][375][3] = parameters['W1'][375][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[375][0])

    parameters['W1'][376][0] = parameters['W1'][376][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[376][0])
    parameters['W1'][376][1] = parameters['W1'][376][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[376][0])
    parameters['W1'][376][2] = parameters['W1'][376][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[376][0])
    parameters['W1'][376][3] = parameters['W1'][376][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[376][0])

    parameters['W1'][377][0] = parameters['W1'][377][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[377][0])
    parameters['W1'][377][1] = parameters['W1'][377][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[377][0])
    parameters['W1'][377][2] = parameters['W1'][377][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[377][0])
    parameters['W1'][377][3] = parameters['W1'][377][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[377][0])

    parameters['W1'][378][0] = parameters['W1'][378][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[378][0])
    parameters['W1'][378][1] = parameters['W1'][378][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[378][0])
    parameters['W1'][378][2] = parameters['W1'][378][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[378][0])
    parameters['W1'][378][3] = parameters['W1'][378][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[378][0])

    parameters['W1'][379][0] = parameters['W1'][379][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[379][0])
    parameters['W1'][379][1] = parameters['W1'][379][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[379][0])
    parameters['W1'][379][2] = parameters['W1'][379][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[379][0])
    parameters['W1'][379][3] = parameters['W1'][379][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[379][0])

    parameters['W1'][380][0] = parameters['W1'][380][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[380][0])
    parameters['W1'][380][1] = parameters['W1'][380][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[380][0])
    parameters['W1'][380][2] = parameters['W1'][380][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[380][0])
    parameters['W1'][380][3] = parameters['W1'][380][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[380][0])

    parameters['W1'][381][0] = parameters['W1'][381][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[381][0])
    parameters['W1'][381][1] = parameters['W1'][381][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[381][0])
    parameters['W1'][381][2] = parameters['W1'][381][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[381][0])
    parameters['W1'][381][3] = parameters['W1'][381][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[381][0])

    parameters['W1'][382][0] = parameters['W1'][382][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[382][0])
    parameters['W1'][382][1] = parameters['W1'][382][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[382][0])
    parameters['W1'][382][2] = parameters['W1'][382][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[382][0])
    parameters['W1'][382][3] = parameters['W1'][382][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[382][0])

    parameters['W1'][383][0] = parameters['W1'][383][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[383][0])
    parameters['W1'][383][1] = parameters['W1'][383][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[383][0])
    parameters['W1'][383][2] = parameters['W1'][383][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[383][0])
    parameters['W1'][383][3] = parameters['W1'][383][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[383][0])

    parameters['W1'][384][0] = parameters['W1'][384][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[384][0])
    parameters['W1'][384][1] = parameters['W1'][384][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[384][0])
    parameters['W1'][384][2] = parameters['W1'][384][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[384][0])
    parameters['W1'][384][3] = parameters['W1'][384][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[384][0])

    parameters['W1'][385][0] = parameters['W1'][385][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[385][0])
    parameters['W1'][385][1] = parameters['W1'][385][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[385][0])
    parameters['W1'][385][2] = parameters['W1'][385][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[385][0])
    parameters['W1'][385][3] = parameters['W1'][385][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[385][0])

    parameters['W1'][386][0] = parameters['W1'][386][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[386][0])
    parameters['W1'][386][1] = parameters['W1'][386][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[386][0])
    parameters['W1'][386][2] = parameters['W1'][386][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[386][0])
    parameters['W1'][386][3] = parameters['W1'][386][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[386][0])

    parameters['W1'][387][0] = parameters['W1'][387][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[387][0])
    parameters['W1'][387][1] = parameters['W1'][387][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[387][0])
    parameters['W1'][387][2] = parameters['W1'][387][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[387][0])
    parameters['W1'][387][3] = parameters['W1'][387][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[387][0])

    parameters['W1'][388][0] = parameters['W1'][388][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[388][0])
    parameters['W1'][388][1] = parameters['W1'][388][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[388][0])
    parameters['W1'][388][2] = parameters['W1'][388][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[388][0])
    parameters['W1'][388][3] = parameters['W1'][388][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[388][0])

    parameters['W1'][389][0] = parameters['W1'][389][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[389][0])
    parameters['W1'][389][1] = parameters['W1'][389][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[389][0])
    parameters['W1'][389][2] = parameters['W1'][389][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[389][0])
    parameters['W1'][389][3] = parameters['W1'][389][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[389][0])

    parameters['W1'][390][0] = parameters['W1'][390][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[390][0])
    parameters['W1'][390][1] = parameters['W1'][390][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[390][0])
    parameters['W1'][390][2] = parameters['W1'][390][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[390][0])
    parameters['W1'][390][3] = parameters['W1'][390][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[390][0])

    parameters['W1'][391][0] = parameters['W1'][391][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[391][0])
    parameters['W1'][391][1] = parameters['W1'][391][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[391][0])
    parameters['W1'][391][2] = parameters['W1'][391][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[391][0])
    parameters['W1'][391][3] = parameters['W1'][391][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[391][0])

    parameters['W1'][392][0] = parameters['W1'][392][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[392][0])
    parameters['W1'][392][1] = parameters['W1'][392][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[392][0])
    parameters['W1'][392][2] = parameters['W1'][392][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[392][0])
    parameters['W1'][392][3] = parameters['W1'][392][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[392][0])

    parameters['W1'][393][0] = parameters['W1'][393][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[393][0])
    parameters['W1'][393][1] = parameters['W1'][393][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[393][0])
    parameters['W1'][393][2] = parameters['W1'][393][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[393][0])
    parameters['W1'][393][3] = parameters['W1'][393][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[393][0])

    parameters['W1'][394][0] = parameters['W1'][394][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[394][0])
    parameters['W1'][394][1] = parameters['W1'][394][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[394][0])
    parameters['W1'][394][2] = parameters['W1'][394][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[394][0])
    parameters['W1'][394][3] = parameters['W1'][394][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[394][0])

    parameters['W1'][395][0] = parameters['W1'][395][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[395][0])
    parameters['W1'][395][1] = parameters['W1'][395][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[395][0])
    parameters['W1'][395][2] = parameters['W1'][395][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[395][0])
    parameters['W1'][395][3] = parameters['W1'][395][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[395][0])

    parameters['W1'][396][0] = parameters['W1'][396][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[396][0])
    parameters['W1'][396][1] = parameters['W1'][396][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[396][0])
    parameters['W1'][396][2] = parameters['W1'][396][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[396][0])
    parameters['W1'][396][3] = parameters['W1'][396][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[396][0])

    parameters['W1'][397][0] = parameters['W1'][397][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[397][0])
    parameters['W1'][397][1] = parameters['W1'][397][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[397][0])
    parameters['W1'][397][2] = parameters['W1'][397][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[397][0])
    parameters['W1'][397][3] = parameters['W1'][397][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[397][0])

    parameters['W1'][398][0] = parameters['W1'][398][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[398][0])
    parameters['W1'][398][1] = parameters['W1'][398][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[398][0])
    parameters['W1'][398][2] = parameters['W1'][398][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[398][0])
    parameters['W1'][398][3] = parameters['W1'][398][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[398][0])

    parameters['W1'][399][0] = parameters['W1'][399][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[399][0])
    parameters['W1'][399][1] = parameters['W1'][399][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[399][0])
    parameters['W1'][399][2] = parameters['W1'][399][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[399][0])
    parameters['W1'][399][3] = parameters['W1'][399][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[399][0])

    parameters['W1'][400][0] = parameters['W1'][400][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[400][0])
    parameters['W1'][400][1] = parameters['W1'][400][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[400][0])
    parameters['W1'][400][2] = parameters['W1'][400][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[400][0])
    parameters['W1'][400][3] = parameters['W1'][400][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[400][0])

    parameters['W1'][401][0] = parameters['W1'][401][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[401][0])
    parameters['W1'][401][1] = parameters['W1'][401][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[401][0])
    parameters['W1'][401][2] = parameters['W1'][401][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[401][0])
    parameters['W1'][401][3] = parameters['W1'][401][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[401][0])

    parameters['W1'][402][0] = parameters['W1'][402][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[402][0])
    parameters['W1'][402][1] = parameters['W1'][402][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[402][0])
    parameters['W1'][402][2] = parameters['W1'][402][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[402][0])
    parameters['W1'][402][3] = parameters['W1'][402][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[402][0])

    parameters['W1'][403][0] = parameters['W1'][403][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[403][0])
    parameters['W1'][403][1] = parameters['W1'][403][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[403][0])
    parameters['W1'][403][2] = parameters['W1'][403][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[403][0])
    parameters['W1'][403][3] = parameters['W1'][403][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[403][0])

    parameters['W1'][404][0] = parameters['W1'][404][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[404][0])
    parameters['W1'][404][1] = parameters['W1'][404][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[404][0])
    parameters['W1'][404][2] = parameters['W1'][404][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[404][0])
    parameters['W1'][404][3] = parameters['W1'][404][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[404][0])

    parameters['W1'][405][0] = parameters['W1'][405][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[405][0])
    parameters['W1'][405][1] = parameters['W1'][405][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[405][0])
    parameters['W1'][405][2] = parameters['W1'][405][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[405][0])
    parameters['W1'][405][3] = parameters['W1'][405][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[405][0])

    parameters['W1'][406][0] = parameters['W1'][406][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[406][0])
    parameters['W1'][406][1] = parameters['W1'][406][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[406][0])
    parameters['W1'][406][2] = parameters['W1'][406][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[406][0])
    parameters['W1'][406][3] = parameters['W1'][406][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[406][0])

    parameters['W1'][407][0] = parameters['W1'][407][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[407][0])
    parameters['W1'][407][1] = parameters['W1'][407][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[407][0])
    parameters['W1'][407][2] = parameters['W1'][407][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[407][0])
    parameters['W1'][407][3] = parameters['W1'][407][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[407][0])

    parameters['W1'][408][0] = parameters['W1'][408][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[408][0])
    parameters['W1'][408][1] = parameters['W1'][408][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[408][0])
    parameters['W1'][408][2] = parameters['W1'][408][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[408][0])
    parameters['W1'][408][3] = parameters['W1'][408][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[408][0])

    parameters['W1'][409][0] = parameters['W1'][409][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[409][0])
    parameters['W1'][409][1] = parameters['W1'][409][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[409][0])
    parameters['W1'][409][2] = parameters['W1'][409][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[409][0])
    parameters['W1'][409][3] = parameters['W1'][409][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[409][0])

    parameters['W1'][410][0] = parameters['W1'][410][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[410][0])
    parameters['W1'][410][1] = parameters['W1'][410][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[410][0])
    parameters['W1'][410][2] = parameters['W1'][410][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[410][0])
    parameters['W1'][410][3] = parameters['W1'][410][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[410][0])

    parameters['W1'][411][0] = parameters['W1'][411][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[411][0])
    parameters['W1'][411][1] = parameters['W1'][411][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[411][0])
    parameters['W1'][411][2] = parameters['W1'][411][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[411][0])
    parameters['W1'][411][3] = parameters['W1'][411][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[411][0])

    parameters['W1'][412][0] = parameters['W1'][412][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[412][0])
    parameters['W1'][412][1] = parameters['W1'][412][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[412][0])
    parameters['W1'][412][2] = parameters['W1'][412][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[412][0])
    parameters['W1'][412][3] = parameters['W1'][412][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[412][0])

    parameters['W1'][413][0] = parameters['W1'][413][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[413][0])
    parameters['W1'][413][1] = parameters['W1'][413][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[413][0])
    parameters['W1'][413][2] = parameters['W1'][413][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[413][0])
    parameters['W1'][413][3] = parameters['W1'][413][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[413][0])

    parameters['W1'][414][0] = parameters['W1'][414][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[414][0])
    parameters['W1'][414][1] = parameters['W1'][414][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[414][0])
    parameters['W1'][414][2] = parameters['W1'][414][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[414][0])
    parameters['W1'][414][3] = parameters['W1'][414][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[414][0])

    parameters['W1'][415][0] = parameters['W1'][415][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[415][0])
    parameters['W1'][415][1] = parameters['W1'][415][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[415][0])
    parameters['W1'][415][2] = parameters['W1'][415][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[415][0])
    parameters['W1'][415][3] = parameters['W1'][415][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[415][0])

    parameters['W1'][416][0] = parameters['W1'][416][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[416][0])
    parameters['W1'][416][1] = parameters['W1'][416][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[416][0])
    parameters['W1'][416][2] = parameters['W1'][416][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[416][0])
    parameters['W1'][416][3] = parameters['W1'][416][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[416][0])

    parameters['W1'][417][0] = parameters['W1'][417][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[417][0])
    parameters['W1'][417][1] = parameters['W1'][417][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[417][0])
    parameters['W1'][417][2] = parameters['W1'][417][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[417][0])
    parameters['W1'][417][3] = parameters['W1'][417][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[417][0])

    parameters['W1'][418][0] = parameters['W1'][418][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[418][0])
    parameters['W1'][418][1] = parameters['W1'][418][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[418][0])
    parameters['W1'][418][2] = parameters['W1'][418][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[418][0])
    parameters['W1'][418][3] = parameters['W1'][418][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[418][0])

    parameters['W1'][419][0] = parameters['W1'][419][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[419][0])
    parameters['W1'][419][1] = parameters['W1'][419][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[419][0])
    parameters['W1'][419][2] = parameters['W1'][419][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[419][0])
    parameters['W1'][419][3] = parameters['W1'][419][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[419][0])

    parameters['W1'][420][0] = parameters['W1'][420][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[420][0])
    parameters['W1'][420][1] = parameters['W1'][420][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[420][0])
    parameters['W1'][420][2] = parameters['W1'][420][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[420][0])
    parameters['W1'][420][3] = parameters['W1'][420][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[420][0])

    parameters['W1'][421][0] = parameters['W1'][421][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[421][0])
    parameters['W1'][421][1] = parameters['W1'][421][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[421][0])
    parameters['W1'][421][2] = parameters['W1'][421][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[421][0])
    parameters['W1'][421][3] = parameters['W1'][421][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[421][0])

    parameters['W1'][422][0] = parameters['W1'][422][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[422][0])
    parameters['W1'][422][1] = parameters['W1'][422][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[422][0])
    parameters['W1'][422][2] = parameters['W1'][422][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[422][0])
    parameters['W1'][422][3] = parameters['W1'][422][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[422][0])

    parameters['W1'][423][0] = parameters['W1'][423][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[423][0])
    parameters['W1'][423][1] = parameters['W1'][423][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[423][0])
    parameters['W1'][423][2] = parameters['W1'][423][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[423][0])
    parameters['W1'][423][3] = parameters['W1'][423][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[423][0])

    parameters['W1'][424][0] = parameters['W1'][424][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[424][0])
    parameters['W1'][424][1] = parameters['W1'][424][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[424][0])
    parameters['W1'][424][2] = parameters['W1'][424][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[424][0])
    parameters['W1'][424][3] = parameters['W1'][424][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[424][0])

    parameters['W1'][425][0] = parameters['W1'][425][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[425][0])
    parameters['W1'][425][1] = parameters['W1'][425][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[425][0])
    parameters['W1'][425][2] = parameters['W1'][425][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[425][0])
    parameters['W1'][425][3] = parameters['W1'][425][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[425][0])

    parameters['W1'][426][0] = parameters['W1'][426][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[426][0])
    parameters['W1'][426][1] = parameters['W1'][426][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[426][0])
    parameters['W1'][426][2] = parameters['W1'][426][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[426][0])
    parameters['W1'][426][3] = parameters['W1'][426][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[426][0])

    parameters['W1'][427][0] = parameters['W1'][427][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[427][0])
    parameters['W1'][427][1] = parameters['W1'][427][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[427][0])
    parameters['W1'][427][2] = parameters['W1'][427][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[427][0])
    parameters['W1'][427][3] = parameters['W1'][427][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[427][0])

    parameters['W1'][428][0] = parameters['W1'][428][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[428][0])
    parameters['W1'][428][1] = parameters['W1'][428][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[428][0])
    parameters['W1'][428][2] = parameters['W1'][428][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[428][0])
    parameters['W1'][428][3] = parameters['W1'][428][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[428][0])

    parameters['W1'][429][0] = parameters['W1'][429][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[429][0])
    parameters['W1'][429][1] = parameters['W1'][429][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[429][0])
    parameters['W1'][429][2] = parameters['W1'][429][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[429][0])
    parameters['W1'][429][3] = parameters['W1'][429][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[429][0])

    parameters['W1'][430][0] = parameters['W1'][430][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[430][0])
    parameters['W1'][430][1] = parameters['W1'][430][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[430][0])
    parameters['W1'][430][2] = parameters['W1'][430][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[430][0])
    parameters['W1'][430][3] = parameters['W1'][430][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[430][0])

    parameters['W1'][431][0] = parameters['W1'][431][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[431][0])
    parameters['W1'][431][1] = parameters['W1'][431][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[431][0])
    parameters['W1'][431][2] = parameters['W1'][431][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[431][0])
    parameters['W1'][431][3] = parameters['W1'][431][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[431][0])

    parameters['W1'][432][0] = parameters['W1'][432][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[432][0])
    parameters['W1'][432][1] = parameters['W1'][432][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[432][0])
    parameters['W1'][432][2] = parameters['W1'][432][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[432][0])
    parameters['W1'][432][3] = parameters['W1'][432][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[432][0])

    parameters['W1'][433][0] = parameters['W1'][433][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[433][0])
    parameters['W1'][433][1] = parameters['W1'][433][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[433][0])
    parameters['W1'][433][2] = parameters['W1'][433][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[433][0])
    parameters['W1'][433][3] = parameters['W1'][433][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[433][0])

    parameters['W1'][434][0] = parameters['W1'][434][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[434][0])
    parameters['W1'][434][1] = parameters['W1'][434][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[434][0])
    parameters['W1'][434][2] = parameters['W1'][434][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[434][0])
    parameters['W1'][434][3] = parameters['W1'][434][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[434][0])

    parameters['W1'][435][0] = parameters['W1'][435][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[435][0])
    parameters['W1'][435][1] = parameters['W1'][435][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[435][0])
    parameters['W1'][435][2] = parameters['W1'][435][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[435][0])
    parameters['W1'][435][3] = parameters['W1'][435][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[435][0])

    parameters['W1'][436][0] = parameters['W1'][436][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[436][0])
    parameters['W1'][436][1] = parameters['W1'][436][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[436][0])
    parameters['W1'][436][2] = parameters['W1'][436][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[436][0])
    parameters['W1'][436][3] = parameters['W1'][436][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[436][0])

    parameters['W1'][437][0] = parameters['W1'][437][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[437][0])
    parameters['W1'][437][1] = parameters['W1'][437][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[437][0])
    parameters['W1'][437][2] = parameters['W1'][437][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[437][0])
    parameters['W1'][437][3] = parameters['W1'][437][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[437][0])

    parameters['W1'][438][0] = parameters['W1'][438][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[438][0])
    parameters['W1'][438][1] = parameters['W1'][438][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[438][0])
    parameters['W1'][438][2] = parameters['W1'][438][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[438][0])
    parameters['W1'][438][3] = parameters['W1'][438][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[438][0])

    parameters['W1'][439][0] = parameters['W1'][439][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[439][0])
    parameters['W1'][439][1] = parameters['W1'][439][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[439][0])
    parameters['W1'][439][2] = parameters['W1'][439][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[439][0])
    parameters['W1'][439][3] = parameters['W1'][439][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[439][0])

    parameters['W1'][440][0] = parameters['W1'][440][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[440][0])
    parameters['W1'][440][1] = parameters['W1'][440][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[440][0])
    parameters['W1'][440][2] = parameters['W1'][440][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[440][0])
    parameters['W1'][440][3] = parameters['W1'][440][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[440][0])

    parameters['W1'][441][0] = parameters['W1'][441][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[441][0])
    parameters['W1'][441][1] = parameters['W1'][441][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[441][0])
    parameters['W1'][441][2] = parameters['W1'][441][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[441][0])
    parameters['W1'][441][3] = parameters['W1'][441][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[441][0])

    parameters['W1'][442][0] = parameters['W1'][442][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[442][0])
    parameters['W1'][442][1] = parameters['W1'][442][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[442][0])
    parameters['W1'][442][2] = parameters['W1'][442][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[442][0])
    parameters['W1'][442][3] = parameters['W1'][442][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[442][0])

    parameters['W1'][443][0] = parameters['W1'][443][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[443][0])
    parameters['W1'][443][1] = parameters['W1'][443][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[443][0])
    parameters['W1'][443][2] = parameters['W1'][443][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[443][0])
    parameters['W1'][443][3] = parameters['W1'][443][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[443][0])

    parameters['W1'][444][0] = parameters['W1'][444][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[444][0])
    parameters['W1'][444][1] = parameters['W1'][444][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[444][0])
    parameters['W1'][444][2] = parameters['W1'][444][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[444][0])
    parameters['W1'][444][3] = parameters['W1'][444][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[444][0])

    parameters['W1'][445][0] = parameters['W1'][445][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[445][0])
    parameters['W1'][445][1] = parameters['W1'][445][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[445][0])
    parameters['W1'][445][2] = parameters['W1'][445][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[445][0])
    parameters['W1'][445][3] = parameters['W1'][445][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[445][0])

    parameters['W1'][446][0] = parameters['W1'][446][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[446][0])
    parameters['W1'][446][1] = parameters['W1'][446][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[446][0])
    parameters['W1'][446][2] = parameters['W1'][446][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[446][0])
    parameters['W1'][446][3] = parameters['W1'][446][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[446][0])

    parameters['W1'][447][0] = parameters['W1'][447][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[447][0])
    parameters['W1'][447][1] = parameters['W1'][447][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[447][0])
    parameters['W1'][447][2] = parameters['W1'][447][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[447][0])
    parameters['W1'][447][3] = parameters['W1'][447][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[447][0])

    parameters['W1'][448][0] = parameters['W1'][448][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[448][0])
    parameters['W1'][448][1] = parameters['W1'][448][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[448][0])
    parameters['W1'][448][2] = parameters['W1'][448][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[448][0])
    parameters['W1'][448][3] = parameters['W1'][448][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[448][0])

    parameters['W1'][449][0] = parameters['W1'][449][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[449][0])
    parameters['W1'][449][1] = parameters['W1'][449][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[449][0])
    parameters['W1'][449][2] = parameters['W1'][449][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[449][0])
    parameters['W1'][449][3] = parameters['W1'][449][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[449][0])

    parameters['W1'][450][0] = parameters['W1'][450][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[450][0])
    parameters['W1'][450][1] = parameters['W1'][450][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[450][0])
    parameters['W1'][450][2] = parameters['W1'][450][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[450][0])
    parameters['W1'][450][3] = parameters['W1'][450][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[450][0])

    parameters['W1'][451][0] = parameters['W1'][451][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[451][0])
    parameters['W1'][451][1] = parameters['W1'][451][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[451][0])
    parameters['W1'][451][2] = parameters['W1'][451][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[451][0])
    parameters['W1'][451][3] = parameters['W1'][451][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[451][0])

    parameters['W1'][452][0] = parameters['W1'][452][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[452][0])
    parameters['W1'][452][1] = parameters['W1'][452][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[452][0])
    parameters['W1'][452][2] = parameters['W1'][452][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[452][0])
    parameters['W1'][452][3] = parameters['W1'][452][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[452][0])

    parameters['W1'][453][0] = parameters['W1'][453][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[453][0])
    parameters['W1'][453][1] = parameters['W1'][453][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[453][0])
    parameters['W1'][453][2] = parameters['W1'][453][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[453][0])
    parameters['W1'][453][3] = parameters['W1'][453][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[453][0])

    parameters['W1'][454][0] = parameters['W1'][454][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[454][0])
    parameters['W1'][454][1] = parameters['W1'][454][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[454][0])
    parameters['W1'][454][2] = parameters['W1'][454][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[454][0])
    parameters['W1'][454][3] = parameters['W1'][454][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[454][0])

    parameters['W1'][455][0] = parameters['W1'][455][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[455][0])
    parameters['W1'][455][1] = parameters['W1'][455][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[455][0])
    parameters['W1'][455][2] = parameters['W1'][455][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[455][0])
    parameters['W1'][455][3] = parameters['W1'][455][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[455][0])

    parameters['W1'][456][0] = parameters['W1'][456][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[456][0])
    parameters['W1'][456][1] = parameters['W1'][456][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[456][0])
    parameters['W1'][456][2] = parameters['W1'][456][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[456][0])
    parameters['W1'][456][3] = parameters['W1'][456][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[456][0])

    parameters['W1'][457][0] = parameters['W1'][457][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[457][0])
    parameters['W1'][457][1] = parameters['W1'][457][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[457][0])
    parameters['W1'][457][2] = parameters['W1'][457][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[457][0])
    parameters['W1'][457][3] = parameters['W1'][457][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[457][0])

    parameters['W1'][458][0] = parameters['W1'][458][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[458][0])
    parameters['W1'][458][1] = parameters['W1'][458][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[458][0])
    parameters['W1'][458][2] = parameters['W1'][458][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[458][0])
    parameters['W1'][458][3] = parameters['W1'][458][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[458][0])

    parameters['W1'][459][0] = parameters['W1'][459][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[459][0])
    parameters['W1'][459][1] = parameters['W1'][459][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[459][0])
    parameters['W1'][459][2] = parameters['W1'][459][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[459][0])
    parameters['W1'][459][3] = parameters['W1'][459][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[459][0])

    parameters['W1'][460][0] = parameters['W1'][460][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[460][0])
    parameters['W1'][460][1] = parameters['W1'][460][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[460][0])
    parameters['W1'][460][2] = parameters['W1'][460][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[460][0])
    parameters['W1'][460][3] = parameters['W1'][460][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[460][0])

    parameters['W1'][461][0] = parameters['W1'][461][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[461][0])
    parameters['W1'][461][1] = parameters['W1'][461][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[461][0])
    parameters['W1'][461][2] = parameters['W1'][461][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[461][0])
    parameters['W1'][461][3] = parameters['W1'][461][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[461][0])

    parameters['W1'][462][0] = parameters['W1'][462][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[462][0])
    parameters['W1'][462][1] = parameters['W1'][462][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[462][0])
    parameters['W1'][462][2] = parameters['W1'][462][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[462][0])
    parameters['W1'][462][3] = parameters['W1'][462][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[462][0])

    parameters['W1'][463][0] = parameters['W1'][463][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[463][0])
    parameters['W1'][463][1] = parameters['W1'][463][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[463][0])
    parameters['W1'][463][2] = parameters['W1'][463][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[463][0])
    parameters['W1'][463][3] = parameters['W1'][463][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[463][0])

    parameters['W1'][464][0] = parameters['W1'][464][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[464][0])
    parameters['W1'][464][1] = parameters['W1'][464][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[464][0])
    parameters['W1'][464][2] = parameters['W1'][464][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[464][0])
    parameters['W1'][464][3] = parameters['W1'][464][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[464][0])

    parameters['W1'][465][0] = parameters['W1'][465][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[465][0])
    parameters['W1'][465][1] = parameters['W1'][465][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[465][0])
    parameters['W1'][465][2] = parameters['W1'][465][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[465][0])
    parameters['W1'][465][3] = parameters['W1'][465][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[465][0])

    parameters['W1'][466][0] = parameters['W1'][466][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[466][0])
    parameters['W1'][466][1] = parameters['W1'][466][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[466][0])
    parameters['W1'][466][2] = parameters['W1'][466][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[466][0])
    parameters['W1'][466][3] = parameters['W1'][466][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[466][0])

    parameters['W1'][467][0] = parameters['W1'][467][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[467][0])
    parameters['W1'][467][1] = parameters['W1'][467][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[467][0])
    parameters['W1'][467][2] = parameters['W1'][467][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[467][0])
    parameters['W1'][467][3] = parameters['W1'][467][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[467][0])

    parameters['W1'][468][0] = parameters['W1'][468][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[468][0])
    parameters['W1'][468][1] = parameters['W1'][468][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[468][0])
    parameters['W1'][468][2] = parameters['W1'][468][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[468][0])
    parameters['W1'][468][3] = parameters['W1'][468][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[468][0])

    parameters['W1'][469][0] = parameters['W1'][469][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[469][0])
    parameters['W1'][469][1] = parameters['W1'][469][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[469][0])
    parameters['W1'][469][2] = parameters['W1'][469][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[469][0])
    parameters['W1'][469][3] = parameters['W1'][469][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[469][0])

    parameters['W1'][470][0] = parameters['W1'][470][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[470][0])
    parameters['W1'][470][1] = parameters['W1'][470][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[470][0])
    parameters['W1'][470][2] = parameters['W1'][470][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[470][0])
    parameters['W1'][470][3] = parameters['W1'][470][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[470][0])

    parameters['W1'][471][0] = parameters['W1'][471][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[471][0])
    parameters['W1'][471][1] = parameters['W1'][471][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[471][0])
    parameters['W1'][471][2] = parameters['W1'][471][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[471][0])
    parameters['W1'][471][3] = parameters['W1'][471][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[471][0])

    parameters['W1'][472][0] = parameters['W1'][472][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[472][0])
    parameters['W1'][472][1] = parameters['W1'][472][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[472][0])
    parameters['W1'][472][2] = parameters['W1'][472][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[472][0])
    parameters['W1'][472][3] = parameters['W1'][472][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[472][0])

    parameters['W1'][473][0] = parameters['W1'][473][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[473][0])
    parameters['W1'][473][1] = parameters['W1'][473][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[473][0])
    parameters['W1'][473][2] = parameters['W1'][473][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[473][0])
    parameters['W1'][473][3] = parameters['W1'][473][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[473][0])

    parameters['W1'][474][0] = parameters['W1'][474][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[474][0])
    parameters['W1'][474][1] = parameters['W1'][474][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[474][0])
    parameters['W1'][474][2] = parameters['W1'][474][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[474][0])
    parameters['W1'][474][3] = parameters['W1'][474][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[474][0])

    parameters['W1'][475][0] = parameters['W1'][475][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[475][0])
    parameters['W1'][475][1] = parameters['W1'][475][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[475][0])
    parameters['W1'][475][2] = parameters['W1'][475][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[475][0])
    parameters['W1'][475][3] = parameters['W1'][475][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[475][0])

    parameters['W1'][476][0] = parameters['W1'][476][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[476][0])
    parameters['W1'][476][1] = parameters['W1'][476][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[476][0])
    parameters['W1'][476][2] = parameters['W1'][476][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[476][0])
    parameters['W1'][476][3] = parameters['W1'][476][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[476][0])

    parameters['W1'][477][0] = parameters['W1'][477][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[477][0])
    parameters['W1'][477][1] = parameters['W1'][477][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[477][0])
    parameters['W1'][477][2] = parameters['W1'][477][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[477][0])
    parameters['W1'][477][3] = parameters['W1'][477][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[477][0])

    parameters['W1'][478][0] = parameters['W1'][478][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[478][0])
    parameters['W1'][478][1] = parameters['W1'][478][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[478][0])
    parameters['W1'][478][2] = parameters['W1'][478][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[478][0])
    parameters['W1'][478][3] = parameters['W1'][478][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[478][0])

    parameters['W1'][479][0] = parameters['W1'][479][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[479][0])
    parameters['W1'][479][1] = parameters['W1'][479][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[479][0])
    parameters['W1'][479][2] = parameters['W1'][479][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[479][0])
    parameters['W1'][479][3] = parameters['W1'][479][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[479][0])

    parameters['W1'][480][0] = parameters['W1'][480][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[480][0])
    parameters['W1'][480][1] = parameters['W1'][480][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[480][0])
    parameters['W1'][480][2] = parameters['W1'][480][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[480][0])
    parameters['W1'][480][3] = parameters['W1'][480][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[480][0])

    parameters['W1'][481][0] = parameters['W1'][481][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[481][0])
    parameters['W1'][481][1] = parameters['W1'][481][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[481][0])
    parameters['W1'][481][2] = parameters['W1'][481][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[481][0])
    parameters['W1'][481][3] = parameters['W1'][481][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[481][0])

    parameters['W1'][482][0] = parameters['W1'][482][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[482][0])
    parameters['W1'][482][1] = parameters['W1'][482][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[482][0])
    parameters['W1'][482][2] = parameters['W1'][482][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[482][0])
    parameters['W1'][482][3] = parameters['W1'][482][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[482][0])

    parameters['W1'][483][0] = parameters['W1'][483][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[483][0])
    parameters['W1'][483][1] = parameters['W1'][483][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[483][0])
    parameters['W1'][483][2] = parameters['W1'][483][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[483][0])
    parameters['W1'][483][3] = parameters['W1'][483][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[483][0])

    parameters['W1'][484][0] = parameters['W1'][484][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[484][0])
    parameters['W1'][484][1] = parameters['W1'][484][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[484][0])
    parameters['W1'][484][2] = parameters['W1'][484][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[484][0])
    parameters['W1'][484][3] = parameters['W1'][484][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[484][0])

    parameters['W1'][485][0] = parameters['W1'][485][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[485][0])
    parameters['W1'][485][1] = parameters['W1'][485][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[485][0])
    parameters['W1'][485][2] = parameters['W1'][485][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[485][0])
    parameters['W1'][485][3] = parameters['W1'][485][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[485][0])

    parameters['W1'][486][0] = parameters['W1'][486][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[486][0])
    parameters['W1'][486][1] = parameters['W1'][486][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[486][0])
    parameters['W1'][486][2] = parameters['W1'][486][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[486][0])
    parameters['W1'][486][3] = parameters['W1'][486][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[486][0])

    parameters['W1'][487][0] = parameters['W1'][487][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[487][0])
    parameters['W1'][487][1] = parameters['W1'][487][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[487][0])
    parameters['W1'][487][2] = parameters['W1'][487][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[487][0])
    parameters['W1'][487][3] = parameters['W1'][487][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[487][0])

    parameters['W1'][488][0] = parameters['W1'][488][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[488][0])
    parameters['W1'][488][1] = parameters['W1'][488][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[488][0])
    parameters['W1'][488][2] = parameters['W1'][488][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[488][0])
    parameters['W1'][488][3] = parameters['W1'][488][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[488][0])

    parameters['W1'][489][0] = parameters['W1'][489][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[489][0])
    parameters['W1'][489][1] = parameters['W1'][489][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[489][0])
    parameters['W1'][489][2] = parameters['W1'][489][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[489][0])
    parameters['W1'][489][3] = parameters['W1'][489][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[489][0])

    parameters['W1'][490][0] = parameters['W1'][490][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[490][0])
    parameters['W1'][490][1] = parameters['W1'][490][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[490][0])
    parameters['W1'][490][2] = parameters['W1'][490][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[490][0])
    parameters['W1'][490][3] = parameters['W1'][490][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[490][0])

    parameters['W1'][491][0] = parameters['W1'][491][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[491][0])
    parameters['W1'][491][1] = parameters['W1'][491][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[491][0])
    parameters['W1'][491][2] = parameters['W1'][491][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[491][0])
    parameters['W1'][491][3] = parameters['W1'][491][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[491][0])

    parameters['W1'][492][0] = parameters['W1'][492][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[492][0])
    parameters['W1'][492][1] = parameters['W1'][492][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[492][0])
    parameters['W1'][492][2] = parameters['W1'][492][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[492][0])
    parameters['W1'][492][3] = parameters['W1'][492][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[492][0])

    parameters['W1'][493][0] = parameters['W1'][493][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[493][0])
    parameters['W1'][493][1] = parameters['W1'][493][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[493][0])
    parameters['W1'][493][2] = parameters['W1'][493][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[493][0])
    parameters['W1'][493][3] = parameters['W1'][493][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[493][0])

    parameters['W1'][494][0] = parameters['W1'][494][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[494][0])
    parameters['W1'][494][1] = parameters['W1'][494][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[494][0])
    parameters['W1'][494][2] = parameters['W1'][494][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[494][0])
    parameters['W1'][494][3] = parameters['W1'][494][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[494][0])

    parameters['W1'][495][0] = parameters['W1'][495][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[495][0])
    parameters['W1'][495][1] = parameters['W1'][495][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[495][0])
    parameters['W1'][495][2] = parameters['W1'][495][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[495][0])
    parameters['W1'][495][3] = parameters['W1'][495][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[495][0])

    parameters['W1'][496][0] = parameters['W1'][496][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[496][0])
    parameters['W1'][496][1] = parameters['W1'][496][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[496][0])
    parameters['W1'][496][2] = parameters['W1'][496][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[496][0])
    parameters['W1'][496][3] = parameters['W1'][496][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[496][0])

    parameters['W1'][497][0] = parameters['W1'][497][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[497][0])
    parameters['W1'][497][1] = parameters['W1'][497][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[497][0])
    parameters['W1'][497][2] = parameters['W1'][497][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[497][0])
    parameters['W1'][497][3] = parameters['W1'][497][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[497][0])

    parameters['W1'][498][0] = parameters['W1'][498][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[498][0])
    parameters['W1'][498][1] = parameters['W1'][498][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[498][0])
    parameters['W1'][498][2] = parameters['W1'][498][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[498][0])
    parameters['W1'][498][3] = parameters['W1'][498][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[498][0])

    parameters['W1'][499][0] = parameters['W1'][499][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[499][0])
    parameters['W1'][499][1] = parameters['W1'][499][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[499][0])
    parameters['W1'][499][2] = parameters['W1'][499][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[499][0])
    parameters['W1'][499][3] = parameters['W1'][499][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[499][0])

    parameters['W1'][500][0] = parameters['W1'][500][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[500][0])
    parameters['W1'][500][1] = parameters['W1'][500][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[500][0])
    parameters['W1'][500][2] = parameters['W1'][500][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[500][0])
    parameters['W1'][500][3] = parameters['W1'][500][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[500][0])

    parameters['W1'][501][0] = parameters['W1'][501][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[501][0])
    parameters['W1'][501][1] = parameters['W1'][501][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[501][0])
    parameters['W1'][501][2] = parameters['W1'][501][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[501][0])
    parameters['W1'][501][3] = parameters['W1'][501][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[501][0])

    parameters['W1'][502][0] = parameters['W1'][502][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[502][0])
    parameters['W1'][502][1] = parameters['W1'][502][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[502][0])
    parameters['W1'][502][2] = parameters['W1'][502][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[502][0])
    parameters['W1'][502][3] = parameters['W1'][502][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[502][0])

    parameters['W1'][503][0] = parameters['W1'][503][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[503][0])
    parameters['W1'][503][1] = parameters['W1'][503][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[503][0])
    parameters['W1'][503][2] = parameters['W1'][503][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[503][0])
    parameters['W1'][503][3] = parameters['W1'][503][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[503][0])

    parameters['W1'][504][0] = parameters['W1'][504][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[504][0])
    parameters['W1'][504][1] = parameters['W1'][504][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[504][0])
    parameters['W1'][504][2] = parameters['W1'][504][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[504][0])
    parameters['W1'][504][3] = parameters['W1'][504][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[504][0])

    parameters['W1'][505][0] = parameters['W1'][505][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[505][0])
    parameters['W1'][505][1] = parameters['W1'][505][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[505][0])
    parameters['W1'][505][2] = parameters['W1'][505][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[505][0])
    parameters['W1'][505][3] = parameters['W1'][505][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[505][0])

    parameters['W1'][506][0] = parameters['W1'][506][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[506][0])
    parameters['W1'][506][1] = parameters['W1'][506][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[506][0])
    parameters['W1'][506][2] = parameters['W1'][506][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[506][0])
    parameters['W1'][506][3] = parameters['W1'][506][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[506][0])

    parameters['W1'][507][0] = parameters['W1'][507][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[507][0])
    parameters['W1'][507][1] = parameters['W1'][507][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[507][0])
    parameters['W1'][507][2] = parameters['W1'][507][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[507][0])
    parameters['W1'][507][3] = parameters['W1'][507][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[507][0])

    parameters['W1'][508][0] = parameters['W1'][508][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[508][0])
    parameters['W1'][508][1] = parameters['W1'][508][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[508][0])
    parameters['W1'][508][2] = parameters['W1'][508][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[508][0])
    parameters['W1'][508][3] = parameters['W1'][508][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[508][0])

    parameters['W1'][509][0] = parameters['W1'][509][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[509][0])
    parameters['W1'][509][1] = parameters['W1'][509][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[509][0])
    parameters['W1'][509][2] = parameters['W1'][509][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[509][0])
    parameters['W1'][509][3] = parameters['W1'][509][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[509][0])

    parameters['W1'][510][0] = parameters['W1'][510][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[510][0])
    parameters['W1'][510][1] = parameters['W1'][510][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[510][0])
    parameters['W1'][510][2] = parameters['W1'][510][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[510][0])
    parameters['W1'][510][3] = parameters['W1'][510][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[510][0])

    parameters['W1'][511][0] = parameters['W1'][511][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[511][0])
    parameters['W1'][511][1] = parameters['W1'][511][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[511][0])
    parameters['W1'][511][2] = parameters['W1'][511][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[511][0])
    parameters['W1'][511][3] = parameters['W1'][511][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[511][0])

    parameters['W1'][512][0] = parameters['W1'][512][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[512][0])
    parameters['W1'][512][1] = parameters['W1'][512][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[512][0])
    parameters['W1'][512][2] = parameters['W1'][512][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[512][0])
    parameters['W1'][512][3] = parameters['W1'][512][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[512][0])

    parameters['W1'][513][0] = parameters['W1'][513][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[513][0])
    parameters['W1'][513][1] = parameters['W1'][513][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[513][0])
    parameters['W1'][513][2] = parameters['W1'][513][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[513][0])
    parameters['W1'][513][3] = parameters['W1'][513][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[513][0])

    parameters['W1'][514][0] = parameters['W1'][514][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[514][0])
    parameters['W1'][514][1] = parameters['W1'][514][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[514][0])
    parameters['W1'][514][2] = parameters['W1'][514][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[514][0])
    parameters['W1'][514][3] = parameters['W1'][514][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[514][0])

    parameters['W1'][515][0] = parameters['W1'][515][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[515][0])
    parameters['W1'][515][1] = parameters['W1'][515][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[515][0])
    parameters['W1'][515][2] = parameters['W1'][515][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[515][0])
    parameters['W1'][515][3] = parameters['W1'][515][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[515][0])

    parameters['W1'][516][0] = parameters['W1'][516][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[516][0])
    parameters['W1'][516][1] = parameters['W1'][516][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[516][0])
    parameters['W1'][516][2] = parameters['W1'][516][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[516][0])
    parameters['W1'][516][3] = parameters['W1'][516][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[516][0])

    parameters['W1'][517][0] = parameters['W1'][517][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[517][0])
    parameters['W1'][517][1] = parameters['W1'][517][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[517][0])
    parameters['W1'][517][2] = parameters['W1'][517][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[517][0])
    parameters['W1'][517][3] = parameters['W1'][517][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[517][0])

    parameters['W1'][518][0] = parameters['W1'][518][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[518][0])
    parameters['W1'][518][1] = parameters['W1'][518][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[518][0])
    parameters['W1'][518][2] = parameters['W1'][518][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[518][0])
    parameters['W1'][518][3] = parameters['W1'][518][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[518][0])

    parameters['W1'][519][0] = parameters['W1'][519][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[519][0])
    parameters['W1'][519][1] = parameters['W1'][519][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[519][0])
    parameters['W1'][519][2] = parameters['W1'][519][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[519][0])
    parameters['W1'][519][3] = parameters['W1'][519][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[519][0])

    parameters['W1'][520][0] = parameters['W1'][520][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[520][0])
    parameters['W1'][520][1] = parameters['W1'][520][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[520][0])
    parameters['W1'][520][2] = parameters['W1'][520][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[520][0])
    parameters['W1'][520][3] = parameters['W1'][520][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[520][0])

    parameters['W1'][521][0] = parameters['W1'][521][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[521][0])
    parameters['W1'][521][1] = parameters['W1'][521][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[521][0])
    parameters['W1'][521][2] = parameters['W1'][521][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[521][0])
    parameters['W1'][521][3] = parameters['W1'][521][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[521][0])

    parameters['W1'][522][0] = parameters['W1'][522][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[522][0])
    parameters['W1'][522][1] = parameters['W1'][522][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[522][0])
    parameters['W1'][522][2] = parameters['W1'][522][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[522][0])
    parameters['W1'][522][3] = parameters['W1'][522][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[522][0])

    parameters['W1'][523][0] = parameters['W1'][523][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[523][0])
    parameters['W1'][523][1] = parameters['W1'][523][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[523][0])
    parameters['W1'][523][2] = parameters['W1'][523][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[523][0])
    parameters['W1'][523][3] = parameters['W1'][523][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[523][0])

    parameters['W1'][524][0] = parameters['W1'][524][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[524][0])
    parameters['W1'][524][1] = parameters['W1'][524][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[524][0])
    parameters['W1'][524][2] = parameters['W1'][524][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[524][0])
    parameters['W1'][524][3] = parameters['W1'][524][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[524][0])

    parameters['W1'][525][0] = parameters['W1'][525][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[525][0])
    parameters['W1'][525][1] = parameters['W1'][525][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[525][0])
    parameters['W1'][525][2] = parameters['W1'][525][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[525][0])
    parameters['W1'][525][3] = parameters['W1'][525][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[525][0])

    parameters['W1'][526][0] = parameters['W1'][526][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[526][0])
    parameters['W1'][526][1] = parameters['W1'][526][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[526][0])
    parameters['W1'][526][2] = parameters['W1'][526][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[526][0])
    parameters['W1'][526][3] = parameters['W1'][526][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[526][0])

    parameters['W1'][527][0] = parameters['W1'][527][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[527][0])
    parameters['W1'][527][1] = parameters['W1'][527][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[527][0])
    parameters['W1'][527][2] = parameters['W1'][527][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[527][0])
    parameters['W1'][527][3] = parameters['W1'][527][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[527][0])

    parameters['W1'][528][0] = parameters['W1'][528][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[528][0])
    parameters['W1'][528][1] = parameters['W1'][528][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[528][0])
    parameters['W1'][528][2] = parameters['W1'][528][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[528][0])
    parameters['W1'][528][3] = parameters['W1'][528][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[528][0])

    parameters['W1'][529][0] = parameters['W1'][529][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[529][0])
    parameters['W1'][529][1] = parameters['W1'][529][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[529][0])
    parameters['W1'][529][2] = parameters['W1'][529][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[529][0])
    parameters['W1'][529][3] = parameters['W1'][529][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[529][0])

    parameters['W1'][530][0] = parameters['W1'][530][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[530][0])
    parameters['W1'][530][1] = parameters['W1'][530][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[530][0])
    parameters['W1'][530][2] = parameters['W1'][530][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[530][0])
    parameters['W1'][530][3] = parameters['W1'][530][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[530][0])

    parameters['W1'][531][0] = parameters['W1'][531][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[531][0])
    parameters['W1'][531][1] = parameters['W1'][531][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[531][0])
    parameters['W1'][531][2] = parameters['W1'][531][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[531][0])
    parameters['W1'][531][3] = parameters['W1'][531][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[531][0])

    parameters['W1'][532][0] = parameters['W1'][532][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[532][0])
    parameters['W1'][532][1] = parameters['W1'][532][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[532][0])
    parameters['W1'][532][2] = parameters['W1'][532][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[532][0])
    parameters['W1'][532][3] = parameters['W1'][532][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[532][0])

    parameters['W1'][533][0] = parameters['W1'][533][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[533][0])
    parameters['W1'][533][1] = parameters['W1'][533][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[533][0])
    parameters['W1'][533][2] = parameters['W1'][533][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[533][0])
    parameters['W1'][533][3] = parameters['W1'][533][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[533][0])

    parameters['W1'][534][0] = parameters['W1'][534][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[534][0])
    parameters['W1'][534][1] = parameters['W1'][534][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[534][0])
    parameters['W1'][534][2] = parameters['W1'][534][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[534][0])
    parameters['W1'][534][3] = parameters['W1'][534][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[534][0])

    parameters['W1'][535][0] = parameters['W1'][535][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[535][0])
    parameters['W1'][535][1] = parameters['W1'][535][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[535][0])
    parameters['W1'][535][2] = parameters['W1'][535][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[535][0])
    parameters['W1'][535][3] = parameters['W1'][535][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[535][0])

    parameters['W1'][536][0] = parameters['W1'][536][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[536][0])
    parameters['W1'][536][1] = parameters['W1'][536][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[536][0])
    parameters['W1'][536][2] = parameters['W1'][536][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[536][0])
    parameters['W1'][536][3] = parameters['W1'][536][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[536][0])

    parameters['W1'][537][0] = parameters['W1'][537][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[537][0])
    parameters['W1'][537][1] = parameters['W1'][537][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[537][0])
    parameters['W1'][537][2] = parameters['W1'][537][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[537][0])
    parameters['W1'][537][3] = parameters['W1'][537][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[537][0])

    parameters['W1'][538][0] = parameters['W1'][538][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[538][0])
    parameters['W1'][538][1] = parameters['W1'][538][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[538][0])
    parameters['W1'][538][2] = parameters['W1'][538][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[538][0])
    parameters['W1'][538][3] = parameters['W1'][538][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[538][0])

    parameters['W1'][539][0] = parameters['W1'][539][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[539][0])
    parameters['W1'][539][1] = parameters['W1'][539][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[539][0])
    parameters['W1'][539][2] = parameters['W1'][539][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[539][0])
    parameters['W1'][539][3] = parameters['W1'][539][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[539][0])

    parameters['W1'][540][0] = parameters['W1'][540][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[540][0])
    parameters['W1'][540][1] = parameters['W1'][540][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[540][0])
    parameters['W1'][540][2] = parameters['W1'][540][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[540][0])
    parameters['W1'][540][3] = parameters['W1'][540][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[540][0])

    parameters['W1'][541][0] = parameters['W1'][541][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[541][0])
    parameters['W1'][541][1] = parameters['W1'][541][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[541][0])
    parameters['W1'][541][2] = parameters['W1'][541][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[541][0])
    parameters['W1'][541][3] = parameters['W1'][541][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[541][0])

    parameters['W1'][542][0] = parameters['W1'][542][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[542][0])
    parameters['W1'][542][1] = parameters['W1'][542][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[542][0])
    parameters['W1'][542][2] = parameters['W1'][542][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[542][0])
    parameters['W1'][542][3] = parameters['W1'][542][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[542][0])

    parameters['W1'][543][0] = parameters['W1'][543][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[543][0])
    parameters['W1'][543][1] = parameters['W1'][543][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[543][0])
    parameters['W1'][543][2] = parameters['W1'][543][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[543][0])
    parameters['W1'][543][3] = parameters['W1'][543][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[543][0])

    parameters['W1'][544][0] = parameters['W1'][544][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[544][0])
    parameters['W1'][544][1] = parameters['W1'][544][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[544][0])
    parameters['W1'][544][2] = parameters['W1'][544][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[544][0])
    parameters['W1'][544][3] = parameters['W1'][544][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[544][0])

    parameters['W1'][545][0] = parameters['W1'][545][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[545][0])
    parameters['W1'][545][1] = parameters['W1'][545][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[545][0])
    parameters['W1'][545][2] = parameters['W1'][545][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[545][0])
    parameters['W1'][545][3] = parameters['W1'][545][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[545][0])

    parameters['W1'][546][0] = parameters['W1'][546][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[546][0])
    parameters['W1'][546][1] = parameters['W1'][546][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[546][0])
    parameters['W1'][546][2] = parameters['W1'][546][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[546][0])
    parameters['W1'][546][3] = parameters['W1'][546][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[546][0])

    parameters['W1'][547][0] = parameters['W1'][547][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[547][0])
    parameters['W1'][547][1] = parameters['W1'][547][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[547][0])
    parameters['W1'][547][2] = parameters['W1'][547][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[547][0])
    parameters['W1'][547][3] = parameters['W1'][547][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[547][0])

    parameters['W1'][548][0] = parameters['W1'][548][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[548][0])
    parameters['W1'][548][1] = parameters['W1'][548][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[548][0])
    parameters['W1'][548][2] = parameters['W1'][548][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[548][0])
    parameters['W1'][548][3] = parameters['W1'][548][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[548][0])

    parameters['W1'][549][0] = parameters['W1'][549][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[549][0])
    parameters['W1'][549][1] = parameters['W1'][549][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[549][0])
    parameters['W1'][549][2] = parameters['W1'][549][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[549][0])
    parameters['W1'][549][3] = parameters['W1'][549][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[549][0])

    parameters['W1'][550][0] = parameters['W1'][550][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[550][0])
    parameters['W1'][550][1] = parameters['W1'][550][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[550][0])
    parameters['W1'][550][2] = parameters['W1'][550][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[550][0])
    parameters['W1'][550][3] = parameters['W1'][550][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[550][0])

    parameters['W1'][551][0] = parameters['W1'][551][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[551][0])
    parameters['W1'][551][1] = parameters['W1'][551][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[551][0])
    parameters['W1'][551][2] = parameters['W1'][551][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[551][0])
    parameters['W1'][551][3] = parameters['W1'][551][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[551][0])

    parameters['W1'][552][0] = parameters['W1'][552][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[552][0])
    parameters['W1'][552][1] = parameters['W1'][552][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[552][0])
    parameters['W1'][552][2] = parameters['W1'][552][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[552][0])
    parameters['W1'][552][3] = parameters['W1'][552][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[552][0])

    parameters['W1'][553][0] = parameters['W1'][553][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[553][0])
    parameters['W1'][553][1] = parameters['W1'][553][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[553][0])
    parameters['W1'][553][2] = parameters['W1'][553][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[553][0])
    parameters['W1'][553][3] = parameters['W1'][553][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[553][0])

    parameters['W1'][554][0] = parameters['W1'][554][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[554][0])
    parameters['W1'][554][1] = parameters['W1'][554][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[554][0])
    parameters['W1'][554][2] = parameters['W1'][554][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[554][0])
    parameters['W1'][554][3] = parameters['W1'][554][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[554][0])

    parameters['W1'][555][0] = parameters['W1'][555][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[555][0])
    parameters['W1'][555][1] = parameters['W1'][555][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[555][0])
    parameters['W1'][555][2] = parameters['W1'][555][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[555][0])
    parameters['W1'][555][3] = parameters['W1'][555][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[555][0])

    parameters['W1'][556][0] = parameters['W1'][556][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[556][0])
    parameters['W1'][556][1] = parameters['W1'][556][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[556][0])
    parameters['W1'][556][2] = parameters['W1'][556][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[556][0])
    parameters['W1'][556][3] = parameters['W1'][556][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[556][0])

    parameters['W1'][557][0] = parameters['W1'][557][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[557][0])
    parameters['W1'][557][1] = parameters['W1'][557][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[557][0])
    parameters['W1'][557][2] = parameters['W1'][557][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[557][0])
    parameters['W1'][557][3] = parameters['W1'][557][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[557][0])

    parameters['W1'][558][0] = parameters['W1'][558][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[558][0])
    parameters['W1'][558][1] = parameters['W1'][558][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[558][0])
    parameters['W1'][558][2] = parameters['W1'][558][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[558][0])
    parameters['W1'][558][3] = parameters['W1'][558][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[558][0])

    parameters['W1'][559][0] = parameters['W1'][559][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[559][0])
    parameters['W1'][559][1] = parameters['W1'][559][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[559][0])
    parameters['W1'][559][2] = parameters['W1'][559][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[559][0])
    parameters['W1'][559][3] = parameters['W1'][559][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[559][0])

    parameters['W1'][560][0] = parameters['W1'][560][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[560][0])
    parameters['W1'][560][1] = parameters['W1'][560][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[560][0])
    parameters['W1'][560][2] = parameters['W1'][560][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[560][0])
    parameters['W1'][560][3] = parameters['W1'][560][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[560][0])

    parameters['W1'][561][0] = parameters['W1'][561][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[561][0])
    parameters['W1'][561][1] = parameters['W1'][561][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[561][0])
    parameters['W1'][561][2] = parameters['W1'][561][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[561][0])
    parameters['W1'][561][3] = parameters['W1'][561][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[561][0])

    parameters['W1'][562][0] = parameters['W1'][562][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[562][0])
    parameters['W1'][562][1] = parameters['W1'][562][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[562][0])
    parameters['W1'][562][2] = parameters['W1'][562][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[562][0])
    parameters['W1'][562][3] = parameters['W1'][562][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[562][0])

    parameters['W1'][563][0] = parameters['W1'][563][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[563][0])
    parameters['W1'][563][1] = parameters['W1'][563][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[563][0])
    parameters['W1'][563][2] = parameters['W1'][563][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[563][0])
    parameters['W1'][563][3] = parameters['W1'][563][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[563][0])

    parameters['W1'][564][0] = parameters['W1'][564][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[564][0])
    parameters['W1'][564][1] = parameters['W1'][564][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[564][0])
    parameters['W1'][564][2] = parameters['W1'][564][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[564][0])
    parameters['W1'][564][3] = parameters['W1'][564][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[564][0])

    parameters['W1'][565][0] = parameters['W1'][565][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[565][0])
    parameters['W1'][565][1] = parameters['W1'][565][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[565][0])
    parameters['W1'][565][2] = parameters['W1'][565][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[565][0])
    parameters['W1'][565][3] = parameters['W1'][565][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[565][0])

    parameters['W1'][566][0] = parameters['W1'][566][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[566][0])
    parameters['W1'][566][1] = parameters['W1'][566][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[566][0])
    parameters['W1'][566][2] = parameters['W1'][566][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[566][0])
    parameters['W1'][566][3] = parameters['W1'][566][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[566][0])

    parameters['W1'][567][0] = parameters['W1'][567][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[567][0])
    parameters['W1'][567][1] = parameters['W1'][567][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[567][0])
    parameters['W1'][567][2] = parameters['W1'][567][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[567][0])
    parameters['W1'][567][3] = parameters['W1'][567][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[567][0])

    parameters['W1'][568][0] = parameters['W1'][568][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[568][0])
    parameters['W1'][568][1] = parameters['W1'][568][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[568][0])
    parameters['W1'][568][2] = parameters['W1'][568][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[568][0])
    parameters['W1'][568][3] = parameters['W1'][568][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[568][0])

    parameters['W1'][569][0] = parameters['W1'][569][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[569][0])
    parameters['W1'][569][1] = parameters['W1'][569][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[569][0])
    parameters['W1'][569][2] = parameters['W1'][569][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[569][0])
    parameters['W1'][569][3] = parameters['W1'][569][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[569][0])

    parameters['W1'][570][0] = parameters['W1'][570][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[570][0])
    parameters['W1'][570][1] = parameters['W1'][570][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[570][0])
    parameters['W1'][570][2] = parameters['W1'][570][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[570][0])
    parameters['W1'][570][3] = parameters['W1'][570][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[570][0])

    parameters['W1'][571][0] = parameters['W1'][571][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[571][0])
    parameters['W1'][571][1] = parameters['W1'][571][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[571][0])
    parameters['W1'][571][2] = parameters['W1'][571][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[571][0])
    parameters['W1'][571][3] = parameters['W1'][571][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[571][0])

    parameters['W1'][572][0] = parameters['W1'][572][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[572][0])
    parameters['W1'][572][1] = parameters['W1'][572][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[572][0])
    parameters['W1'][572][2] = parameters['W1'][572][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[572][0])
    parameters['W1'][572][3] = parameters['W1'][572][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[572][0])

    parameters['W1'][573][0] = parameters['W1'][573][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[573][0])
    parameters['W1'][573][1] = parameters['W1'][573][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[573][0])
    parameters['W1'][573][2] = parameters['W1'][573][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[573][0])
    parameters['W1'][573][3] = parameters['W1'][573][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[573][0])

    parameters['W1'][574][0] = parameters['W1'][574][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[574][0])
    parameters['W1'][574][1] = parameters['W1'][574][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[574][0])
    parameters['W1'][574][2] = parameters['W1'][574][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[574][0])
    parameters['W1'][574][3] = parameters['W1'][574][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[574][0])

    parameters['W1'][575][0] = parameters['W1'][575][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[575][0])
    parameters['W1'][575][1] = parameters['W1'][575][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[575][0])
    parameters['W1'][575][2] = parameters['W1'][575][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[575][0])
    parameters['W1'][575][3] = parameters['W1'][575][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[575][0])

    parameters['W1'][576][0] = parameters['W1'][576][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[576][0])
    parameters['W1'][576][1] = parameters['W1'][576][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[576][0])
    parameters['W1'][576][2] = parameters['W1'][576][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[576][0])
    parameters['W1'][576][3] = parameters['W1'][576][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[576][0])

    parameters['W1'][577][0] = parameters['W1'][577][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[577][0])
    parameters['W1'][577][1] = parameters['W1'][577][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[577][0])
    parameters['W1'][577][2] = parameters['W1'][577][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[577][0])
    parameters['W1'][577][3] = parameters['W1'][577][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[577][0])

    parameters['W1'][578][0] = parameters['W1'][578][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[578][0])
    parameters['W1'][578][1] = parameters['W1'][578][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[578][0])
    parameters['W1'][578][2] = parameters['W1'][578][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[578][0])
    parameters['W1'][578][3] = parameters['W1'][578][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[578][0])

    parameters['W1'][579][0] = parameters['W1'][579][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[579][0])
    parameters['W1'][579][1] = parameters['W1'][579][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[579][0])
    parameters['W1'][579][2] = parameters['W1'][579][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[579][0])
    parameters['W1'][579][3] = parameters['W1'][579][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[579][0])

    parameters['W1'][580][0] = parameters['W1'][580][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[580][0])
    parameters['W1'][580][1] = parameters['W1'][580][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[580][0])
    parameters['W1'][580][2] = parameters['W1'][580][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[580][0])
    parameters['W1'][580][3] = parameters['W1'][580][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[580][0])

    parameters['W1'][581][0] = parameters['W1'][581][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[581][0])
    parameters['W1'][581][1] = parameters['W1'][581][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[581][0])
    parameters['W1'][581][2] = parameters['W1'][581][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[581][0])
    parameters['W1'][581][3] = parameters['W1'][581][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[581][0])

    parameters['W1'][582][0] = parameters['W1'][582][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[582][0])
    parameters['W1'][582][1] = parameters['W1'][582][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[582][0])
    parameters['W1'][582][2] = parameters['W1'][582][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[582][0])
    parameters['W1'][582][3] = parameters['W1'][582][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[582][0])

    parameters['W1'][583][0] = parameters['W1'][583][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[583][0])
    parameters['W1'][583][1] = parameters['W1'][583][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[583][0])
    parameters['W1'][583][2] = parameters['W1'][583][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[583][0])
    parameters['W1'][583][3] = parameters['W1'][583][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[583][0])

    parameters['W1'][584][0] = parameters['W1'][584][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[584][0])
    parameters['W1'][584][1] = parameters['W1'][584][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[584][0])
    parameters['W1'][584][2] = parameters['W1'][584][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[584][0])
    parameters['W1'][584][3] = parameters['W1'][584][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[584][0])

    parameters['W1'][585][0] = parameters['W1'][585][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[585][0])
    parameters['W1'][585][1] = parameters['W1'][585][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[585][0])
    parameters['W1'][585][2] = parameters['W1'][585][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[585][0])
    parameters['W1'][585][3] = parameters['W1'][585][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[585][0])

    parameters['W1'][586][0] = parameters['W1'][586][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[586][0])
    parameters['W1'][586][1] = parameters['W1'][586][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[586][0])
    parameters['W1'][586][2] = parameters['W1'][586][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[586][0])
    parameters['W1'][586][3] = parameters['W1'][586][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[586][0])

    parameters['W1'][587][0] = parameters['W1'][587][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[587][0])
    parameters['W1'][587][1] = parameters['W1'][587][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[587][0])
    parameters['W1'][587][2] = parameters['W1'][587][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[587][0])
    parameters['W1'][587][3] = parameters['W1'][587][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[587][0])

    parameters['W1'][588][0] = parameters['W1'][588][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[588][0])
    parameters['W1'][588][1] = parameters['W1'][588][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[588][0])
    parameters['W1'][588][2] = parameters['W1'][588][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[588][0])
    parameters['W1'][588][3] = parameters['W1'][588][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[588][0])

    parameters['W1'][589][0] = parameters['W1'][589][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[589][0])
    parameters['W1'][589][1] = parameters['W1'][589][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[589][0])
    parameters['W1'][589][2] = parameters['W1'][589][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[589][0])
    parameters['W1'][589][3] = parameters['W1'][589][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[589][0])

    parameters['W1'][590][0] = parameters['W1'][590][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[590][0])
    parameters['W1'][590][1] = parameters['W1'][590][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[590][0])
    parameters['W1'][590][2] = parameters['W1'][590][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[590][0])
    parameters['W1'][590][3] = parameters['W1'][590][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[590][0])

    parameters['W1'][591][0] = parameters['W1'][591][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[591][0])
    parameters['W1'][591][1] = parameters['W1'][591][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[591][0])
    parameters['W1'][591][2] = parameters['W1'][591][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[591][0])
    parameters['W1'][591][3] = parameters['W1'][591][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[591][0])

    parameters['W1'][592][0] = parameters['W1'][592][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[592][0])
    parameters['W1'][592][1] = parameters['W1'][592][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[592][0])
    parameters['W1'][592][2] = parameters['W1'][592][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[592][0])
    parameters['W1'][592][3] = parameters['W1'][592][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[592][0])

    parameters['W1'][593][0] = parameters['W1'][593][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[593][0])
    parameters['W1'][593][1] = parameters['W1'][593][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[593][0])
    parameters['W1'][593][2] = parameters['W1'][593][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[593][0])
    parameters['W1'][593][3] = parameters['W1'][593][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[593][0])

    parameters['W1'][594][0] = parameters['W1'][594][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[594][0])
    parameters['W1'][594][1] = parameters['W1'][594][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[594][0])
    parameters['W1'][594][2] = parameters['W1'][594][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[594][0])
    parameters['W1'][594][3] = parameters['W1'][594][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[594][0])

    parameters['W1'][595][0] = parameters['W1'][595][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[595][0])
    parameters['W1'][595][1] = parameters['W1'][595][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[595][0])
    parameters['W1'][595][2] = parameters['W1'][595][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[595][0])
    parameters['W1'][595][3] = parameters['W1'][595][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[595][0])

    parameters['W1'][596][0] = parameters['W1'][596][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[596][0])
    parameters['W1'][596][1] = parameters['W1'][596][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[596][0])
    parameters['W1'][596][2] = parameters['W1'][596][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[596][0])
    parameters['W1'][596][3] = parameters['W1'][596][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[596][0])

    parameters['W1'][597][0] = parameters['W1'][597][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[597][0])
    parameters['W1'][597][1] = parameters['W1'][597][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[597][0])
    parameters['W1'][597][2] = parameters['W1'][597][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[597][0])
    parameters['W1'][597][3] = parameters['W1'][597][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[597][0])

    parameters['W1'][598][0] = parameters['W1'][598][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[598][0])
    parameters['W1'][598][1] = parameters['W1'][598][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[598][0])
    parameters['W1'][598][2] = parameters['W1'][598][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[598][0])
    parameters['W1'][598][3] = parameters['W1'][598][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[598][0])

    parameters['W1'][599][0] = parameters['W1'][599][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[599][0])
    parameters['W1'][599][1] = parameters['W1'][599][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[599][0])
    parameters['W1'][599][2] = parameters['W1'][599][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[599][0])
    parameters['W1'][599][3] = parameters['W1'][599][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[599][0])

    parameters['W1'][600][0] = parameters['W1'][600][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[600][0])
    parameters['W1'][600][1] = parameters['W1'][600][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[600][0])
    parameters['W1'][600][2] = parameters['W1'][600][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[600][0])
    parameters['W1'][600][3] = parameters['W1'][600][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[600][0])

    parameters['W1'][601][0] = parameters['W1'][601][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[601][0])
    parameters['W1'][601][1] = parameters['W1'][601][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[601][0])
    parameters['W1'][601][2] = parameters['W1'][601][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[601][0])
    parameters['W1'][601][3] = parameters['W1'][601][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[601][0])

    parameters['W1'][602][0] = parameters['W1'][602][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[602][0])
    parameters['W1'][602][1] = parameters['W1'][602][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[602][0])
    parameters['W1'][602][2] = parameters['W1'][602][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[602][0])
    parameters['W1'][602][3] = parameters['W1'][602][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[602][0])

    parameters['W1'][603][0] = parameters['W1'][603][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[603][0])
    parameters['W1'][603][1] = parameters['W1'][603][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[603][0])
    parameters['W1'][603][2] = parameters['W1'][603][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[603][0])
    parameters['W1'][603][3] = parameters['W1'][603][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[603][0])

    parameters['W1'][604][0] = parameters['W1'][604][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[604][0])
    parameters['W1'][604][1] = parameters['W1'][604][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[604][0])
    parameters['W1'][604][2] = parameters['W1'][604][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[604][0])
    parameters['W1'][604][3] = parameters['W1'][604][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[604][0])

    parameters['W1'][605][0] = parameters['W1'][605][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[605][0])
    parameters['W1'][605][1] = parameters['W1'][605][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[605][0])
    parameters['W1'][605][2] = parameters['W1'][605][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[605][0])
    parameters['W1'][605][3] = parameters['W1'][605][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[605][0])

    parameters['W1'][606][0] = parameters['W1'][606][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[606][0])
    parameters['W1'][606][1] = parameters['W1'][606][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[606][0])
    parameters['W1'][606][2] = parameters['W1'][606][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[606][0])
    parameters['W1'][606][3] = parameters['W1'][606][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[606][0])

    parameters['W1'][607][0] = parameters['W1'][607][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[607][0])
    parameters['W1'][607][1] = parameters['W1'][607][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[607][0])
    parameters['W1'][607][2] = parameters['W1'][607][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[607][0])
    parameters['W1'][607][3] = parameters['W1'][607][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[607][0])

    parameters['W1'][608][0] = parameters['W1'][608][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[608][0])
    parameters['W1'][608][1] = parameters['W1'][608][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[608][0])
    parameters['W1'][608][2] = parameters['W1'][608][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[608][0])
    parameters['W1'][608][3] = parameters['W1'][608][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[608][0])

    parameters['W1'][609][0] = parameters['W1'][609][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[609][0])
    parameters['W1'][609][1] = parameters['W1'][609][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[609][0])
    parameters['W1'][609][2] = parameters['W1'][609][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[609][0])
    parameters['W1'][609][3] = parameters['W1'][609][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[609][0])

    parameters['W1'][610][0] = parameters['W1'][610][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[610][0])
    parameters['W1'][610][1] = parameters['W1'][610][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[610][0])
    parameters['W1'][610][2] = parameters['W1'][610][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[610][0])
    parameters['W1'][610][3] = parameters['W1'][610][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[610][0])

    parameters['W1'][611][0] = parameters['W1'][611][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[611][0])
    parameters['W1'][611][1] = parameters['W1'][611][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[611][0])
    parameters['W1'][611][2] = parameters['W1'][611][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[611][0])
    parameters['W1'][611][3] = parameters['W1'][611][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[611][0])

    parameters['W1'][612][0] = parameters['W1'][612][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[612][0])
    parameters['W1'][612][1] = parameters['W1'][612][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[612][0])
    parameters['W1'][612][2] = parameters['W1'][612][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[612][0])
    parameters['W1'][612][3] = parameters['W1'][612][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[612][0])

    parameters['W1'][613][0] = parameters['W1'][613][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[613][0])
    parameters['W1'][613][1] = parameters['W1'][613][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[613][0])
    parameters['W1'][613][2] = parameters['W1'][613][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[613][0])
    parameters['W1'][613][3] = parameters['W1'][613][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[613][0])

    parameters['W1'][614][0] = parameters['W1'][614][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[614][0])
    parameters['W1'][614][1] = parameters['W1'][614][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[614][0])
    parameters['W1'][614][2] = parameters['W1'][614][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[614][0])
    parameters['W1'][614][3] = parameters['W1'][614][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[614][0])

    parameters['W1'][615][0] = parameters['W1'][615][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[615][0])
    parameters['W1'][615][1] = parameters['W1'][615][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[615][0])
    parameters['W1'][615][2] = parameters['W1'][615][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[615][0])
    parameters['W1'][615][3] = parameters['W1'][615][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[615][0])

    parameters['W1'][616][0] = parameters['W1'][616][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[616][0])
    parameters['W1'][616][1] = parameters['W1'][616][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[616][0])
    parameters['W1'][616][2] = parameters['W1'][616][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[616][0])
    parameters['W1'][616][3] = parameters['W1'][616][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[616][0])

    parameters['W1'][617][0] = parameters['W1'][617][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[617][0])
    parameters['W1'][617][1] = parameters['W1'][617][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[617][0])
    parameters['W1'][617][2] = parameters['W1'][617][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[617][0])
    parameters['W1'][617][3] = parameters['W1'][617][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[617][0])

    parameters['W1'][618][0] = parameters['W1'][618][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[618][0])
    parameters['W1'][618][1] = parameters['W1'][618][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[618][0])
    parameters['W1'][618][2] = parameters['W1'][618][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[618][0])
    parameters['W1'][618][3] = parameters['W1'][618][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[618][0])

    parameters['W1'][619][0] = parameters['W1'][619][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[619][0])
    parameters['W1'][619][1] = parameters['W1'][619][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[619][0])
    parameters['W1'][619][2] = parameters['W1'][619][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[619][0])
    parameters['W1'][619][3] = parameters['W1'][619][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[619][0])

    parameters['W1'][620][0] = parameters['W1'][620][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[620][0])
    parameters['W1'][620][1] = parameters['W1'][620][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[620][0])
    parameters['W1'][620][2] = parameters['W1'][620][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[620][0])
    parameters['W1'][620][3] = parameters['W1'][620][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[620][0])

    parameters['W1'][621][0] = parameters['W1'][621][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[621][0])
    parameters['W1'][621][1] = parameters['W1'][621][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[621][0])
    parameters['W1'][621][2] = parameters['W1'][621][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[621][0])
    parameters['W1'][621][3] = parameters['W1'][621][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[621][0])

    parameters['W1'][622][0] = parameters['W1'][622][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[622][0])
    parameters['W1'][622][1] = parameters['W1'][622][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[622][0])
    parameters['W1'][622][2] = parameters['W1'][622][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[622][0])
    parameters['W1'][622][3] = parameters['W1'][622][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[622][0])

    parameters['W1'][623][0] = parameters['W1'][623][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[623][0])
    parameters['W1'][623][1] = parameters['W1'][623][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[623][0])
    parameters['W1'][623][2] = parameters['W1'][623][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[623][0])
    parameters['W1'][623][3] = parameters['W1'][623][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[623][0])

    parameters['W1'][624][0] = parameters['W1'][624][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[624][0])
    parameters['W1'][624][1] = parameters['W1'][624][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[624][0])
    parameters['W1'][624][2] = parameters['W1'][624][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[624][0])
    parameters['W1'][624][3] = parameters['W1'][624][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[624][0])

    parameters['W1'][625][0] = parameters['W1'][625][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[625][0])
    parameters['W1'][625][1] = parameters['W1'][625][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[625][0])
    parameters['W1'][625][2] = parameters['W1'][625][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[625][0])
    parameters['W1'][625][3] = parameters['W1'][625][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[625][0])

    parameters['W1'][626][0] = parameters['W1'][626][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[626][0])
    parameters['W1'][626][1] = parameters['W1'][626][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[626][0])
    parameters['W1'][626][2] = parameters['W1'][626][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[626][0])
    parameters['W1'][626][3] = parameters['W1'][626][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[626][0])

    parameters['W1'][627][0] = parameters['W1'][627][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[627][0])
    parameters['W1'][627][1] = parameters['W1'][627][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[627][0])
    parameters['W1'][627][2] = parameters['W1'][627][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[627][0])
    parameters['W1'][627][3] = parameters['W1'][627][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[627][0])

    parameters['W1'][628][0] = parameters['W1'][628][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[628][0])
    parameters['W1'][628][1] = parameters['W1'][628][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[628][0])
    parameters['W1'][628][2] = parameters['W1'][628][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[628][0])
    parameters['W1'][628][3] = parameters['W1'][628][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[628][0])

    parameters['W1'][629][0] = parameters['W1'][629][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[629][0])
    parameters['W1'][629][1] = parameters['W1'][629][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[629][0])
    parameters['W1'][629][2] = parameters['W1'][629][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[629][0])
    parameters['W1'][629][3] = parameters['W1'][629][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[629][0])

    parameters['W1'][630][0] = parameters['W1'][630][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[630][0])
    parameters['W1'][630][1] = parameters['W1'][630][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[630][0])
    parameters['W1'][630][2] = parameters['W1'][630][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[630][0])
    parameters['W1'][630][3] = parameters['W1'][630][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[630][0])

    parameters['W1'][631][0] = parameters['W1'][631][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[631][0])
    parameters['W1'][631][1] = parameters['W1'][631][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[631][0])
    parameters['W1'][631][2] = parameters['W1'][631][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[631][0])
    parameters['W1'][631][3] = parameters['W1'][631][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[631][0])

    parameters['W1'][632][0] = parameters['W1'][632][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[632][0])
    parameters['W1'][632][1] = parameters['W1'][632][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[632][0])
    parameters['W1'][632][2] = parameters['W1'][632][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[632][0])
    parameters['W1'][632][3] = parameters['W1'][632][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[632][0])

    parameters['W1'][633][0] = parameters['W1'][633][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[633][0])
    parameters['W1'][633][1] = parameters['W1'][633][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[633][0])
    parameters['W1'][633][2] = parameters['W1'][633][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[633][0])
    parameters['W1'][633][3] = parameters['W1'][633][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[633][0])

    parameters['W1'][634][0] = parameters['W1'][634][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[634][0])
    parameters['W1'][634][1] = parameters['W1'][634][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[634][0])
    parameters['W1'][634][2] = parameters['W1'][634][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[634][0])
    parameters['W1'][634][3] = parameters['W1'][634][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[634][0])

    parameters['W1'][635][0] = parameters['W1'][635][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[635][0])
    parameters['W1'][635][1] = parameters['W1'][635][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[635][0])
    parameters['W1'][635][2] = parameters['W1'][635][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[635][0])
    parameters['W1'][635][3] = parameters['W1'][635][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[635][0])

    parameters['W1'][636][0] = parameters['W1'][636][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[636][0])
    parameters['W1'][636][1] = parameters['W1'][636][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[636][0])
    parameters['W1'][636][2] = parameters['W1'][636][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[636][0])
    parameters['W1'][636][3] = parameters['W1'][636][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[636][0])

    parameters['W1'][637][0] = parameters['W1'][637][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[637][0])
    parameters['W1'][637][1] = parameters['W1'][637][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[637][0])
    parameters['W1'][637][2] = parameters['W1'][637][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[637][0])
    parameters['W1'][637][3] = parameters['W1'][637][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[637][0])

    parameters['W1'][638][0] = parameters['W1'][638][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[638][0])
    parameters['W1'][638][1] = parameters['W1'][638][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[638][0])
    parameters['W1'][638][2] = parameters['W1'][638][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[638][0])
    parameters['W1'][638][3] = parameters['W1'][638][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[638][0])

    parameters['W1'][639][0] = parameters['W1'][639][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[639][0])
    parameters['W1'][639][1] = parameters['W1'][639][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[639][0])
    parameters['W1'][639][2] = parameters['W1'][639][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[639][0])
    parameters['W1'][639][3] = parameters['W1'][639][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[639][0])

    parameters['W1'][640][0] = parameters['W1'][640][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[640][0])
    parameters['W1'][640][1] = parameters['W1'][640][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[640][0])
    parameters['W1'][640][2] = parameters['W1'][640][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[640][0])
    parameters['W1'][640][3] = parameters['W1'][640][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[640][0])

    parameters['W1'][641][0] = parameters['W1'][641][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[641][0])
    parameters['W1'][641][1] = parameters['W1'][641][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[641][0])
    parameters['W1'][641][2] = parameters['W1'][641][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[641][0])
    parameters['W1'][641][3] = parameters['W1'][641][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[641][0])

    parameters['W1'][642][0] = parameters['W1'][642][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[642][0])
    parameters['W1'][642][1] = parameters['W1'][642][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[642][0])
    parameters['W1'][642][2] = parameters['W1'][642][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[642][0])
    parameters['W1'][642][3] = parameters['W1'][642][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[642][0])

    parameters['W1'][643][0] = parameters['W1'][643][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[643][0])
    parameters['W1'][643][1] = parameters['W1'][643][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[643][0])
    parameters['W1'][643][2] = parameters['W1'][643][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[643][0])
    parameters['W1'][643][3] = parameters['W1'][643][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[643][0])

    parameters['W1'][644][0] = parameters['W1'][644][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[644][0])
    parameters['W1'][644][1] = parameters['W1'][644][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[644][0])
    parameters['W1'][644][2] = parameters['W1'][644][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[644][0])
    parameters['W1'][644][3] = parameters['W1'][644][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[644][0])

    parameters['W1'][645][0] = parameters['W1'][645][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[645][0])
    parameters['W1'][645][1] = parameters['W1'][645][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[645][0])
    parameters['W1'][645][2] = parameters['W1'][645][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[645][0])
    parameters['W1'][645][3] = parameters['W1'][645][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[645][0])

    parameters['W1'][646][0] = parameters['W1'][646][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[646][0])
    parameters['W1'][646][1] = parameters['W1'][646][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[646][0])
    parameters['W1'][646][2] = parameters['W1'][646][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[646][0])
    parameters['W1'][646][3] = parameters['W1'][646][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[646][0])

    parameters['W1'][647][0] = parameters['W1'][647][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[647][0])
    parameters['W1'][647][1] = parameters['W1'][647][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[647][0])
    parameters['W1'][647][2] = parameters['W1'][647][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[647][0])
    parameters['W1'][647][3] = parameters['W1'][647][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[647][0])

    parameters['W1'][648][0] = parameters['W1'][648][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[648][0])
    parameters['W1'][648][1] = parameters['W1'][648][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[648][0])
    parameters['W1'][648][2] = parameters['W1'][648][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[648][0])
    parameters['W1'][648][3] = parameters['W1'][648][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[648][0])

    parameters['W1'][649][0] = parameters['W1'][649][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[649][0])
    parameters['W1'][649][1] = parameters['W1'][649][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[649][0])
    parameters['W1'][649][2] = parameters['W1'][649][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[649][0])
    parameters['W1'][649][3] = parameters['W1'][649][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[649][0])

    parameters['W1'][650][0] = parameters['W1'][650][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[650][0])
    parameters['W1'][650][1] = parameters['W1'][650][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[650][0])
    parameters['W1'][650][2] = parameters['W1'][650][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[650][0])
    parameters['W1'][650][3] = parameters['W1'][650][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[650][0])

    parameters['W1'][651][0] = parameters['W1'][651][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[651][0])
    parameters['W1'][651][1] = parameters['W1'][651][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[651][0])
    parameters['W1'][651][2] = parameters['W1'][651][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[651][0])
    parameters['W1'][651][3] = parameters['W1'][651][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[651][0])

    parameters['W1'][652][0] = parameters['W1'][652][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[652][0])
    parameters['W1'][652][1] = parameters['W1'][652][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[652][0])
    parameters['W1'][652][2] = parameters['W1'][652][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[652][0])
    parameters['W1'][652][3] = parameters['W1'][652][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[652][0])

    parameters['W1'][653][0] = parameters['W1'][653][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[653][0])
    parameters['W1'][653][1] = parameters['W1'][653][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[653][0])
    parameters['W1'][653][2] = parameters['W1'][653][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[653][0])
    parameters['W1'][653][3] = parameters['W1'][653][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[653][0])

    parameters['W1'][654][0] = parameters['W1'][654][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[654][0])
    parameters['W1'][654][1] = parameters['W1'][654][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[654][0])
    parameters['W1'][654][2] = parameters['W1'][654][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[654][0])
    parameters['W1'][654][3] = parameters['W1'][654][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[654][0])

    parameters['W1'][655][0] = parameters['W1'][655][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[655][0])
    parameters['W1'][655][1] = parameters['W1'][655][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[655][0])
    parameters['W1'][655][2] = parameters['W1'][655][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[655][0])
    parameters['W1'][655][3] = parameters['W1'][655][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[655][0])

    parameters['W1'][656][0] = parameters['W1'][656][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[656][0])
    parameters['W1'][656][1] = parameters['W1'][656][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[656][0])
    parameters['W1'][656][2] = parameters['W1'][656][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[656][0])
    parameters['W1'][656][3] = parameters['W1'][656][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[656][0])

    parameters['W1'][657][0] = parameters['W1'][657][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[657][0])
    parameters['W1'][657][1] = parameters['W1'][657][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[657][0])
    parameters['W1'][657][2] = parameters['W1'][657][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[657][0])
    parameters['W1'][657][3] = parameters['W1'][657][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[657][0])

    parameters['W1'][658][0] = parameters['W1'][658][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[658][0])
    parameters['W1'][658][1] = parameters['W1'][658][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[658][0])
    parameters['W1'][658][2] = parameters['W1'][658][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[658][0])
    parameters['W1'][658][3] = parameters['W1'][658][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[658][0])

    parameters['W1'][659][0] = parameters['W1'][659][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[659][0])
    parameters['W1'][659][1] = parameters['W1'][659][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[659][0])
    parameters['W1'][659][2] = parameters['W1'][659][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[659][0])
    parameters['W1'][659][3] = parameters['W1'][659][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[659][0])

    parameters['W1'][660][0] = parameters['W1'][660][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[660][0])
    parameters['W1'][660][1] = parameters['W1'][660][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[660][0])
    parameters['W1'][660][2] = parameters['W1'][660][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[660][0])
    parameters['W1'][660][3] = parameters['W1'][660][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[660][0])

    parameters['W1'][661][0] = parameters['W1'][661][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[661][0])
    parameters['W1'][661][1] = parameters['W1'][661][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[661][0])
    parameters['W1'][661][2] = parameters['W1'][661][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[661][0])
    parameters['W1'][661][3] = parameters['W1'][661][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[661][0])

    parameters['W1'][662][0] = parameters['W1'][662][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[662][0])
    parameters['W1'][662][1] = parameters['W1'][662][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[662][0])
    parameters['W1'][662][2] = parameters['W1'][662][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[662][0])
    parameters['W1'][662][3] = parameters['W1'][662][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[662][0])

    parameters['W1'][663][0] = parameters['W1'][663][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[663][0])
    parameters['W1'][663][1] = parameters['W1'][663][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[663][0])
    parameters['W1'][663][2] = parameters['W1'][663][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[663][0])
    parameters['W1'][663][3] = parameters['W1'][663][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[663][0])

    parameters['W1'][664][0] = parameters['W1'][664][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[664][0])
    parameters['W1'][664][1] = parameters['W1'][664][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[664][0])
    parameters['W1'][664][2] = parameters['W1'][664][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[664][0])
    parameters['W1'][664][3] = parameters['W1'][664][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[664][0])

    parameters['W1'][665][0] = parameters['W1'][665][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[665][0])
    parameters['W1'][665][1] = parameters['W1'][665][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[665][0])
    parameters['W1'][665][2] = parameters['W1'][665][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[665][0])
    parameters['W1'][665][3] = parameters['W1'][665][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[665][0])

    parameters['W1'][666][0] = parameters['W1'][666][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[666][0])
    parameters['W1'][666][1] = parameters['W1'][666][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[666][0])
    parameters['W1'][666][2] = parameters['W1'][666][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[666][0])
    parameters['W1'][666][3] = parameters['W1'][666][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[666][0])

    parameters['W1'][667][0] = parameters['W1'][667][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[667][0])
    parameters['W1'][667][1] = parameters['W1'][667][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[667][0])
    parameters['W1'][667][2] = parameters['W1'][667][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[667][0])
    parameters['W1'][667][3] = parameters['W1'][667][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[667][0])

    parameters['W1'][668][0] = parameters['W1'][668][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[668][0])
    parameters['W1'][668][1] = parameters['W1'][668][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[668][0])
    parameters['W1'][668][2] = parameters['W1'][668][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[668][0])
    parameters['W1'][668][3] = parameters['W1'][668][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[668][0])

    parameters['W1'][669][0] = parameters['W1'][669][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[669][0])
    parameters['W1'][669][1] = parameters['W1'][669][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[669][0])
    parameters['W1'][669][2] = parameters['W1'][669][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[669][0])
    parameters['W1'][669][3] = parameters['W1'][669][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[669][0])

    parameters['W1'][670][0] = parameters['W1'][670][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[670][0])
    parameters['W1'][670][1] = parameters['W1'][670][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[670][0])
    parameters['W1'][670][2] = parameters['W1'][670][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[670][0])
    parameters['W1'][670][3] = parameters['W1'][670][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[670][0])

    parameters['W1'][671][0] = parameters['W1'][671][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[671][0])
    parameters['W1'][671][1] = parameters['W1'][671][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[671][0])
    parameters['W1'][671][2] = parameters['W1'][671][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[671][0])
    parameters['W1'][671][3] = parameters['W1'][671][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[671][0])

    parameters['W1'][672][0] = parameters['W1'][672][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[672][0])
    parameters['W1'][672][1] = parameters['W1'][672][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[672][0])
    parameters['W1'][672][2] = parameters['W1'][672][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[672][0])
    parameters['W1'][672][3] = parameters['W1'][672][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[672][0])

    parameters['W1'][673][0] = parameters['W1'][673][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[673][0])
    parameters['W1'][673][1] = parameters['W1'][673][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[673][0])
    parameters['W1'][673][2] = parameters['W1'][673][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[673][0])
    parameters['W1'][673][3] = parameters['W1'][673][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[673][0])

    parameters['W1'][674][0] = parameters['W1'][674][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[674][0])
    parameters['W1'][674][1] = parameters['W1'][674][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[674][0])
    parameters['W1'][674][2] = parameters['W1'][674][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[674][0])
    parameters['W1'][674][3] = parameters['W1'][674][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[674][0])

    parameters['W1'][675][0] = parameters['W1'][675][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[675][0])
    parameters['W1'][675][1] = parameters['W1'][675][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[675][0])
    parameters['W1'][675][2] = parameters['W1'][675][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[675][0])
    parameters['W1'][675][3] = parameters['W1'][675][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[675][0])

    parameters['W1'][676][0] = parameters['W1'][676][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[676][0])
    parameters['W1'][676][1] = parameters['W1'][676][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[676][0])
    parameters['W1'][676][2] = parameters['W1'][676][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[676][0])
    parameters['W1'][676][3] = parameters['W1'][676][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[676][0])

    parameters['W1'][677][0] = parameters['W1'][677][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[677][0])
    parameters['W1'][677][1] = parameters['W1'][677][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[677][0])
    parameters['W1'][677][2] = parameters['W1'][677][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[677][0])
    parameters['W1'][677][3] = parameters['W1'][677][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[677][0])

    parameters['W1'][678][0] = parameters['W1'][678][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[678][0])
    parameters['W1'][678][1] = parameters['W1'][678][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[678][0])
    parameters['W1'][678][2] = parameters['W1'][678][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[678][0])
    parameters['W1'][678][3] = parameters['W1'][678][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[678][0])

    parameters['W1'][679][0] = parameters['W1'][679][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[679][0])
    parameters['W1'][679][1] = parameters['W1'][679][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[679][0])
    parameters['W1'][679][2] = parameters['W1'][679][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[679][0])
    parameters['W1'][679][3] = parameters['W1'][679][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[679][0])

    parameters['W1'][680][0] = parameters['W1'][680][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[680][0])
    parameters['W1'][680][1] = parameters['W1'][680][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[680][0])
    parameters['W1'][680][2] = parameters['W1'][680][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[680][0])
    parameters['W1'][680][3] = parameters['W1'][680][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[680][0])

    parameters['W1'][681][0] = parameters['W1'][681][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[681][0])
    parameters['W1'][681][1] = parameters['W1'][681][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[681][0])
    parameters['W1'][681][2] = parameters['W1'][681][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[681][0])
    parameters['W1'][681][3] = parameters['W1'][681][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[681][0])

    parameters['W1'][682][0] = parameters['W1'][682][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[682][0])
    parameters['W1'][682][1] = parameters['W1'][682][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[682][0])
    parameters['W1'][682][2] = parameters['W1'][682][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[682][0])
    parameters['W1'][682][3] = parameters['W1'][682][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[682][0])

    parameters['W1'][683][0] = parameters['W1'][683][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[683][0])
    parameters['W1'][683][1] = parameters['W1'][683][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[683][0])
    parameters['W1'][683][2] = parameters['W1'][683][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[683][0])
    parameters['W1'][683][3] = parameters['W1'][683][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[683][0])

    parameters['W1'][684][0] = parameters['W1'][684][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[684][0])
    parameters['W1'][684][1] = parameters['W1'][684][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[684][0])
    parameters['W1'][684][2] = parameters['W1'][684][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[684][0])
    parameters['W1'][684][3] = parameters['W1'][684][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[684][0])

    parameters['W1'][685][0] = parameters['W1'][685][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[685][0])
    parameters['W1'][685][1] = parameters['W1'][685][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[685][0])
    parameters['W1'][685][2] = parameters['W1'][685][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[685][0])
    parameters['W1'][685][3] = parameters['W1'][685][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[685][0])

    parameters['W1'][686][0] = parameters['W1'][686][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[686][0])
    parameters['W1'][686][1] = parameters['W1'][686][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[686][0])
    parameters['W1'][686][2] = parameters['W1'][686][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[686][0])
    parameters['W1'][686][3] = parameters['W1'][686][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[686][0])

    parameters['W1'][687][0] = parameters['W1'][687][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[687][0])
    parameters['W1'][687][1] = parameters['W1'][687][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[687][0])
    parameters['W1'][687][2] = parameters['W1'][687][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[687][0])
    parameters['W1'][687][3] = parameters['W1'][687][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[687][0])

    parameters['W1'][688][0] = parameters['W1'][688][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[688][0])
    parameters['W1'][688][1] = parameters['W1'][688][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[688][0])
    parameters['W1'][688][2] = parameters['W1'][688][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[688][0])
    parameters['W1'][688][3] = parameters['W1'][688][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[688][0])

    parameters['W1'][689][0] = parameters['W1'][689][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[689][0])
    parameters['W1'][689][1] = parameters['W1'][689][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[689][0])
    parameters['W1'][689][2] = parameters['W1'][689][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[689][0])
    parameters['W1'][689][3] = parameters['W1'][689][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[689][0])

    parameters['W1'][690][0] = parameters['W1'][690][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[690][0])
    parameters['W1'][690][1] = parameters['W1'][690][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[690][0])
    parameters['W1'][690][2] = parameters['W1'][690][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[690][0])
    parameters['W1'][690][3] = parameters['W1'][690][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[690][0])

    parameters['W1'][691][0] = parameters['W1'][691][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[691][0])
    parameters['W1'][691][1] = parameters['W1'][691][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[691][0])
    parameters['W1'][691][2] = parameters['W1'][691][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[691][0])
    parameters['W1'][691][3] = parameters['W1'][691][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[691][0])

    parameters['W1'][692][0] = parameters['W1'][692][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[692][0])
    parameters['W1'][692][1] = parameters['W1'][692][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[692][0])
    parameters['W1'][692][2] = parameters['W1'][692][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[692][0])
    parameters['W1'][692][3] = parameters['W1'][692][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[692][0])

    parameters['W1'][693][0] = parameters['W1'][693][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[693][0])
    parameters['W1'][693][1] = parameters['W1'][693][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[693][0])
    parameters['W1'][693][2] = parameters['W1'][693][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[693][0])
    parameters['W1'][693][3] = parameters['W1'][693][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[693][0])

    parameters['W1'][694][0] = parameters['W1'][694][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[694][0])
    parameters['W1'][694][1] = parameters['W1'][694][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[694][0])
    parameters['W1'][694][2] = parameters['W1'][694][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[694][0])
    parameters['W1'][694][3] = parameters['W1'][694][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[694][0])

    parameters['W1'][695][0] = parameters['W1'][695][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[695][0])
    parameters['W1'][695][1] = parameters['W1'][695][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[695][0])
    parameters['W1'][695][2] = parameters['W1'][695][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[695][0])
    parameters['W1'][695][3] = parameters['W1'][695][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[695][0])

    parameters['W1'][696][0] = parameters['W1'][696][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[696][0])
    parameters['W1'][696][1] = parameters['W1'][696][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[696][0])
    parameters['W1'][696][2] = parameters['W1'][696][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[696][0])
    parameters['W1'][696][3] = parameters['W1'][696][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[696][0])

    parameters['W1'][697][0] = parameters['W1'][697][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[697][0])
    parameters['W1'][697][1] = parameters['W1'][697][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[697][0])
    parameters['W1'][697][2] = parameters['W1'][697][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[697][0])
    parameters['W1'][697][3] = parameters['W1'][697][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[697][0])

    parameters['W1'][698][0] = parameters['W1'][698][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[698][0])
    parameters['W1'][698][1] = parameters['W1'][698][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[698][0])
    parameters['W1'][698][2] = parameters['W1'][698][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[698][0])
    parameters['W1'][698][3] = parameters['W1'][698][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[698][0])

    parameters['W1'][699][0] = parameters['W1'][699][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[699][0])
    parameters['W1'][699][1] = parameters['W1'][699][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[699][0])
    parameters['W1'][699][2] = parameters['W1'][699][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[699][0])
    parameters['W1'][699][3] = parameters['W1'][699][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[699][0])

    parameters['W1'][700][0] = parameters['W1'][700][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[700][0])
    parameters['W1'][700][1] = parameters['W1'][700][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[700][0])
    parameters['W1'][700][2] = parameters['W1'][700][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[700][0])
    parameters['W1'][700][3] = parameters['W1'][700][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[700][0])

    parameters['W1'][701][0] = parameters['W1'][701][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[701][0])
    parameters['W1'][701][1] = parameters['W1'][701][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[701][0])
    parameters['W1'][701][2] = parameters['W1'][701][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[701][0])
    parameters['W1'][701][3] = parameters['W1'][701][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[701][0])

    parameters['W1'][702][0] = parameters['W1'][702][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[702][0])
    parameters['W1'][702][1] = parameters['W1'][702][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[702][0])
    parameters['W1'][702][2] = parameters['W1'][702][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[702][0])
    parameters['W1'][702][3] = parameters['W1'][702][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[702][0])

    parameters['W1'][703][0] = parameters['W1'][703][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[703][0])
    parameters['W1'][703][1] = parameters['W1'][703][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[703][0])
    parameters['W1'][703][2] = parameters['W1'][703][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[703][0])
    parameters['W1'][703][3] = parameters['W1'][703][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[703][0])

    parameters['W1'][704][0] = parameters['W1'][704][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[704][0])
    parameters['W1'][704][1] = parameters['W1'][704][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[704][0])
    parameters['W1'][704][2] = parameters['W1'][704][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[704][0])
    parameters['W1'][704][3] = parameters['W1'][704][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[704][0])

    parameters['W1'][705][0] = parameters['W1'][705][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[705][0])
    parameters['W1'][705][1] = parameters['W1'][705][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[705][0])
    parameters['W1'][705][2] = parameters['W1'][705][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[705][0])
    parameters['W1'][705][3] = parameters['W1'][705][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[705][0])

    parameters['W1'][706][0] = parameters['W1'][706][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[706][0])
    parameters['W1'][706][1] = parameters['W1'][706][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[706][0])
    parameters['W1'][706][2] = parameters['W1'][706][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[706][0])
    parameters['W1'][706][3] = parameters['W1'][706][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[706][0])

    parameters['W1'][707][0] = parameters['W1'][707][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[707][0])
    parameters['W1'][707][1] = parameters['W1'][707][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[707][0])
    parameters['W1'][707][2] = parameters['W1'][707][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[707][0])
    parameters['W1'][707][3] = parameters['W1'][707][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[707][0])

    parameters['W1'][708][0] = parameters['W1'][708][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[708][0])
    parameters['W1'][708][1] = parameters['W1'][708][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[708][0])
    parameters['W1'][708][2] = parameters['W1'][708][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[708][0])
    parameters['W1'][708][3] = parameters['W1'][708][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[708][0])

    parameters['W1'][709][0] = parameters['W1'][709][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[709][0])
    parameters['W1'][709][1] = parameters['W1'][709][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[709][0])
    parameters['W1'][709][2] = parameters['W1'][709][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[709][0])
    parameters['W1'][709][3] = parameters['W1'][709][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[709][0])

    parameters['W1'][710][0] = parameters['W1'][710][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[710][0])
    parameters['W1'][710][1] = parameters['W1'][710][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[710][0])
    parameters['W1'][710][2] = parameters['W1'][710][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[710][0])
    parameters['W1'][710][3] = parameters['W1'][710][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[710][0])

    parameters['W1'][711][0] = parameters['W1'][711][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[711][0])
    parameters['W1'][711][1] = parameters['W1'][711][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[711][0])
    parameters['W1'][711][2] = parameters['W1'][711][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[711][0])
    parameters['W1'][711][3] = parameters['W1'][711][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[711][0])

    parameters['W1'][712][0] = parameters['W1'][712][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[712][0])
    parameters['W1'][712][1] = parameters['W1'][712][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[712][0])
    parameters['W1'][712][2] = parameters['W1'][712][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[712][0])
    parameters['W1'][712][3] = parameters['W1'][712][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[712][0])

    parameters['W1'][713][0] = parameters['W1'][713][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[713][0])
    parameters['W1'][713][1] = parameters['W1'][713][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[713][0])
    parameters['W1'][713][2] = parameters['W1'][713][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[713][0])
    parameters['W1'][713][3] = parameters['W1'][713][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[713][0])

    parameters['W1'][714][0] = parameters['W1'][714][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[714][0])
    parameters['W1'][714][1] = parameters['W1'][714][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[714][0])
    parameters['W1'][714][2] = parameters['W1'][714][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[714][0])
    parameters['W1'][714][3] = parameters['W1'][714][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[714][0])

    parameters['W1'][715][0] = parameters['W1'][715][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[715][0])
    parameters['W1'][715][1] = parameters['W1'][715][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[715][0])
    parameters['W1'][715][2] = parameters['W1'][715][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[715][0])
    parameters['W1'][715][3] = parameters['W1'][715][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[715][0])

    parameters['W1'][716][0] = parameters['W1'][716][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[716][0])
    parameters['W1'][716][1] = parameters['W1'][716][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[716][0])
    parameters['W1'][716][2] = parameters['W1'][716][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[716][0])
    parameters['W1'][716][3] = parameters['W1'][716][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[716][0])

    parameters['W1'][717][0] = parameters['W1'][717][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[717][0])
    parameters['W1'][717][1] = parameters['W1'][717][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[717][0])
    parameters['W1'][717][2] = parameters['W1'][717][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[717][0])
    parameters['W1'][717][3] = parameters['W1'][717][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[717][0])

    parameters['W1'][718][0] = parameters['W1'][718][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[718][0])
    parameters['W1'][718][1] = parameters['W1'][718][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[718][0])
    parameters['W1'][718][2] = parameters['W1'][718][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[718][0])
    parameters['W1'][718][3] = parameters['W1'][718][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[718][0])

    parameters['W1'][719][0] = parameters['W1'][719][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[719][0])
    parameters['W1'][719][1] = parameters['W1'][719][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[719][0])
    parameters['W1'][719][2] = parameters['W1'][719][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[719][0])
    parameters['W1'][719][3] = parameters['W1'][719][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[719][0])

    parameters['W1'][720][0] = parameters['W1'][720][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[720][0])
    parameters['W1'][720][1] = parameters['W1'][720][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[720][0])
    parameters['W1'][720][2] = parameters['W1'][720][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[720][0])
    parameters['W1'][720][3] = parameters['W1'][720][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[720][0])

    parameters['W1'][721][0] = parameters['W1'][721][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[721][0])
    parameters['W1'][721][1] = parameters['W1'][721][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[721][0])
    parameters['W1'][721][2] = parameters['W1'][721][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[721][0])
    parameters['W1'][721][3] = parameters['W1'][721][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[721][0])

    parameters['W1'][722][0] = parameters['W1'][722][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[722][0])
    parameters['W1'][722][1] = parameters['W1'][722][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[722][0])
    parameters['W1'][722][2] = parameters['W1'][722][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[722][0])
    parameters['W1'][722][3] = parameters['W1'][722][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[722][0])

    parameters['W1'][723][0] = parameters['W1'][723][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[723][0])
    parameters['W1'][723][1] = parameters['W1'][723][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[723][0])
    parameters['W1'][723][2] = parameters['W1'][723][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[723][0])
    parameters['W1'][723][3] = parameters['W1'][723][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[723][0])

    parameters['W1'][724][0] = parameters['W1'][724][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[724][0])
    parameters['W1'][724][1] = parameters['W1'][724][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[724][0])
    parameters['W1'][724][2] = parameters['W1'][724][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[724][0])
    parameters['W1'][724][3] = parameters['W1'][724][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[724][0])

    parameters['W1'][725][0] = parameters['W1'][725][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[725][0])
    parameters['W1'][725][1] = parameters['W1'][725][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[725][0])
    parameters['W1'][725][2] = parameters['W1'][725][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[725][0])
    parameters['W1'][725][3] = parameters['W1'][725][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[725][0])

    parameters['W1'][726][0] = parameters['W1'][726][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[726][0])
    parameters['W1'][726][1] = parameters['W1'][726][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[726][0])
    parameters['W1'][726][2] = parameters['W1'][726][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[726][0])
    parameters['W1'][726][3] = parameters['W1'][726][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[726][0])

    parameters['W1'][727][0] = parameters['W1'][727][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[727][0])
    parameters['W1'][727][1] = parameters['W1'][727][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[727][0])
    parameters['W1'][727][2] = parameters['W1'][727][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[727][0])
    parameters['W1'][727][3] = parameters['W1'][727][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[727][0])

    parameters['W1'][728][0] = parameters['W1'][728][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[728][0])
    parameters['W1'][728][1] = parameters['W1'][728][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[728][0])
    parameters['W1'][728][2] = parameters['W1'][728][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[728][0])
    parameters['W1'][728][3] = parameters['W1'][728][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[728][0])

    parameters['W1'][729][0] = parameters['W1'][729][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[729][0])
    parameters['W1'][729][1] = parameters['W1'][729][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[729][0])
    parameters['W1'][729][2] = parameters['W1'][729][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[729][0])
    parameters['W1'][729][3] = parameters['W1'][729][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[729][0])

    parameters['W1'][730][0] = parameters['W1'][730][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[730][0])
    parameters['W1'][730][1] = parameters['W1'][730][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[730][0])
    parameters['W1'][730][2] = parameters['W1'][730][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[730][0])
    parameters['W1'][730][3] = parameters['W1'][730][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[730][0])

    parameters['W1'][731][0] = parameters['W1'][731][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[731][0])
    parameters['W1'][731][1] = parameters['W1'][731][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[731][0])
    parameters['W1'][731][2] = parameters['W1'][731][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[731][0])
    parameters['W1'][731][3] = parameters['W1'][731][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[731][0])

    parameters['W1'][732][0] = parameters['W1'][732][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[732][0])
    parameters['W1'][732][1] = parameters['W1'][732][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[732][0])
    parameters['W1'][732][2] = parameters['W1'][732][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[732][0])
    parameters['W1'][732][3] = parameters['W1'][732][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[732][0])

    parameters['W1'][733][0] = parameters['W1'][733][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[733][0])
    parameters['W1'][733][1] = parameters['W1'][733][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[733][0])
    parameters['W1'][733][2] = parameters['W1'][733][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[733][0])
    parameters['W1'][733][3] = parameters['W1'][733][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[733][0])

    parameters['W1'][734][0] = parameters['W1'][734][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[734][0])
    parameters['W1'][734][1] = parameters['W1'][734][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[734][0])
    parameters['W1'][734][2] = parameters['W1'][734][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[734][0])
    parameters['W1'][734][3] = parameters['W1'][734][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[734][0])

    parameters['W1'][735][0] = parameters['W1'][735][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[735][0])
    parameters['W1'][735][1] = parameters['W1'][735][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[735][0])
    parameters['W1'][735][2] = parameters['W1'][735][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[735][0])
    parameters['W1'][735][3] = parameters['W1'][735][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[735][0])

    parameters['W1'][736][0] = parameters['W1'][736][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[736][0])
    parameters['W1'][736][1] = parameters['W1'][736][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[736][0])
    parameters['W1'][736][2] = parameters['W1'][736][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[736][0])
    parameters['W1'][736][3] = parameters['W1'][736][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[736][0])

    parameters['W1'][737][0] = parameters['W1'][737][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[737][0])
    parameters['W1'][737][1] = parameters['W1'][737][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[737][0])
    parameters['W1'][737][2] = parameters['W1'][737][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[737][0])
    parameters['W1'][737][3] = parameters['W1'][737][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[737][0])

    parameters['W1'][738][0] = parameters['W1'][738][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[738][0])
    parameters['W1'][738][1] = parameters['W1'][738][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[738][0])
    parameters['W1'][738][2] = parameters['W1'][738][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[738][0])
    parameters['W1'][738][3] = parameters['W1'][738][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[738][0])

    parameters['W1'][739][0] = parameters['W1'][739][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[739][0])
    parameters['W1'][739][1] = parameters['W1'][739][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[739][0])
    parameters['W1'][739][2] = parameters['W1'][739][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[739][0])
    parameters['W1'][739][3] = parameters['W1'][739][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[739][0])

    parameters['W1'][740][0] = parameters['W1'][740][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[740][0])
    parameters['W1'][740][1] = parameters['W1'][740][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[740][0])
    parameters['W1'][740][2] = parameters['W1'][740][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[740][0])
    parameters['W1'][740][3] = parameters['W1'][740][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[740][0])

    parameters['W1'][741][0] = parameters['W1'][741][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[741][0])
    parameters['W1'][741][1] = parameters['W1'][741][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[741][0])
    parameters['W1'][741][2] = parameters['W1'][741][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[741][0])
    parameters['W1'][741][3] = parameters['W1'][741][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[741][0])

    parameters['W1'][742][0] = parameters['W1'][742][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[742][0])
    parameters['W1'][742][1] = parameters['W1'][742][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[742][0])
    parameters['W1'][742][2] = parameters['W1'][742][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[742][0])
    parameters['W1'][742][3] = parameters['W1'][742][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[742][0])

    parameters['W1'][743][0] = parameters['W1'][743][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[743][0])
    parameters['W1'][743][1] = parameters['W1'][743][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[743][0])
    parameters['W1'][743][2] = parameters['W1'][743][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[743][0])
    parameters['W1'][743][3] = parameters['W1'][743][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[743][0])

    parameters['W1'][744][0] = parameters['W1'][744][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[744][0])
    parameters['W1'][744][1] = parameters['W1'][744][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[744][0])
    parameters['W1'][744][2] = parameters['W1'][744][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[744][0])
    parameters['W1'][744][3] = parameters['W1'][744][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[744][0])

    parameters['W1'][745][0] = parameters['W1'][745][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[745][0])
    parameters['W1'][745][1] = parameters['W1'][745][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[745][0])
    parameters['W1'][745][2] = parameters['W1'][745][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[745][0])
    parameters['W1'][745][3] = parameters['W1'][745][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[745][0])

    parameters['W1'][746][0] = parameters['W1'][746][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[746][0])
    parameters['W1'][746][1] = parameters['W1'][746][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[746][0])
    parameters['W1'][746][2] = parameters['W1'][746][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[746][0])
    parameters['W1'][746][3] = parameters['W1'][746][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[746][0])

    parameters['W1'][747][0] = parameters['W1'][747][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[747][0])
    parameters['W1'][747][1] = parameters['W1'][747][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[747][0])
    parameters['W1'][747][2] = parameters['W1'][747][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[747][0])
    parameters['W1'][747][3] = parameters['W1'][747][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[747][0])

    parameters['W1'][748][0] = parameters['W1'][748][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[748][0])
    parameters['W1'][748][1] = parameters['W1'][748][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[748][0])
    parameters['W1'][748][2] = parameters['W1'][748][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[748][0])
    parameters['W1'][748][3] = parameters['W1'][748][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[748][0])

    parameters['W1'][749][0] = parameters['W1'][749][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[749][0])
    parameters['W1'][749][1] = parameters['W1'][749][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[749][0])
    parameters['W1'][749][2] = parameters['W1'][749][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[749][0])
    parameters['W1'][749][3] = parameters['W1'][749][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[749][0])

    parameters['W1'][750][0] = parameters['W1'][750][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[750][0])
    parameters['W1'][750][1] = parameters['W1'][750][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[750][0])
    parameters['W1'][750][2] = parameters['W1'][750][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[750][0])
    parameters['W1'][750][3] = parameters['W1'][750][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[750][0])

    parameters['W1'][751][0] = parameters['W1'][751][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[751][0])
    parameters['W1'][751][1] = parameters['W1'][751][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[751][0])
    parameters['W1'][751][2] = parameters['W1'][751][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[751][0])
    parameters['W1'][751][3] = parameters['W1'][751][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[751][0])

    parameters['W1'][752][0] = parameters['W1'][752][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[752][0])
    parameters['W1'][752][1] = parameters['W1'][752][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[752][0])
    parameters['W1'][752][2] = parameters['W1'][752][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[752][0])
    parameters['W1'][752][3] = parameters['W1'][752][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[752][0])

    parameters['W1'][753][0] = parameters['W1'][753][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[753][0])
    parameters['W1'][753][1] = parameters['W1'][753][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[753][0])
    parameters['W1'][753][2] = parameters['W1'][753][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[753][0])
    parameters['W1'][753][3] = parameters['W1'][753][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[753][0])

    parameters['W1'][754][0] = parameters['W1'][754][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[754][0])
    parameters['W1'][754][1] = parameters['W1'][754][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[754][0])
    parameters['W1'][754][2] = parameters['W1'][754][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[754][0])
    parameters['W1'][754][3] = parameters['W1'][754][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[754][0])

    parameters['W1'][755][0] = parameters['W1'][755][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[755][0])
    parameters['W1'][755][1] = parameters['W1'][755][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[755][0])
    parameters['W1'][755][2] = parameters['W1'][755][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[755][0])
    parameters['W1'][755][3] = parameters['W1'][755][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[755][0])

    parameters['W1'][756][0] = parameters['W1'][756][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[756][0])
    parameters['W1'][756][1] = parameters['W1'][756][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[756][0])
    parameters['W1'][756][2] = parameters['W1'][756][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[756][0])
    parameters['W1'][756][3] = parameters['W1'][756][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[756][0])

    parameters['W1'][757][0] = parameters['W1'][757][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[757][0])
    parameters['W1'][757][1] = parameters['W1'][757][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[757][0])
    parameters['W1'][757][2] = parameters['W1'][757][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[757][0])
    parameters['W1'][757][3] = parameters['W1'][757][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[757][0])

    parameters['W1'][758][0] = parameters['W1'][758][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[758][0])
    parameters['W1'][758][1] = parameters['W1'][758][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[758][0])
    parameters['W1'][758][2] = parameters['W1'][758][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[758][0])
    parameters['W1'][758][3] = parameters['W1'][758][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[758][0])

    parameters['W1'][759][0] = parameters['W1'][759][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[759][0])
    parameters['W1'][759][1] = parameters['W1'][759][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[759][0])
    parameters['W1'][759][2] = parameters['W1'][759][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[759][0])
    parameters['W1'][759][3] = parameters['W1'][759][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[759][0])

    parameters['W1'][760][0] = parameters['W1'][760][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[760][0])
    parameters['W1'][760][1] = parameters['W1'][760][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[760][0])
    parameters['W1'][760][2] = parameters['W1'][760][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[760][0])
    parameters['W1'][760][3] = parameters['W1'][760][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[760][0])

    parameters['W1'][761][0] = parameters['W1'][761][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[761][0])
    parameters['W1'][761][1] = parameters['W1'][761][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[761][0])
    parameters['W1'][761][2] = parameters['W1'][761][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[761][0])
    parameters['W1'][761][3] = parameters['W1'][761][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[761][0])

    parameters['W1'][762][0] = parameters['W1'][762][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[762][0])
    parameters['W1'][762][1] = parameters['W1'][762][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[762][0])
    parameters['W1'][762][2] = parameters['W1'][762][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[762][0])
    parameters['W1'][762][3] = parameters['W1'][762][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[762][0])

    parameters['W1'][763][0] = parameters['W1'][763][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[763][0])
    parameters['W1'][763][1] = parameters['W1'][763][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[763][0])
    parameters['W1'][763][2] = parameters['W1'][763][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[763][0])
    parameters['W1'][763][3] = parameters['W1'][763][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[763][0])

    parameters['W1'][764][0] = parameters['W1'][764][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[764][0])
    parameters['W1'][764][1] = parameters['W1'][764][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[764][0])
    parameters['W1'][764][2] = parameters['W1'][764][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[764][0])
    parameters['W1'][764][3] = parameters['W1'][764][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[764][0])

    parameters['W1'][765][0] = parameters['W1'][765][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[765][0])
    parameters['W1'][765][1] = parameters['W1'][765][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[765][0])
    parameters['W1'][765][2] = parameters['W1'][765][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[765][0])
    parameters['W1'][765][3] = parameters['W1'][765][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[765][0])

    parameters['W1'][766][0] = parameters['W1'][766][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[766][0])
    parameters['W1'][766][1] = parameters['W1'][766][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[766][0])
    parameters['W1'][766][2] = parameters['W1'][766][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[766][0])
    parameters['W1'][766][3] = parameters['W1'][766][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[766][0])

    parameters['W1'][767][0] = parameters['W1'][767][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[767][0])
    parameters['W1'][767][1] = parameters['W1'][767][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[767][0])
    parameters['W1'][767][2] = parameters['W1'][767][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[767][0])
    parameters['W1'][767][3] = parameters['W1'][767][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[767][0])

    parameters['W1'][768][0] = parameters['W1'][768][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[768][0])
    parameters['W1'][768][1] = parameters['W1'][768][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[768][0])
    parameters['W1'][768][2] = parameters['W1'][768][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[768][0])
    parameters['W1'][768][3] = parameters['W1'][768][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[768][0])

    parameters['W1'][769][0] = parameters['W1'][769][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[769][0])
    parameters['W1'][769][1] = parameters['W1'][769][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[769][0])
    parameters['W1'][769][2] = parameters['W1'][769][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[769][0])
    parameters['W1'][769][3] = parameters['W1'][769][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[769][0])

    parameters['W1'][770][0] = parameters['W1'][770][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[770][0])
    parameters['W1'][770][1] = parameters['W1'][770][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[770][0])
    parameters['W1'][770][2] = parameters['W1'][770][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[770][0])
    parameters['W1'][770][3] = parameters['W1'][770][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[770][0])

    parameters['W1'][771][0] = parameters['W1'][771][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[771][0])
    parameters['W1'][771][1] = parameters['W1'][771][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[771][0])
    parameters['W1'][771][2] = parameters['W1'][771][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[771][0])
    parameters['W1'][771][3] = parameters['W1'][771][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[771][0])

    parameters['W1'][772][0] = parameters['W1'][772][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[772][0])
    parameters['W1'][772][1] = parameters['W1'][772][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[772][0])
    parameters['W1'][772][2] = parameters['W1'][772][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[772][0])
    parameters['W1'][772][3] = parameters['W1'][772][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[772][0])

    parameters['W1'][773][0] = parameters['W1'][773][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[773][0])
    parameters['W1'][773][1] = parameters['W1'][773][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[773][0])
    parameters['W1'][773][2] = parameters['W1'][773][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[773][0])
    parameters['W1'][773][3] = parameters['W1'][773][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[773][0])

    parameters['W1'][774][0] = parameters['W1'][774][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[774][0])
    parameters['W1'][774][1] = parameters['W1'][774][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[774][0])
    parameters['W1'][774][2] = parameters['W1'][774][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[774][0])
    parameters['W1'][774][3] = parameters['W1'][774][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[774][0])

    parameters['W1'][775][0] = parameters['W1'][775][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[775][0])
    parameters['W1'][775][1] = parameters['W1'][775][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[775][0])
    parameters['W1'][775][2] = parameters['W1'][775][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[775][0])
    parameters['W1'][775][3] = parameters['W1'][775][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[775][0])

    parameters['W1'][776][0] = parameters['W1'][776][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[776][0])
    parameters['W1'][776][1] = parameters['W1'][776][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[776][0])
    parameters['W1'][776][2] = parameters['W1'][776][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[776][0])
    parameters['W1'][776][3] = parameters['W1'][776][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[776][0])

    parameters['W1'][777][0] = parameters['W1'][777][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[777][0])
    parameters['W1'][777][1] = parameters['W1'][777][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[777][0])
    parameters['W1'][777][2] = parameters['W1'][777][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[777][0])
    parameters['W1'][777][3] = parameters['W1'][777][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[777][0])

    parameters['W1'][778][0] = parameters['W1'][778][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[778][0])
    parameters['W1'][778][1] = parameters['W1'][778][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[778][0])
    parameters['W1'][778][2] = parameters['W1'][778][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[778][0])
    parameters['W1'][778][3] = parameters['W1'][778][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[778][0])

    parameters['W1'][779][0] = parameters['W1'][779][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[779][0])
    parameters['W1'][779][1] = parameters['W1'][779][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[779][0])
    parameters['W1'][779][2] = parameters['W1'][779][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[779][0])
    parameters['W1'][779][3] = parameters['W1'][779][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[779][0])

    parameters['W1'][780][0] = parameters['W1'][780][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[780][0])
    parameters['W1'][780][1] = parameters['W1'][780][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[780][0])
    parameters['W1'][780][2] = parameters['W1'][780][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[780][0])
    parameters['W1'][780][3] = parameters['W1'][780][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[780][0])

    parameters['W1'][781][0] = parameters['W1'][781][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[781][0])
    parameters['W1'][781][1] = parameters['W1'][781][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[781][0])
    parameters['W1'][781][2] = parameters['W1'][781][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[781][0])
    parameters['W1'][781][3] = parameters['W1'][781][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[781][0])

    parameters['W1'][782][0] = parameters['W1'][782][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[782][0])
    parameters['W1'][782][1] = parameters['W1'][782][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[782][0])
    parameters['W1'][782][2] = parameters['W1'][782][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[782][0])
    parameters['W1'][782][3] = parameters['W1'][782][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[782][0])

    parameters['W1'][783][0] = parameters['W1'][783][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0]*X[783][0])
    parameters['W1'][783][1] = parameters['W1'][783][1] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0]*X[783][0])
    parameters['W1'][783][2] = parameters['W1'][783][2] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0]*X[783][0])
    parameters['W1'][783][3] = parameters['W1'][783][3] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0]*X[783][0])

    

        
    parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 *  (y - y_hat)*A1[0][0]*(1-A1[0][0])*parameters['W2'][0][0])
    parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 *  (y - y_hat)*A1[1][0]*(1-A1[1][0])*parameters['W2'][1][0])
    parameters['b1'][2][0] = parameters['b1'][2][0] + (0.001 *  (y - y_hat)*A1[2][0]*(1-A1[2][0])*parameters['W2'][2][0])
    parameters['b1'][3][0] = parameters['b1'][3][0] + (0.001 *  (y - y_hat)*A1[3][0]*(1-A1[3][0])*parameters['W2'][3][0])
